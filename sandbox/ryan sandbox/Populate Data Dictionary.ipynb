# %%
import boto3
import pandas as pd
import awswrangler as wr

# %%
! aws sso login --profile Stellaralgo-DataScienceAdmin
# Out:
# Attempting to automatically open the SSO authorization page in your default browser.
# If the browser does not open or you wish to use a different device to authorize this request, open the following URL:
#
# https://device.sso.us-east-1.amazonaws.com/
#
# Then enter the code:
#
# RDMK-VBJM
# Successully logged into Start URL: https://stellaralgo.awsapps.com/start

# %%
session = boto3.setup_default_session(profile_name='Stellaralgo-DataScienceAdmin')
client = boto3.client('redshift')

cluster = 'qa-app'
dbname = 'datascience'
schema = 'ds'
table = 'dummytable'
    
conn = wr.data_api.redshift.connect(
    cluster_id = cluster,
    database = dbname,
    db_user = "admin"
)

# %%
df_data_dictionary = pd.read_csv('./data_dictionary.csv')
df_data_dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Model        84 non-null     object
#  1   Feature Raw  84 non-null     object
#  2   Feature      84 non-null     object
#  3   Data Type    84 non-null     object
#  4   Source       82 non-null     object
#  5   Engineered   84 non-null     bool
#  6   Description  84 non-null     object
# dtypes: bool(1), object(6)
# memory usage: 4.1+ KB

# %%
fields = f"""
    INSERT INTO datascience.ds.datadictionary (
        feature,
        featureraw,
        datatype,
        source,
        engineered,
        description
    ) VALUES """

values_list = []
for i, row in df_data_dictionary.iterrows():
    
    values = f"""(
        '{row["Feature"]}',
        '{row["Feature Raw"]}',
        '{row["Data Type"]}',
        '{row["Source"]}',
        {row["Engineered"]},
        '{row["Description"]}'
    )"""
    
    values_list.append(values)
        
insert_statement = fields + ",".join(values_list)+";"
 
wr.data_api.redshift.read_sql_query(
    sql = insert_statement, 
    con = conn
)
# Out:
#     INSERT INTO datascience.ds.datadictionary (
#         feature,
#         featureraw,
#         datatype,
#         source,
#         engineered,
#         description
#     ) VALUES (
#         'Annual Household Income',
#         'annualHHIncome',
#         'object',
#         'Demographic Data',
#         True,
#         'Total amount of annual income in the household'
#     ),(
#         'Attendance',
#         'attendancePercent',
#         'float64',
#         'Ticketing',
#         True,
#         'The attendance percentage for the season'
#     ),(
#         'Cancel Records',
#         'cancel_records',
#         'int64',
#         'Secondary',
#         True,
#         'Total number of Ticket Exchange cancel records in a season year for a customer'
#     ),(
#         'Children in Household',
#         'childrenPresentInHH',
#         'int64',
#         'Demographic Data',
#         False,
#         'Total number of childerns in a household'
#     ),(
#         'Click Link',
#         'click_link',
#         'int64',
#         'Marketing',
#         True,
#         'Total number of activities a customer clicked an marketing email'
#     ),(
#         'Click to Open Ratio',
#         'clickToOpenRatio',
#         'float64',
#         'Marketing',
#         True,
#         'Total number of clicked marketing email devided by opened email'
#     ),(
#         'Click to Send Ratio',
#         'clickToSendRatio',
#         'float64',
#         'Marketing',
#         True,
#         'Total number of clicked marketing email devided by sent email'
#     ),(
#         'Received Credits After Refund',
#         'credits_after_refund',
#         'float64',
#         'Ticketing',
#         True,
#         'Total amonut of credit a customer has after getting refund'
#     ),(
#         'Internal Feature',
#         'customerNumber',
#         'object',
#         'dimCustomer table',
#         False,
#         'Source ticketing account number'
#     ),(
#         'Purchase Days Out From Event',
#         'daysOut',
#         'object',
#         'Ticketing',
#         True,
#         'How many days out (bucketed) this potential purchase is from the event date. Possible values are Day-of, 1-3 days, 4-7 days or 8+ days'
#     ),(
#         'Internal Feature',
#         'did_purchase',
#         'int64',
#         'Ticketing',
#         True,
#         'In Case a customer bought ticket for an event did_purchase is 1 else 0. Target variable for prediction'
#     ),(
#         'Internal Feature',
#         'dimCustomerMasterId',
#         'int64',
#         'Customer',
#         False,
#         'SCV ID for the fan making the potential purchase. Not used for prediction'
#     ),(
#         'Internal Feature',
#         'dimCustomerMasterId',
#         'int64',
#         'dimCustomerMaster table',
#         False,
#         'SCV ID for the fan making the potential purchase. Not used for prediction'
#     ),(
#         'Distance to Venue',
#         'distanceToVenue',
#         'float64',
#         'Customer',
#         False,
#         'Physical distance of fan from venue'
#     ),(
#         'Distance to Venue',
#         'distToVenue',
#         'float64',
#         'Ticketing',
#         True,
#         'Physical distance of fan from venue'
#     ),(
#         'Education',
#         'education',
#         'object',
#         'Demographic Data',
#         True,
#         'Education of the buyer'
#     ),(
#         'No. Sales Rep Emails',
#         'email',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of email activities in touchpoint data'
#     ),(
#         'Event Date',
#         'eventDate',
#         'datetime64',
#         'Ticketing',
#         False,
#         'Event date that the game happened'
#     ),(
#         'Event Name',
#         'eventName',
#         'object',
#         'Ticketing',
#         False,
#         'Event name of the game. Not used for prediction'
#     ),(
#         'Events Purchased',
#         'events_purchased',
#         'int64',
#         'Ticketing',
#         True,
#         'Total number of events purchased prior to the potential purchase'
#     ),(
#         'Form Filled Out',
#         'fill_out_form',
#         'int64',
#         'Marketing',
#         True,
#         'Total number of activities a customer fill out a form in an marketing email'
#     ),(
#         'Forward Records',
#         'forward_records',
#         'int64',
#         'Secondary',
#         True,
#         'Total number of Ticket Exchange forward records in a season year for a customer'
#     ),(
#         'Event Day Purchase Frequency',
#         'frequency_eventDay',
#         'float64',
#         'Ticketing',
#         True,
#         'Percentage of games purchased prior to the potential purchase on the same day of the week'
#     ),(
#         'Event Time Purchase Frequency',
#         'frequency_eventTime',
#         'float64',
#         'Ticketing',
#         True,
#         'Percentage of games purchased prior to the potential purchase at the same time of day'
#     ),(
#         'Opponent Purchase Frequency',
#         'frequency_opponent',
#         'float64',
#         'Ticketing',
#         True,
#         'Percentage of games purchased prior to the potential purchase with the same opponent'
#     ),(
#         'Gender',
#         'gender',
#         'object',
#         'Demographic Data',
#         False,
#         'Gender of the buyer'
#     ),(
#         'No. Inbound Emails to Rep',
#         'inbound_email',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of inbound activity in email'
#     ),(
#         'No. Inbound Phonecalls to Rep',
#         'inbound_phonecall',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of outbound activity in email'
#     ),(
#         'In Market',
#         'inMarket',
#         'object',
#         'Customer',
#         False,
#         'Whether the fan making this potential purchase is considered in-market'
#     ),(
#         'In Person Contact',
#         'inperson_contact',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of touchpoint acivities which contains MEETING, inPersonContact , appointment, Significant appointment'
#     ),(
#         'No. Notes in CRM',
#         'internal_note',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of touchpoint acivities which contains NOTE, internalNote'
#     ),(
#         'Stadium Availability',
#         'is_Lockdown',
#         'int64',
#         'nan',
#         True,
#         'If a most of the days in a year was lockdown during Covid then is_Lockdown is 1 else 0'
#     ),(
#         'Internal Feature',
#         'isBuyer',
#         'object',
#         'Ticketing',
#         True,
#         'If a customer bought ticket the isBuyer is True else False'
#     ),(
#         'Internal Feature',
#         'isNextYear_Buyer',
#         'int64',
#         'nan',
#         True,
#         'If a customer bought ticket for next season the isNextYear_Buyer is 1 else 0'
#     ),(
#         'Left Voicemail',
#         'left_message',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of messages left in voicecall'
#     ),(
#         'Length of Residence (Yrs)',
#         'lengthOfResidenceInYrs',
#         'object',
#         'Demographic Data',
#         True,
#         'The length of residence of the buyer in his home address'
#     ),(
#         'Marital Status',
#         'maritalStatus',
#         'int64',
#         'Demographic Data',
#         False,
#         'Marital status of the buyer'
#     ),(
#         'Internal Feature',
#         'maxDaysOut',
#         'float64',
#         'Ticketing',
#         True,
#         'Maximum bound for the above bucket. NULL for 8+ days bucket. Not used for prediction'
#     ),(
#         'Internal Feature',
#         'minDaysOut',
#         'int64',
#         'Ticketing',
#         True,
#         'Minimum bound for the above bucket. Not used for prediction'
#     ),(
#         'Missed Games Streak 1',
#         'missed_games_1',
#         'int64',
#         'Ticketing',
#         True,
#         'Number of times the customer has missed 1 consecutive game'
#     ),(
#         'Missed Games Streak 2',
#         'missed_games_2',
#         'int64',
#         'Ticketing',
#         True,
#         'Number of times the customer has missed 2 consecutive games '
#     ),(
#         'Missed Games Streak Over 2',
#         'missed_games_over_2',
#         'int64',
#         'Ticketing',
#         True,
#         'Number of times the customer has missed more than 2 consecutive games'
#     ),(
#         'No. Games per Season',
#         'NumberofGamesPerSeason',
#         'int64',
#         'Ticketing',
#         True,
#         'Total number of games in a season year'
#     ),(
#         'Opened Marketing Email',
#         'open_email',
#         'int64',
#         'Marketing',
#         True,
#         'Total number of activities a customer opened an marketing email'
#     ),(
#         'Open to Send Ratio',
#         'openToSendRatio',
#         'float64',
#         'Marketing',
#         True,
#         'Total number of opened marketing email devided by sent email'
#     ),(
#         'No. Outbound Emails from Rep',
#         'outbound_email',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of outband activity in email'
#     ),(
#         'No. Outbound Phonecalls from Rep',
#         'outbound_phonecall',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of outband activity in phone call'
#     ),(
#         'Phonecall',
#         'phonecall',
#         'int64',
#         'Touchpoint Data',
#         True,
#         'Total number of phonecall activities in touchpoint data'
#     ),(
#         'Posting Records',
#         'posting_records',
#         'int64',
#         'Secondary',
#         True,
#         'Total number of Ticket Exchange posting records in a season year for a customer'
#     ),(
#         'Product',
#         'productGrouping',
#         'object',
#         'dimProduct',
#         False,
#         'Scored product'
#     ),(
#         'Recency',
#         'recency',
#         'int64',
#         'Ticketing',
#         True,
#         'Recency is based on the most recently attended event'
#     ),(
#         'Recent Email Click Rate',
#         'recent_clickRate',
#         'float64',
#         'Marketing',
#         True,
#         'Total number of clicked email divided by total number of opened email. For true purchases (training), scoped to the week prior to purchase date. For potential purchases (training + scoring), scoped to the week prior to the date corresponding to minDaysOut'
#     ),(
#         'Recent Email Open Rate',
#         'recent_openRate',
#         'float64',
#         'Marketing',
#         True,
#         'Total number of opened email divided by total number of sent email. For true purchases (training), scoped to the week prior to purchase date. For potential purchases (training + scoring), scoped to the week prior to the date corresponding to minDaysOut'
#     ),(
#         'Last Attendance Date',
#         'recentDate',
#         'object',
#         'Ticketing',
#         True,
#         'The last event date that a customer attended the game'
#     ),(
#         'Attendance Month - January',
#         'recentDate_month_1',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (1 = January)'
#     ),(
#         'Attendance Month - October',
#         'recentDate_month_10',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (10 = October)'
#     ),(
#         'Attendance Month - November',
#         'recentDate_month_11',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (11 = November)'
#     ),(
#         'Attendance Month - February',
#         'recentDate_month_2',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (2 = February'
#     ),(
#         'Attendance Month - March',
#         'recentDate_month_3',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (3 =March)'
#     ),(
#         'Attendance Month - April',
#         'recentDate_month_4',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (4 = April)'
#     ),(
#         'Attendance Month - May',
#         'recentDate_month_5',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (5 = May)'
#     ),(
#         'Attendance Month - June',
#         'recentDate_month_6',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (6 = June)'
#     ),(
#         'Attendance Month - July',
#         'recentDate_month_7',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (7 = July)'
#     ),(
#         'Attendance Month - August',
#         'recentDate_month_8',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (8 = August)'
#     ),(
#         'Attendance Month - September',
#         'recentDate_month_9',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the month of the recentDate feature (9 = September)'
#     ),(
#         'Attendance Day - Sunday',
#         'recentDate_weekday_0',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (0 = Sunday)'
#     ),(
#         'Attendance Day - Monday',
#         'recentDate_weekday_1',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (1 = Monday)'
#     ),(
#         'Attendance Day - Tuesday',
#         'recentDate_weekday_2',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (2 = Tuesday)'
#     ),(
#         'Attendance Day - Friday',
#         'recentDate_weekday_3',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (3 = Wednesday)'
#     ),(
#         'Attendance Day - Sunday',
#         'recentDate_weekday_4',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (4 = Thursday)'
#     ),(
#         'Attendance Day - Friday',
#         'recentDate_weekday_5',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (5 = Friday)'
#     ),(
#         'Attendance Day - Saturday',
#         'recentDate_weekday_6',
#         'object',
#         'Pycaret',
#         True,
#         'Represents the day of the recentDate feature (6 = Saturday)'
#     ),(
#         'Time to Renew',
#         'renewedBeforeDays',
#         'int64',
#         'Ticketing',
#         True,
#         'The number of days a customer bought a ticket before game'
#     ),(
#         'Secondary ATP',
#         'resale_atp',
#         'float64',
#         'Secondary',
#         True,
#         'Total number of Ticket Exchange resale ATP in a season year for a customer'
#     ),(
#         'Resale Records',
#         'resale_records',
#         'int64',
#         'Secondary',
#         True,
#         'Total number of Ticket Exchange resale records in a season year for a customer'
#     ),(
#         'No. Marketing Email Sends',
#         'send_email',
#         'int64',
#         'Marketing',
#         True,
#         'Total number of activities a customer Sent an marketing email'
#     ),(
#         'Tenure (Provided by Team)',
#         'source_tenure',
#         'int64',
#         'Ticketing',
#         True,
#         'Source tenure for the customer provided by the team'
#     ),(
#         'Tenure',
#         'tenure',
#         'int64',
#         'Ticketing',
#         True,
#         'Number of seasons elapsed since the fans first purchase (as of the potential purchase date)'
#     ),(
#         'Tenure',
#         'tenure',
#         'int64',
#         'Ticketing',
#         True,
#         'Days between first ticketing purchase date to the latest event date for a customer'
#     ),(
#         'Total Games Attended',
#         'totalGames',
#         'int64',
#         'Ticketing',
#         True,
#         'Total attended games by customer, season and product'
#     ),(
#         'Total Ticketing Spend',
#         'totalSpent',
#         'float64',
#         'Ticketing',
#         True,
#         'Total amount of dollars spent for the season'
#     ),(
#         'No. Email Marketing Unsubscribes',
#         'unsubscribe_email',
#         'int64',
#         'Marketing',
#         True,
#         'Total number of activities a customer unsibscribed an marketing email'
#     ),(
#         'Urbanicity',
#         'urbanicity',
#         'object',
#         'Demographic Data',
#         True,
#         'Represents if the customer lives in an urban or suburban area'
#     ),(
#         'Year',
#         'year',
#         'int64',
#         'dimSeason',
#         False,
#         'Scored season year'
#     );
