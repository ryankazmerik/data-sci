# %% [markdown]
# # Experiment - Data Preparation Techniques
# * StelllarAlgo Data Science
# * Ryan Kazmerik, Grant Donst, Peter Morrison
# * Dec 02, 2022

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from shared_utilities import helpers
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA

from pycaret.classification import *

# %% [markdown]
# ## Let's load in a training dataset from Redshift:

# %%
CLUSTER = "prod-app"
DATABASE = "stlrmilb"
LKUPCLIENTID = "44"
SCORING_YEAR = 2022
PRODUCT_MAPPING = {'Flex Plan': 0, 'Mini Plan': 1, 'Quarter Season': 2, 'Half Season': 3, 'Full Season': 4}
PRODUCT_CURRENT_MAPPING = {'Individual': 0, 'Group': 1, 'Mini Pack': 2, 'Quarter': 3, 'Half Season': 4, 'Full Season': 5}

# %%
dataset = helpers.get_product_propensity_dataset(
    cluster=CLUSTER,
    database=DATABASE,
    lkupclientid=LKUPCLIENTID,
    scoring_year=SCORING_YEAR,
    type_flag=0
)

dataset.shape
# Out:
# Authorized as AROASQ4JELIXYLYV6P4UV:pmorrison@stellaralgo.com
# (125567, 27)

# %% [markdown]
# ### Let's choose a smaller set of features for this experiment:

# %%
features = [
    "atp_last",
    "attended_last",
    "distance",
    "events_last",
    "spend_current",
    "sends",
    "tenure",
    "opens",
    "product",
    "volume_current"
]

# %%
df = dataset.copy()

# %%
df = df[features]
df.shape
# Out:
# (125567, 10)

# %% [markdown]
# ### Let's filter our data to product plans only:

# %%
product_plans = [
   "Full Season",
   "Mini Plan"
]

# %%
df = df[df["product"].isin(product_plans)].reset_index(drop=True)
df.shape
# Out:
# (1154, 10)

# %%
df_before = df

# %% [markdown]
# ## Let's visualize the dimensionality of our dataset:

# %%
df_before["product_encoded"] = df_before["product"].astype("category").cat.codes
df_before = df_before.drop(["product"], axis=1)

# %%
df_before = df_before.dropna()

# %% [markdown]
# ### We can use PCA to represent all of our features in three aggregated features:

# %%
pca = PCA(n_components=3)
pca_result = pca.fit_transform(df_before)

df_before['pca-one'] = pca_result[:,0]
df_before['pca-two'] = pca_result[:,1] 
df_before['pca-three'] = pca_result[:,2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 2
#       1 pca = PCA(n_components=3)
# ----> 2 pca_result = pca.fit_transform(df_before)
#       4 df_before['pca-one'] = pca_result[:,0]
#       5 df_before['pca-two'] = pca_result[:,1]
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:376, in PCA.fit_transform(self, X, y)
#     354 def fit_transform(self, X, y=None):
#     355     """Fit the model with X and apply the dimensionality reduction on X.
#     356
#     357     Parameters
#    (...)
#     374     C-ordered array, use 'np.ascontiguousarray'.
#     375     """
# --> 376     U, S, V = self._fit(X)
#     377     U = U[:, :self.n_components_]
#     379     if self.whiten:
#     380         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:397, in PCA._fit(self, X)
#     393 if issparse(X):
#     394     raise TypeError('PCA does not support sparse input. See '
#     395                     'TruncatedSVD for a possible alternative.')
# --> 397 X = self._validate_data(X, dtype=[np.float64, np.float32],
#     398                         ensure_2d=True, copy=self.copy)
#     400 # Handle n_components==None
#     401 if self.n_components is None:
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/base.py:420, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     415     if self._get_tags()['requires_y']:
#     416         raise ValueError(
#     417             f"This {self.__class__.__name__} estimator "
#     418             f"requires y to be passed, but the target y is None."
#     419         )
# --> 420     X = check_array(X, **check_params)
#     421     out = X
#     422 else:
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:650, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     648     n_samples = _num_samples(array)
#     649     if n_samples < ensure_min_samples:
# --> 650         raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     651                          " minimum of %d is required%s."
#     652                          % (n_samples, array.shape, ensure_min_samples,
#     653                             context))
#     655 if ensure_min_features > 0 and array.ndim == 2:
#     656     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 10)) while a minimum of 1 is required.

# %%
ax = plt.figure(figsize=(12,12)).gca(projection='3d')
chart = ax.scatter(
   xs=df_before["pca-one"], 
   ys=df_before["pca-two"], 
   zs=df_before["pca-three"], 
   c=df_before["product_encoded"], 
   cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')

ax.legend(*chart.legend_elements())
plt.show()

# %% [markdown]
# ## Let's try imputing some missing values:

# %%
df["atp_last"] = df["atp_last"].fillna(method="backfill")

# %%
df["attended_last"] = df["attended_last"].fillna(method="backfill")
df["events_last"] = df["events_last"].fillna(method="backfill")

# %%
df["opens"] = df["opens"].fillna(method="backfill")
df["sends"] = df["sends"].fillna(method="backfill")

# %% [markdown]
# ## Let's remove some outliers from our data:

# %%
def subset_by_iqr(df, column, whisker_bottom=1.5, whisker_top=1.5):
    # Calculate Q1, Q2 and IQR
    q1 = df[column].quantile(0.25)                 
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    # Apply filter with respect to IQR, including optional whiskers
    filter = (df[column] >= q1 - whisker_bottom*iqr) & (df[column] <= q3 + whisker_top*iqr)
    return df.loc[filter]

# %%
df = subset_by_iqr(df, 'atp_last', 1.0)
df = subset_by_iqr(df, 'spend_current', 1.5, 1.0)
df = subset_by_iqr(df, 'distance', 1.5, 1.5)
df = subset_by_iqr(df, 'opens', 1.5, 1.0)
df = subset_by_iqr(df, 'volume_current', 1.5, 1.0)
df.shape
# Out:
# (0, 11)

# %%
plt.figure(figsize=(15,1))
sns.boxplot(x=df["volume_current"])
plt.show()

# %% [markdown]
# ## Let's resample our data using SMOTE to fix class imbalance on our target variable:

# %%
df = df.dropna()

# %%
df["product"].value_counts()
# Out:
# Series([], Name: product, dtype: int64)

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(df.drop(["product"], axis=1), df["product"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 2
#       1 sm = SMOTE(random_state=42)
# ----> 2 X_res, y_res = sm.fit_resample(df.drop(["product"], axis=1), df["product"])
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/imblearn/base.py:77, in SamplerMixin.fit_resample(self, X, y)
#      75 check_classification_targets(y)
#      76 arrays_transformer = ArraysTransformer(X, y)
# ---> 77 X, y, binarize_y = self._check_X_y(X, y)
#      79 self.sampling_strategy_ = check_sampling_strategy(
#      80     self.sampling_strategy, y, self._sampling_type
#      81 )
#      83 output = self._fit_resample(X, y)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/imblearn/base.py:134, in BaseSampler._check_X_y(self, X, y, accept_sparse)
#     132     accept_sparse = ["csr", "csc"]
#     133 y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 134 X, y = self._validate_data(
#     135     X, y, reset=True, accept_sparse=accept_sparse
#     136 )
#     137 return X, y, binarize_y
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/base.py:432, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     430         y = check_array(y, **check_y_params)
#     431     else:
# --> 432         X, y = check_X_y(X, y, **check_params)
#     433     out = X, y
#     435 if check_params.get('ensure_2d', True):
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:795, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     792 if y is None:
#     793     raise ValueError("y cannot be None")
# --> 795 X = check_array(X, accept_sparse=accept_sparse,
#     796                 accept_large_sparse=accept_large_sparse,
#     797                 dtype=dtype, order=order, copy=copy,
#     798                 force_all_finite=force_all_finite,
#     799                 ensure_2d=ensure_2d, allow_nd=allow_nd,
#     800                 ensure_min_samples=ensure_min_samples,
#     801                 ensure_min_features=ensure_min_features,
#     802                 estimator=estimator)
#     803 if multi_output:
#     804     y = check_array(y, accept_sparse='csr', force_all_finite=True,
#     805                     ensure_2d=False, dtype=None)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/opt/miniconda3/envs/pycaret_conda/lib/python3.8/site-packages/sklearn/utils/validation.py:650, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     648     n_samples = _num_samples(array)
#     649     if n_samples < ensure_min_samples:
# --> 650         raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     651                          " minimum of %d is required%s."
#     652                          % (n_samples, array.shape, ensure_min_samples,
#     653                             context))
#     655 if ensure_min_features > 0 and array.ndim == 2:
#     656     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 10)) while a minimum of 1 is required.

# %%
df = X_res
df["product"] = y_res

# %%
df.head()
# Out:
#    atp_last  attended_last  distance  events_last  spend_current  sends  \
# 0     40.40            8.0      6.89          9.0         913.82    9.0
# 1     82.97            7.0     19.16          9.0        1493.46    9.0
# 2     82.97            7.0     19.16          9.0        1536.66    9.0
# 3     65.72            9.0     19.87          9.0        1182.96    9.0
# 4     65.72            9.0     19.87          9.0        1216.80    9.0
#
#    tenure  opens  volume_current  product_encoded      product
# 0       2    9.0              20                1  Full Season
# 1       1    0.0              18                1  Full Season
# 2       2    0.0              18                1  Full Season
# 3       1    0.0              18                1  Full Season
# 4       2    0.0              18                1  Full Season

# %%
df.shape
# Out:
# (14598, 11)

# %% [markdown]
# ## Let's check the datatypes infered by Pandas to see if they are correct:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14598 entries, 0 to 14597
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   atp_last         14598 non-null  float64
#  1   attended_last    14598 non-null  float64
#  2   distance         14598 non-null  float64
#  3   events_last      14598 non-null  float64
#  4   spend_current    14598 non-null  float64
#  5   sends            14598 non-null  float64
#  6   tenure           14598 non-null  int64
#  7   opens            14598 non-null  float64
#  8   volume_current   14598 non-null  int64
#  9   product_encoded  14598 non-null  int8
#  10  product          14598 non-null  object
# dtypes: float64(7), int64(2), int8(1), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Let's visualize the dimensionality of our dataset:

# %%
df["product_encoded"] = df["product"].astype("category").cat.codes
df = df.drop(["product"], axis=1)

# %%
pca = PCA(n_components=3)
pca_result = pca.fit_transform(df)

df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1] 
df['pca-three'] = pca_result[:,2]

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
chart = ax.scatter(
    xs=df["pca-one"], 
    ys=df["pca-two"], 
    zs=df["pca-three"], 
    c=df["product_encoded"], 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')

ax.legend(*chart.legend_elements())
plt.show()

# %% [markdown]
# ### We have reduced the dimensionality of our dataset quite a bit and the vector space required to capture each data point is much smaller.

# %% [markdown]
# # Done
