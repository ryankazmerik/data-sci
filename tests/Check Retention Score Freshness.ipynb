# %% [markdown]
# # Check Retention Score Freshness
# * StelllarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * Apr 30, 2022

# %%
import boto3 
import json
import pandas as pd
import psycopg2
import pytz

from datetime import datetime, timedelta
from shared_utilities import helpers

# %%
! aws sso login --profile Stellaralgo-DataScienceAdmin
# Out:
# Attempting to automatically open the SSO authorization page in your default browser.
# If the browser does not open or you wish to use a different device to authorize this request, open the following URL:
#
# https://device.sso.us-east-1.amazonaws.com/
#
# Then enter the code:
#
# VNTB-QTJC
# Successfully logged into Start URL: https://stellaralgo.awsapps.com/start#/

# %%
session = boto3.setup_default_session(profile_name='Stellaralgo-DataScienceAdmin')

# %% [markdown]
# ### Let's create a list of team db's that we'd like to check for fresh scores:

# %%
teams = json.load(open('../config/teamsconfig.json'))

results = []
for team in teams:

    cnxn = helpers.get_redshift_connection(team['cluster'], team['dbname'])
    cursor = cnxn.cursor()

    sql = f"""
        SELECT count(*), lkupclientid, MAX(scoredate) as max_score_date
        FROM {team['dbname'].lower()}.dw.customerretentionscores 
        WHERE lkupclientid = {team['lkupclientid']}
        GROUP BY lkupclientid
    """

    cursor.execute(sql)

    df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])
    df["cluster"] = team["cluster"]
    df["dbname"] = team["dbname"]
    df["lkupclientid"] = team["lkupclientid"]
    df["name"] = team["name"]
    
    if len(df) > 0:
        results.append(df)
    else:
        print(f" > NO RETENTION SCORES FOUND FOR: {team['name']} - {team['clientcode']} ({team['lkupclientid']})")

df_results = pd.concat(results)

df_results["count"] = pd.to_numeric(df_results["count"])
df_results["max_score_date"] = pd.to_datetime(df_results["max_score_date"])

df_results.shape
# Out:
# (38, 6)

# %% [markdown]
# ### Now we can loop through each datatbase, connect to it and check the retention scores:

# %%
today = datetime.now(pytz.timezone("MST")).strftime("%Y-%m-%d")

days_to_sub = 0
target_day = (datetime.today() - timedelta(days_to_sub)).strftime("%Y-%m-%d")

df_stale = df_results[df_results["max_score_date"] < target_day]
df_stale = df_stale.sort_values(by='name')

print(f"STALE TEAMS: {len(df_stale)}")
print(f"TARGET DAY: {target_day}")
df_stale
# Out:
# STALE TEAMS: 38
# TARGET DAY: 2022-08-29
#      count  lkupclientid max_score_date        cluster              dbname  \
# 0   623356            55     2022-08-28       prod-app         stlrcoyotes
# 0  1216705            36     2022-08-28       prod-app          stlrflames
# 0   379094            37     2022-08-28       prod-app             stlrwhl
# 0   793813             8     2022-08-28       prod-app             stlrnll
# 0  1369225            35     2022-08-28       prod-app             stlrcfl
# 0   162562            28     2022-08-28       prod-app            stlrmilb
# 0  1785094            11     2022-08-28       prod-app            stlrmilb
# 0   396345            30     2022-08-28       prod-app            stlrmilb
# 0    72334            99     2022-08-28  prod-app-elbu   stlrusllocomotive
# 0    61215            96     2022-08-28  prod-app-elbu  stlrechleverblades
# 0   830183            93     2022-08-28       prod-app     stlrnhlpanthers
# 0   342115            20     2022-08-28       prod-app            stlrmilb
# 0   544121            48     2022-08-28       prod-app            stlrmilb
# 0   238299            49     2022-08-28       prod-app            stlrmilb
# 0   194577            44     2022-08-28       prod-app            stlrmilb
# 0   376360             9     2022-08-28       prod-app            stlrmilb
# 0  1242487            13     2022-08-28       prod-app             stlrmls
# 0   139968            19     2022-08-28       prod-app            stlrmilb
# 0    82153            51     2022-08-28       prod-app            stlrmilb
# 0  2333141             6     2022-08-28       prod-app             stlrmls
# 0   886202            15     2022-08-28       prod-app            stlrmilb
# 0  1141488            33     2022-08-28       prod-app             stlrvgk
# 0    31855            26     2022-08-28       prod-app            stlrmilb
# 0   645774            16     2022-08-28       prod-app             stlrahl
# 0   855873            47     2022-08-28       prod-app            stlrmilb
# 0   177882            43     2022-08-28       prod-app            stlrmilb
# 0    86953           100     2022-08-28  prod-app-elbu     stlrmilbseadogs
# 0  1295392             5     2022-08-28       prod-app    stlrtrailblazers
# 0   742984            40     2022-08-28       prod-app            stlrmilb
# 0   330223            34     2022-08-28       prod-app            stlrmilb
# 0  1231207            31     2022-08-28       prod-app             stlrmls
# 0   439792            12     2022-08-28       prod-app            stlrmilb
# 0   566657            45     2022-08-28       prod-app            stlrrays
# 0   233589            59     2022-08-28       prod-app            stlrmilb
# 0   700438            52     2022-08-28       prod-app             stlrahl
# 0   109127            56     2022-08-28       prod-app             stlrahl
# 0  1162064             7     2022-08-28       prod-app         stlrcanucks
# 0    63730            98     2022-08-28  prod-app-elbu   stlrmilbwindsurge
#
#                        name
# 0           Arizona Coyotes
# 0            Calgary Flames
# 0            Calgary Hitmen
# 0        Calgary Roughnecks
# 0        Calgary Stampeders
# 0        Columbia Fireflies
# 0              Durham Bulls
# 0        El Paso Chihauhaus
# 0        El Paso Locomotive
# 0        Florida Everblades
# 0          Florida Panthers
# 0         Great Lakes Loons
# 0          Greenville Drive
# 0         Gwinnett Stripers
# 0       Hartford Yard Goats
# 0            Hillsboro Hops
# 0            Houston Dynamo
# 0       Inland Empire 66ers
# 0       Kane County Cougars
# 0                 LA Galaxy
# 0        Las Vegas Aviators
# 0  Las Vegas Golden Knights
# 0         Lexington Legends
# 0        Milwaukee Admirals
# 0     Oklahoma City Dodgers
# 0       Omaha Storm Chasers
# 0         Portland Sea Dogs
# 0    Portland Trail Blazers
# 0                 Reno Aces
# 0        Round Rock Express
# 0       Sacramento Republic
# 0     Sacramento River Cats
# 0            Tampa Bay Rays
# 0           Toledo Mud Hens
# 0            Toledo Walleye
# 0       Tuscon Road Runners
# 0         Vancouver Canucks
# 0         Wichita WindSurge

# %% [markdown]
# ### Done
