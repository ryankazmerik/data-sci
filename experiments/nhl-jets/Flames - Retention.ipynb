# %% [markdown]
# # Flames - Feature Selection
# * StellarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * October 8, 2021

# %% [markdown]
# ## Hypothesis
# Two very important components of a machine learning model are feature selection and feature engineering. Our idea is that adding some more features to the StellarAlgo retention model could improve performance of the model. This notebook will test the standard features used by the StellarAlgo retention model.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import pyodbc
import pandas as pd
import warnings
import matplotlib.pyplot as plt

from pycaret.classification import *

warnings.filterwarnings('ignore')
# Out:
# /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
# connect to SQL Server.
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)

# %%
lkupclientid = 36 # flames

cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrFlames].[ds].[getRetentionScoringModelData] {lkupclientid}"""
)

df = pd.read_sql(storedProc, CNXN)

CNXN.commit()
cursor.close()

df.shape
# Out:
# (39050, 53)

# %% [markdown]
# ### In order to compare two sets of features, we need to create some datasets for training and evalution:

# %%
# choose the features for the stellar base retention model
features = [
    "dimCustomerMasterId",
    "attendancePercent",
    "clickToOpenRatio", 
    "clickToSendRatio",
    "distToVenue",
    "lkupClientId",
    "inperson_contact",
    "isNextYear_Buyer",
    "missed_games_1",
    "missed_games_2",
    "missed_games_over_2",
    "openToSendRatio",
    "productGrouping",
    "recency",
    "renewedBeforeDays",
    "source_tenure",
    "totalSpent",
    "year"
]

# choose the features & train year & test year
df = df[features]
df["year"] = pd.to_numeric(df["year"])

df_train = df.loc[df["year"] <= 2019]
df_train = df_train.sample(frac=0.95, random_state=786).reset_index(drop=True)

df_eval = df.drop(df_train.index).reset_index(drop=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (31856, 17)
# Unseen Data For Predictions: (7194, 17)

# %%
df_train.head()
# Out:
#    dimCustomerMasterId  attendancePercent  clickToOpenRatio  clickToSendRatio  \
# 0               138159             0.1250          0.000000          0.000000
# 1               215977             1.0250          0.000000          0.000000
# 2            275693945             0.2875          0.000000          0.000000
# 3               300185             0.0000          0.000000          0.000000
# 4               283533             0.7625          0.618182          0.149123
#
#    distToVenue  inperson_contact  isNextYear_Buyer  missed_games_1  \
# 0        16.35                 0                 1               0
# 1        10.39                 0                 1               0
# 2        18.83                 0                 1               3
# 3        21.96                 0                 1               0
# 4        10.39                 0                 1               7
#
#    missed_games_2  missed_games_over_2  openToSendRatio productGrouping  \
# 0               0                    4         0.000000     Full Season
# 1               0                    0         0.375000     Full Season
# 2               4                    3         0.000000     Full Season
# 3               0                    1         0.000000     Full Season
# 4               2                    0         0.241228     Full Season
#
#    recency  renewedBeforeDays  source_tenure  totalSpent  year
# 0       24                153           7300     2408.44  2018
# 1        0                164          14235    11903.96  2017
# 2        1                249           9855    15889.78  2016
# 3        0                249           7300     5674.28  2016
# 4        0                159           2190     2231.16  2018

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.80,
    data_split_shuffle=True,
    ignore_features=[
        "dimCustomerMasterId",
        "productGrouping",
        "year"
    ],
    silent=True,
    verbose=False,
    numeric_features=[
        "attendancePercent",
        "distToVenue",
        "missed_games_1",
        "missed_games_2",
        "missed_games_over_2",
        "recency",
        "renewedBeforeDays",
        "source_tenure",
        "totalSpent"
    ]
);

# %%
model_matrix = compare_models(
    fold=10,
    exclude=["lda","qda"]
)
# Out:
# <style type="text/css">
# #T_75807 th {
#   text-align: left;
# }
# #T_75807_row0_col0, #T_75807_row0_col3, #T_75807_row0_col4, #T_75807_row0_col6, #T_75807_row1_col0, #T_75807_row1_col1, #T_75807_row1_col2, #T_75807_row1_col3, #T_75807_row1_col5, #T_75807_row1_col7, #T_75807_row2_col0, #T_75807_row2_col1, #T_75807_row2_col2, #T_75807_row2_col3, #T_75807_row2_col4, #T_75807_row2_col5, #T_75807_row2_col6, #T_75807_row2_col7, #T_75807_row3_col0, #T_75807_row3_col1, #T_75807_row3_col2, #T_75807_row3_col3, #T_75807_row3_col4, #T_75807_row3_col5, #T_75807_row3_col6, #T_75807_row3_col7, #T_75807_row4_col0, #T_75807_row4_col1, #T_75807_row4_col2, #T_75807_row4_col3, #T_75807_row4_col4, #T_75807_row4_col5, #T_75807_row4_col6, #T_75807_row4_col7, #T_75807_row5_col0, #T_75807_row5_col1, #T_75807_row5_col2, #T_75807_row5_col3, #T_75807_row5_col4, #T_75807_row5_col5, #T_75807_row5_col6, #T_75807_row5_col7, #T_75807_row6_col0, #T_75807_row6_col1, #T_75807_row6_col2, #T_75807_row6_col3, #T_75807_row6_col4, #T_75807_row6_col5, #T_75807_row6_col6, #T_75807_row6_col7, #T_75807_row7_col0, #T_75807_row7_col1, #T_75807_row7_col2, #T_75807_row7_col3, #T_75807_row7_col4, #T_75807_row7_col5, #T_75807_row7_col6, #T_75807_row7_col7, #T_75807_row8_col0, #T_75807_row8_col1, #T_75807_row8_col2, #T_75807_row8_col3, #T_75807_row8_col4, #T_75807_row8_col5, #T_75807_row8_col6, #T_75807_row8_col7, #T_75807_row9_col0, #T_75807_row9_col1, #T_75807_row9_col2, #T_75807_row9_col3, #T_75807_row9_col4, #T_75807_row9_col5, #T_75807_row9_col6, #T_75807_row9_col7, #T_75807_row10_col0, #T_75807_row10_col1, #T_75807_row10_col2, #T_75807_row10_col4, #T_75807_row10_col5, #T_75807_row10_col6, #T_75807_row10_col7, #T_75807_row11_col0, #T_75807_row11_col1, #T_75807_row11_col2, #T_75807_row11_col3, #T_75807_row11_col4, #T_75807_row11_col5, #T_75807_row11_col6, #T_75807_row11_col7, #T_75807_row12_col0, #T_75807_row12_col1, #T_75807_row12_col2, #T_75807_row12_col3, #T_75807_row12_col4, #T_75807_row12_col5, #T_75807_row12_col6, #T_75807_row12_col7 {
#   text-align: left;
# }
# #T_75807_row0_col1, #T_75807_row0_col2, #T_75807_row0_col5, #T_75807_row0_col7, #T_75807_row1_col4, #T_75807_row1_col6, #T_75807_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_75807_row0_col8, #T_75807_row1_col8, #T_75807_row2_col8, #T_75807_row3_col8, #T_75807_row4_col8, #T_75807_row5_col8, #T_75807_row6_col8, #T_75807_row7_col8, #T_75807_row8_col8, #T_75807_row9_col8, #T_75807_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_75807_row10_col8, #T_75807_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_75807">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75807_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75807_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_75807_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_75807_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_75807_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_75807_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_75807_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_75807_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_75807_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75807_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_75807_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75807_row0_col1" class="data row0 col1" >0.9108</td>
#       <td id="T_75807_row0_col2" class="data row0 col2" >0.9321</td>
#       <td id="T_75807_row0_col3" class="data row0 col3" >0.9756</td>
#       <td id="T_75807_row0_col4" class="data row0 col4" >0.9041</td>
#       <td id="T_75807_row0_col5" class="data row0 col5" >0.9385</td>
#       <td id="T_75807_row0_col6" class="data row0 col6" >0.7776</td>
#       <td id="T_75807_row0_col7" class="data row0 col7" >0.7851</td>
#       <td id="T_75807_row0_col8" class="data row0 col8" >0.8910</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_75807_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_75807_row1_col1" class="data row1 col1" >0.9107</td>
#       <td id="T_75807_row1_col2" class="data row1 col2" >0.9305</td>
#       <td id="T_75807_row1_col3" class="data row1 col3" >0.9723</td>
#       <td id="T_75807_row1_col4" class="data row1 col4" >0.9063</td>
#       <td id="T_75807_row1_col5" class="data row1 col5" >0.9382</td>
#       <td id="T_75807_row1_col6" class="data row1 col6" >0.7781</td>
#       <td id="T_75807_row1_col7" class="data row1 col7" >0.7844</td>
#       <td id="T_75807_row1_col8" class="data row1 col8" >0.7440</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_75807_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_75807_row2_col1" class="data row2 col1" >0.9034</td>
#       <td id="T_75807_row2_col2" class="data row2 col2" >0.9280</td>
#       <td id="T_75807_row2_col3" class="data row2 col3" >0.9757</td>
#       <td id="T_75807_row2_col4" class="data row2 col4" >0.8951</td>
#       <td id="T_75807_row2_col5" class="data row2 col5" >0.9336</td>
#       <td id="T_75807_row2_col6" class="data row2 col6" >0.7570</td>
#       <td id="T_75807_row2_col7" class="data row2 col7" >0.7667</td>
#       <td id="T_75807_row2_col8" class="data row2 col8" >0.3700</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_75807_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_75807_row3_col1" class="data row3 col1" >0.9033</td>
#       <td id="T_75807_row3_col2" class="data row3 col2" >0.9243</td>
#       <td id="T_75807_row3_col3" class="data row3 col3" >0.9686</td>
#       <td id="T_75807_row3_col4" class="data row3 col4" >0.9002</td>
#       <td id="T_75807_row3_col5" class="data row3 col5" >0.9332</td>
#       <td id="T_75807_row3_col6" class="data row3 col6" >0.7593</td>
#       <td id="T_75807_row3_col7" class="data row3 col7" >0.7660</td>
#       <td id="T_75807_row3_col8" class="data row3 col8" >0.4080</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_75807_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_75807_row4_col1" class="data row4 col1" >0.8938</td>
#       <td id="T_75807_row4_col2" class="data row4 col2" >0.9204</td>
#       <td id="T_75807_row4_col3" class="data row4 col3" >0.9730</td>
#       <td id="T_75807_row4_col4" class="data row4 col4" >0.8858</td>
#       <td id="T_75807_row4_col5" class="data row4 col5" >0.9274</td>
#       <td id="T_75807_row4_col6" class="data row4 col6" >0.7314</td>
#       <td id="T_75807_row4_col7" class="data row4 col7" >0.7428</td>
#       <td id="T_75807_row4_col8" class="data row4 col8" >0.1340</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_75807_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_75807_row5_col1" class="data row5 col1" >0.8856</td>
#       <td id="T_75807_row5_col2" class="data row5 col2" >0.9122</td>
#       <td id="T_75807_row5_col3" class="data row5 col3" >0.9475</td>
#       <td id="T_75807_row5_col4" class="data row5 col4" >0.8946</td>
#       <td id="T_75807_row5_col5" class="data row5 col5" >0.9203</td>
#       <td id="T_75807_row5_col6" class="data row5 col6" >0.7184</td>
#       <td id="T_75807_row5_col7" class="data row5 col7" >0.7221</td>
#       <td id="T_75807_row5_col8" class="data row5 col8" >0.3920</td>
#     </tr>
#     <tr>
#       <th id="T_75807_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_758

# %% [markdown]
# ### The top model is performing well, so let's compare it against our unseen evaluation dataset:

# %%
best_model = create_model(model_matrix)
tuned_model = tune_model(best_model, optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_3ccba_row10_col0, #T_3ccba_row10_col1, #T_3ccba_row10_col2, #T_3ccba_row10_col3, #T_3ccba_row10_col4, #T_3ccba_row10_col5, #T_3ccba_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3ccba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ccba_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3ccba_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3ccba_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3ccba_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3ccba_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3ccba_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3ccba_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ccba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ccba_row0_col0" class="data row0 col0" >0.9090</td>
#       <td id="T_3ccba_row0_col1" class="data row0 col1" >0.9259</td>
#       <td id="T_3ccba_row0_col2" class="data row0 col2" >0.9769</td>
#       <td id="T_3ccba_row0_col3" class="data row0 col3" >0.9008</td>
#       <td id="T_3ccba_row0_col4" class="data row0 col4" >0.9373</td>
#       <td id="T_3ccba_row0_col5" class="data row0 col5" >0.7721</td>
#       <td id="T_3ccba_row0_col6" class="data row0 col6" >0.7807</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ccba_row1_col0" class="data row1 col0" >0.9117</td>
#       <td id="T_3ccba_row1_col1" class="data row1 col1" >0.9322</td>
#       <td id="T_3ccba_row1_col2" class="data row1 col2" >0.9718</td>
#       <td id="T_3ccba_row1_col3" class="data row1 col3" >0.9079</td>
#       <td id="T_3ccba_row1_col4" class="data row1 col4" >0.9388</td>
#       <td id="T_3ccba_row1_col5" class="data row1 col5" >0.7811</td>
#       <td id="T_3ccba_row1_col6" class="data row1 col6" >0.7870</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ccba_row2_col0" class="data row2 col0" >0.8972</td>
#       <td id="T_3ccba_row2_col1" class="data row2 col1" >0.9128</td>
#       <td id="T_3ccba_row2_col2" class="data row2 col2" >0.9685</td>
#       <td id="T_3ccba_row2_col3" class="data row2 col3" >0.8930</td>
#       <td id="T_3ccba_row2_col4" class="data row2 col4" >0.9292</td>
#       <td id="T_3ccba_row2_col5" class="data row2 col5" >0.7427</td>
#       <td id="T_3ccba_row2_col6" class="data row2 col6" >0.7509</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ccba_row3_col0" class="data row3 col0" >0.9074</td>
#       <td id="T_3ccba_row3_col1" class="data row3 col1" >0.9272</td>
#       <td id="T_3ccba_row3_col2" class="data row3 col2" >0.9764</td>
#       <td id="T_3ccba_row3_col3" class="data row3 col3" >0.8994</td>
#       <td id="T_3ccba_row3_col4" class="data row3 col4" >0.9363</td>
#       <td id="T_3ccba_row3_col5" class="data row3 col5" >0.7680</td>
#       <td id="T_3ccba_row3_col6" class="data row3 col6" >0.7767</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ccba_row4_col0" class="data row4 col0" >0.9125</td>
#       <td id="T_3ccba_row4_col1" class="data row4 col1" >0.9335</td>
#       <td id="T_3ccba_row4_col2" class="data row4 col2" >0.9752</td>
#       <td id="T_3ccba_row4_col3" class="data row4 col3" >0.9063</td>
#       <td id="T_3ccba_row4_col4" class="data row4 col4" >0.9395</td>
#       <td id="T_3ccba_row4_col5" class="data row4 col5" >0.7820</td>
#       <td id="T_3ccba_row4_col6" class="data row4 col6" >0.7889</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ccba_row5_col0" class="data row5 col0" >0.9031</td>
#       <td id="T_3ccba_row5_col1" class="data row5 col1" >0.9277</td>
#       <td id="T_3ccba_row5_col2" class="data row5 col2" >0.9702</td>
#       <td id="T_3ccba_row5_col3" class="data row5 col3" >0.8988</td>
#       <td id="T_3ccba_row5_col4" class="data row5 col4" >0.9331</td>
#       <td id="T_3ccba_row5_col5" class="data row5 col5" >0.7580</td>
#       <td id="T_3ccba_row5_col6" class="data row5 col6" >0.7653</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ccba_row6_col0" class="data row6 col0" >0.9105</td>
#       <td id="T_3ccba_row6_col1" class="data row6 col1" >0.9431</td>
#       <td id="T_3ccba_row6_col2" class="data row6 col2" >0.9741</td>
#       <td id="T_3ccba_row6_col3" class="data row6 col3" >0.9048</td>
#       <td id="T_3ccba_row6_col4" class="data row6 col4" >0.9382</td>
#       <td id="T_3ccba_row6_col5" class="data row6 col5" >0.7770</td>
#       <td id="T_3ccba_row6_col6" class="data row6 col6" >0.7840</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ccba_row7_col0" class="data row7 col0" >0.9105</td>
#       <td id="T_3ccba_row7_col1" class="data row7 col1" >0.9380</td>
#       <td id="T_3ccba_row7_col2" class="data row7 col2" >0.9713</td>
#       <td id="T_3ccba_row7_col3" class="data row7 col3" >0.9069</td>
#       <td id="T_3ccba_row7_col4" class="data row7 col4" >0.9380</td>
#       <td id="T_3ccba_row7_col5" class="data row7 col5" >0.7781</td>
#       <td id="T_3ccba_row7_col6" class="data row7 col6" >0.7840</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ccba_row8_col0" class="data row8 col0" >0.9109</td>
#       <td id="T_3ccba_row8_col1" class="data row8 col1" >0.9365</td>
#       <td id="T_3ccba_row8_col2" class="data row8 col2" >0.9673</td>
#       <td id="T_3ccba_row8_col3" class="data row8 col3" >0.9104</td>
#       <td id="T_3ccba_row8_col4" class="data row8 col4" >0.9380</td>
#       <td id="T_3ccba_row8_col5" class="data row8 col5" >0.7803</td>
#       <td id="T_3ccba_row8_col6" class="data row8 col6" >0.7849</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ccba_row9_col0" class="data row9 col0" >0.9144</td>
#       <td id="T_3ccba_row9_col1" class="data row9 col1" >0.9405</td>
#       <td id="T_3ccba_row9_col2" class="data row9 col2" >0.9746</td>
#       <td id="T_3ccba_row9_col3" class="data row9 col3" >0.9091</td>
#       <td id="T_3ccba_row9_col4" class="data row9 col4" >0.9407</td>
#       <td id="T_3ccba_row9_col5" class="data row9 col5" >0.7877</td>
#       <td id="T_3ccba_row9_col6" class="data row9 col6" >0.7939</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3ccba_row10_col0" class="data row10 col0" >0.9087</td>
#       <td id="T_3ccba_row10_col1" class="data row10 col1" >0.9318</td>
#       <td id="T_3ccba_row10_col2" class="data row10 col2" >0.9726</td>
#       <td id="T_3ccba_row10_col3" class="data row10 col3" >0.9038</td>
#       <td id="T_3ccba_row10_col4" class="data row10 col4" >0.9369</td>
#       <td id="T_3ccba_row10_col5" class="data row10 col5" >0.7727</td>
#       <td id="T_3ccba_row10_col6" class="data row10 col6" >0.7796</td>
#     </tr>
#     <tr>
#       <th id="T_3ccba_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3ccba_row11_col0" class="data row11 col0" >0.0048</td>
#       <td id="T_3ccba_row11_col1" class="data row11 col1" >0.0084</td>
#       <td id="T_3ccba_row11_col2" class="data row11 col2" >0.0031</td>
#       <td id="T_3ccba_row11_col3" class="data row11 col3" >0.0052</td>
#       <td id="T_3ccba_row11_col4

# %% [markdown]
# ### Let's plot the features to see what attributes were the most important to an accurate prediction

# %%
plot_model(tuned_model, plot='feature')

# %%
plot_model(tuned_model, plot='confusion_matrix')

# %%
plot_model(tuned_model, plot='auc')

# %%
unseen_predictions = predict_model(tuned_model, raw_score=True)

unseen_predictions
print(unseen_predictions['Label'].value_counts())
unseen_predictions['Score_1'].value_counts(bins=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5cd63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cd63_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5cd63_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5cd63_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5cd63_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5cd63_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5cd63_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5cd63_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5cd63_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cd63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cd63_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5cd63_row0_col1" class="data row0 col1" >0.9069</td>
#       <td id="T_5cd63_row0_col2" class="data row0 col2" >0.9301</td>
#       <td id="T_5cd63_row0_col3" class="data row0 col3" >0.9779</td>
#       <td id="T_5cd63_row0_col4" class="data row0 col4" >0.8975</td>
#       <td id="T_5cd63_row0_col5" class="data row0 col5" >0.9360</td>
#       <td id="T_5cd63_row0_col6" class="data row0 col6" >0.7669</td>
#       <td id="T_5cd63_row0_col7" class="data row0 col7" >0.7764</td>
#     </tr>
#   </tbody>
# </table>
# 1    4828
# 0    1544
# Name: Label, dtype: int64
# (0.742, 0.988]      4384
# (0.00372, 0.251]    1327
# (0.497, 0.742]       445
# (0.251, 0.497]       216
# Name: Score_1, dtype: int64

# %%
unseen_predictions.head()
# Out:
#    attendancePercent  clickToOpenRatio  clickToSendRatio  distToVenue  \
# 0             0.1250          0.000000          0.000000    25.440001
# 1             0.9250          0.125000          0.176471    21.959999
# 2             0.3750          0.073171          0.027523    10.390000
# 3             0.0000          0.000000          0.000000     3.670000
# 4             0.8625          0.000000          0.000000     5.260000
#
#    missed_games_1  missed_games_2  missed_games_over_2  openToSendRatio  \
# 0             0.0             0.0                  3.0         0.000000
# 1             4.0             0.0                  0.0         1.411765
# 2             4.0             3.0                  3.0         0.376147
# 3             0.0             0.0                  1.0         0.000000
# 4             5.0             1.0                  0.0         0.388889
#
#    recency  renewedBeforeDays  source_tenure    totalSpent  \
# 0      7.0              117.0         7300.0   5359.200195
# 1      0.0              249.0         6205.0   5674.279785
# 2      0.0              115.0         6205.0  12572.679688
# 3      0.0               49.0         6205.0    816.320007
# 4      0.0              141.0         6570.0   9116.919922
#
#    inperson_contact_0  isNextYear_Buyer  Label  Score_0  Score_1
# 0                 1.0                 0      0   0.9905   0.0095
# 1                 1.0                 1      1   0.0365   0.9635
# 2                 1.0                 1      1   0.1204   0.8796
# 3                 1.0                 1      1   0.2978   0.7022
# 4                 1.0                 1      1   0.0478   0.9522

# %%
plt.hist(unseen_predictions["Score_1"], bins=50)

plt.show()
