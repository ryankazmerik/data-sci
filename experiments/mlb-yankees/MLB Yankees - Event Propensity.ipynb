# %% [markdown]
# # Yankees - Event Propensity - Next Event Buyer
# * Ryan Kazmerik, Nakisa Rad, Joey Lai, Shawn Sutherland, Matt Bahler, Pat Faith
# * Feb 09, 2022

# %% [markdown]
# ## Hypothesis
# Each team has different tier (or quality) of games, based on day of the week, time of the season, opponent, etc. We think that by using previous buyer behaviour we can make a prediction on whether the fan will purchase for the next game or not.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import matplotlib.pyplot as plt
import pyodbc
import pandas as pd
import warnings

from pandas_profiling import ProfileReport
from pycaret.classification import *

warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
# connect to SQL Server.
SERVER = '54.164.224.129'  
DATABASE = 'stlrRays' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password ··························

# %%
cursor = CNXN.cursor()

query = "SELECT * FROM datascience.yankees.event_propensity_training_noFirstPurchases2"
    
df = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266386 entries, 0 to 266385
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   daysOut              266386 non-null  object
#  1   minDaysOut           266386 non-null  int64
#  2   maxDaysOut           147819 non-null  float64
#  3   dimCustomerMasterId  266386 non-null  int64
#  4   recent_openRate      266386 non-null  float64
#  5   recent_clickRate     266386 non-null  float64
#  6   eventDate            266386 non-null  datetime64[ns]
#  7   eventName            266386 non-null  object
#  8   inMarket             242800 non-null  object
#  9   distanceToVenue      242800 non-null  float64
#  10  tenure               266386 non-null  int64
#  11  did_purchase         266386 non-null  int64
#  12  events_purchased     266386 non-null  int64
#  13  frequency_opponent   266386 non-null  float64
#  14  frequency_eventDay   266386 non-null  float64
#  15  frequency_eventTime  266386 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(3)
# memory usage: 32.5+ MB

# %% [markdown]
# ### We should create separate out some data for training the model and some for evaluating:

# %%
# copy your main dataframe
df_dataset = df

df_train = df_dataset.sample(frac=0.85, random_state=786)
df_eval = df_dataset.drop(df_train.index)

df_train.reset_index(drop=True)
df_eval.reset_index(drop=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (226428, 16)
# Unseen Data For Predictions: (39958, 16)

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the target field to see how likely a customer is to purchase:

# %%
setup(
    data= df_train, 
    target="did_purchase", 
    train_size = 0.80,
    data_split_shuffle=True,
    categorical_features=["inMarket"],
    date_features=["eventDate"],
    ignore_features=[
        "dimCustomerMasterId",
        "eventName",
        "minDaysOut",
        "maxDaysOut"
    ],
    silent=True,
    verbose=False,
    numeric_features=[
        "distanceToVenue",
        "events_purchased",
        "frequency_eventDay",
        "frequency_opponent",
        "frequency_eventTime",
        "recent_clickRate",
        "recent_openRate",
        "tenure"
    ]
);

# %%
model_matrix = compare_models(
    fold= 10, 
    include= ["lr"]
)
# Out:
# <style  type="text/css" >
#     #T_95421_ th {
#           text-align: left;
#     }#T_95421_row0_col0{
#             text-align:  left;
#             text-align:  left;
#         }#T_95421_row0_col1,#T_95421_row0_col2,#T_95421_row0_col3,#T_95421_row0_col4,#T_95421_row0_col5,#T_95421_row0_col6,#T_95421_row0_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_95421_row0_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_95421_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95421_level0_row0" class="row_heading level0 row0" >lr</th>
#                         <td id="T_95421_row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_95421_row0_col1" class="data row0 col1" >0.8020</td>
#                         <td id="T_95421_row0_col2" class="data row0 col2" >0.8789</td>
#                         <td id="T_95421_row0_col3" class="data row0 col3" >0.7847</td>
#                         <td id="T_95421_row0_col4" class="data row0 col4" >0.8126</td>
#                         <td id="T_95421_row0_col5" class="data row0 col5" >0.7984</td>
#                         <td id="T_95421_row0_col6" class="data row0 col6" >0.6040</td>
#                         <td id="T_95421_row0_col7" class="data row0 col7" >0.6044</td>
#                         <td id="T_95421_row0_col8" class="data row0 col8" >4.4390</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### The top model is performing well, so let's compare it against our test dataset:

# %%
best_model = create_model(
    model_matrix, 
    fold= 10
)
# Out:
# <style  type="text/css" >
# #T_f5113_row10_col0,#T_f5113_row10_col1,#T_f5113_row10_col2,#T_f5113_row10_col3,#T_f5113_row10_col4,#T_f5113_row10_col5,#T_f5113_row10_col6{
#             background:  yellow;
#         }</style><table id="T_f5113_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5113_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f5113_row0_col0" class="data row0 col0" >0.8025</td>
#                         <td id="T_f5113_row0_col1" class="data row0 col1" >0.8790</td>
#                         <td id="T_f5113_row0_col2" class="data row0 col2" >0.7847</td>
#                         <td id="T_f5113_row0_col3" class="data row0 col3" >0.8135</td>
#                         <td id="T_f5113_row0_col4" class="data row0 col4" >0.7988</td>
#                         <td id="T_f5113_row0_col5" class="data row0 col5" >0.6051</td>
#                         <td id="T_f5113_row0_col6" class="data row0 col6" >0.6054</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f5113_row1_col0" class="data row1 col0" >0.7966</td>
#                         <td id="T_f5113_row1_col1" class="data row1 col1" >0.8775</td>
#                         <td id="T_f5113_row1_col2" class="data row1 col2" >0.7735</td>
#                         <td id="T_f5113_row1_col3" class="data row1 col3" >0.8107</td>
#                         <td id="T_f5113_row1_col4" class="data row1 col4" >0.7917</td>
#                         <td id="T_f5113_row1_col5" class="data row1 col5" >0.5931</td>
#                         <td id="T_f5113_row1_col6" class="data row1 col6" >0.5938</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f5113_row2_col0" class="data row2 col0" >0.8022</td>
#                         <td id="T_f5113_row2_col1" class="data row2 col1" >0.8786</td>
#                         <td id="T_f5113_row2_col2" class="data row2 col2" >0.7827</td>
#                         <td id="T_f5113_row2_col3" class="data row2 col3" >0.8142</td>
#                         <td id="T_f5113_row2_col4" class="data row2 col4" >0.7981</td>
#                         <td id="T_f5113_row2_col5" class="data row2 col5" >0.6044</td>
#                         <td id="T_f5113_row2_col6" class="data row2 col6" >0.6048</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f5113_row3_col0" class="data row3 col0" >0.8023</td>
#                         <td id="T_f5113_row3_col1" class="data row3 col1" >0.8762</td>
#                         <td id="T_f5113_row3_col2" class="data row3 col2" >0.7910</td>
#                         <td id="T_f5113_row3_col3" class="data row3 col3" >0.8089</td>
#                         <td id="T_f5113_row3_col4" class="data row3 col4" >0.7999</td>
#                         <td id="T_f5113_row3_col5" class="data row3 col5" >0.6045</td>
#                         <td id="T_f5113_row3_col6" class="data row3 col6" >0.6046</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f5113_row4_col0" class="data row4 col0" >0.8026</td>
#                         <td id="T_f5113_row4_col1" class="data row4 col1" >0.8796</td>
#                         <td id="T_f5113_row4_col2" class="data row4 col2" >0.7877</td>
#                         <td id="T_f5113_row4_col3" class="data row4 col3" >0.8117</td>
#                         <td id="T_f5113_row4_col4" class="data row4 col4" >0.7995</td>
#                         <td id="T_f5113_row4_col5" class="data row4 col5" >0.6053</td>
#                         <td id="T_f5113_row4_col6" class="data row4 col6" >0.6055</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f5113_row5_col0" class="data row5 col0" >0.8035</td>
#                         <td id="T_f5113_row5_col1" class="data row5 col1" >0.8817</td>
#                         <td id="T_f5113_row5_col2" class="data row5 col2" >0.7884</td>
#                         <td id="T_f5113_row5_col3" class="data row5 col3" >0.8127</td>
#                         <td id="T_f5113_row5_col4" class="data row5 col4" >0.8004</td>
#                         <td id="T_f5113_row5_col5" class="data row5 col5" >0.6069</td>
#                         <td id="T_f5113_row5_col6" class="data row5 col6" >0.6072</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f5113_row6_col0" class="data row6 col0" >0.8051</td>
#                         <td id="T_f5113_row6_col1" class="data row6 col1" >0.8810</td>
#                         <td id="T_f5113_row6_col2" class="data row6 col2" >0.7865</td>
#                         <td id="T_f5113_row6_col3" class="data row6 col3" >0.8166</td>
#                         <td id="T_f5113_row6_col4" class="data row6 col4" >0.8013</td>
#                         <td id="T_f5113_row6_col5" class="data row6 col5" >0.6101</td>
#                         <td id="T_f5113_row6_col6" class="data row6 col6" >0.6105</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f5113_row7_col0" class="data row7 col0" >0.8037</td>
#                         <td id="T_f5113_row7_col1" class="data row7 col1" >0.8793</td>
#                         <td id="T_f5113_row7_col2" class="data row7 col2" >0.7804</td>
#                         <td id="T_f5113_row7_col3" class="data row7 col3" >0.8183</td>
#                         <td id="T_f5113_row7_col4" class="data row7 col4" >0.7989</td>
#                         <td id="T_f5113_row7_col5" class="data row7 col5" >0.6074</td>
#                         <td id="T_f5113_row7_col6" class="data row7 col6" >0.6080</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f5113_row8_col0" class="data row8 col0" >0.7998</td>
#                         <td id="T_f5113_row8_col1" class="data row8 col1" >0.8780</td>
#                         <td id="T_f5113_row8_col2" class="data row8 col2" >0.7863</td>
#                         <td id="T_f5113_row8_col3" class="data row8 col3" >0.8078</td>
#                         <td id="T_f5113_row8_col4" class="data row8 col4" >0.7969</td>
#                         <td id="T_f5113_row8_col5" class="data row8 col5" >0.5995</td>
#                         <td id="T_f5113_row8_col6" class="data row8 col6" >0.5997</td>
#             </tr>
#             <tr>
#                         <th id="T_f5113_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f5113_row9_col0" class="data row9 col0" >0.8018</td>
#                         <td id="T_f5113_row9_col1" class="data row9 col1" >0.8783</td>
#                         <td id="T_f5113_row9_col2" class="data row9 col2" >0.7853</td>
#                         <td id="T_f5113_row9_col3" class="data row9 col3" >0.8118</td>
#                         <td id="T_f5113_row9_col4" class="data row9 col4" >0.7983</td>
#                         <td id="T_f5113_row9_col5" class="data row9 col5" >0.6035</td>
#                         <td id=

# %% [markdown]
# ### Let's load in our evaluation data and get propensity scores using the model:

# %%
df_inference = predict_model(best_model, data=df_eval, raw_score=True)
df_inference.head()
# Out:
#             daysOut  minDaysOut  maxDaysOut  dimCustomerMasterId  \
# 3   1 to 3 Days Out           1         4.0                 1488
# 8   1 to 3 Days Out           1         4.0                 1980
# 13  1 to 3 Days Out           1         4.0                 3071
# 29  1 to 3 Days Out           1         4.0                 8115
# 37  1 to 3 Days Out           1         4.0                10753
#
#     recent_openRate  recent_clickRate  eventDate  \
# 3              0.00               0.0 2019-08-03
# 8              0.25               0.0 2017-09-30
# 13             0.00               0.0 2021-05-05
# 29             0.00               0.0 2018-05-09
# 37             0.00               0.0 2017-06-08
#
#                        eventName inMarket  distanceToVenue  tenure  \
# 3      20190803 - Boston Red Sox     True            50.53     122
# 8   20170930 - Toronto Blue Jays     True            85.07     177
# 13     20210505 - Houston Astros     True            31.05    1387
# 29     20180509 - Boston Red Sox     True            23.24     350
# 37     20170608 - Boston Red Sox     True            25.47     106
#
#     did_purchase  events_purchased  frequency_opponent  frequency_eventDay  \
# 3              0                52            0.000000            0.000000
# 8              1                77            0.285714            0.545455
# 13             0               219            0.000000            0.000000
# 29             1                78            0.181818            0.000000
# 37             0                26            0.000000            0.000000
#
#     frequency_eventTime  Label  Score_0  Score_1
# 3              0.000000      0   0.6961   0.3039
# 8              0.428571      1   0.0024   0.9976
# 13             0.000000      0   0.8540   0.1460
# 29             0.113636      1   0.3124   0.6876
# 37             0.000000      0   0.7404   0.2596

# %% [markdown]
# ### Included are some metrics on did and did_not purchase:

# %%
did_purchase = df_inference["Label"].value_counts()[1]
did_not_purchase = df_inference["Label"].value_counts()[0]
total_rows = df_inference["Label"].count()
purchase_percentage = round((did_purchase / total_rows), 2) * 100

print("Would purchase:", did_purchase)
print("Would not purchase:", did_not_purchase)
print("Purchase percentage:", purchase_percentage)
# Out:
# Would purchase: 19354
# Would not purchase: 20604
# Purchase percentage: 48.0

# %% [markdown]
# ### We can also see the correlation between the features and the target variable:

# %%
cor = df.corr()

df_correlated = df

corr = df_correlated.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_95143_row0_col0,#T_95143_row1_col1,#T_95143_row2_col2,#T_95143_row3_col3,#T_95143_row4_col4,#T_95143_row5_col5,#T_95143_row6_col6,#T_95143_row7_col7,#T_95143_row8_col8,#T_95143_row9_col9,#T_95143_row10_col10,#T_95143_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_95143_row0_col1,#T_95143_row1_col0{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_95143_row0_col2,#T_95143_row3_col10{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_95143_row0_col3,#T_95143_row0_col4,#T_95143_row1_col9,#T_95143_row3_col0,#T_95143_row5_col2,#T_95143_row5_col7,#T_95143_row6_col10,#T_95143_row6_col11,#T_95143_row7_col5,#T_95143_row11_col1,#T_95143_row11_col6,#T_95143_row11_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_95143_row0_col5,#T_95143_row10_col5,#T_95143_row11_col5{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_95143_row0_col6,#T_95143_row1_col7,#T_95143_row3_col5,#T_95143_row4_col9,#T_95143_row7_col3{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_95143_row0_col7{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_95143_row0_col8,#T_95143_row8_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_95143_row0_col9,#T_95143_row2_col4,#T_95143_row11_col4{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_95143_row0_col10,#T_95143_row5_col8{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_95143_row0_col11,#T_95143_row7_col8,#T_95143_row9_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_95143_row1_col2,#T_95143_row4_col1{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_95143_row1_col3,#T_95143_row9_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_95143_row1_col4,#T_95143_row10_col6{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_95143_row1_col5,#T_95143_row6_col1{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_95143_row1_col6,#T_95143_row2_col8{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_95143_row1_col8{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_95143_row1_col10,#T_95143_row6_col0{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_95143_row1_col11,#T_95143_row10_col1{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_95143_row2_col0,#T_95143_row4_col10,#T_95143_row8_col2{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_95143_row2_col1,#T_95143_row5_col1{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_95143_row2_col3,#T_95143_row3_col4{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_95143_row2_col5,#T_95143_row5_col10,#T_95143_row7_col6,#T_95143_row10_col4{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_95143_row2_col6,#T_95143_row10_col2{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_95143_row2_col7,#T_95143_row10_col9{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_95143_row2_col9,#T_95143_row4_col7{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_95143_row2_col10,#T_95143_row3_col11{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_95143_row2_col11{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_95143_row3_col1{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_95143_row3_col2,#T_95143_row3_col9,#T_95143_row6_col5{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_95143_row3_col6,#T_95143_row4_col5,#T_95143_row6_col2,#T_95143_row9_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_95143_row3_col7{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_95143_row3_col8,#T_95143_row4_col8,#T_95143_row8_col7{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_95143_row4_col0,#T_95143_row10_col8{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_95143_row4_col2{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_95143_row4_col3{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_95143_row4_col6{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_95143_row4_col11{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_95143_row5_col0{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_95143_row5_col3{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_95143_row5_col4,#T_95143_row8_col4{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_95143_row5_col6{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_95143_row5_col9{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_95143_row5_col11,#T_95143_row7_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_95143_row6_col3{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_95143_row6_col4,#T_95143_row6_col9{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_95143_row6_col7,#T_95143_row9_col4{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_95143_row6_col8,#T_95143_row8_col6{
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }#T_95143_row7_col0,#T_95143_row7_col11{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_95143_row7_col1,#T_95143_row8_col0,#T_95143_row10_col0{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_95143_row7_col2{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_95143_row7_col9{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_95143_row7_col10{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_95143_row8_col3{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_95143_row8_col5{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_95143_row8_col9{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_95143_row8_col10{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_95143_row8_col11,#T_95143_row9_col1{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_95143_row9_col2{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_95143_row9_col6,#T_95143_row9_col8{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_95143_row9_col7{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_95143_row9_col10{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_95143_row9_col11{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_95143_row10_col3{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_95143_row10_col7,#T_95143_row11_col7{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_95143_row10_col11{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }#T_95143_row11_col0{
#             background-color:  #465ecf;
#             colo

# %% [markdown]
# ### Here we can see the distribution of fans who did and did not purchase : Score_0 = Did Not Purchase, Score_1 = Did Purchase

# %%
df_inference.hist(column=['Score_0', 'Score_1'], figsize=(30,5), layout=(1,3));

# %% [markdown]
# ### This plot lists the most important features for a correct prediction (either Score_0 or Score_1) in the model:

# %%
plot_model(best_model, plot='feature')

# %% [markdown]
# ### This confusion matrix helps understand where the model guessed correctly or incorrectly based on the evaluation data:

# %%
plot_model(best_model, plot='confusion_matrix')

# %% [markdown]
# ### The AUC curve tells how much the model is capable of distinguishing between classes. The higher the curve, the better the model is at distiguishing classes:

# %%
plot_model(best_model, plot='auc')

# %% [markdown]
# ### Let's load up some real events from previous events to see how the model scores the data:

# %%
cursor = CNXN.cursor()

query = """
    SELECT
        daysOut,
        dimCustomerMasterId,
        eventDate,
        events_purchased,
        frequency_opponent,
        frequency_eventDay,
        frequency_eventTime,
        inMarket,
        distanceToVenue,
        recent_openRate,
        recent_clickRate,
        tenure
    FROM 
        DataScience.yankees.event_propensity_scoring_20190330
"""
    
df_prev_scores = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

# %%
df_prev_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648764 entries, 0 to 1648763
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   daysOut              1648764 non-null  object
#  1   dimCustomerMasterId  1648764 non-null  int64
#  2   eventDate            1648764 non-null  datetime64[ns]
#  3   events_purchased     1648764 non-null  float64
#  4   frequency_opponent   1648764 non-null  float64
#  5   frequency_eventDay   1647368 non-null  float64
#  6   frequency_eventTime  1648764 non-null  float64
#  7   inMarket             1406432 non-null  object
#  8   distanceToVenue      1406432 non-null  float64
#  9   recent_openRate      415456 non-null   float64
#  10  recent_clickRate     415456 non-null   float64
#  11  tenure               1648764 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 150.9+ MB

# %% [markdown]
# ### Let's run the previous scores through the model for predictions:

# %%
df_scoring = predict_model(best_model, data=df_prev_scores, raw_score=True)
df_scoring.head()
# Out:
#            daysOut  dimCustomerMasterId  eventDate  events_purchased  \
# 0           Day Of              1671914 2019-03-30               1.0
# 1  1 to 3 Days Out              1671914 2019-03-30               1.0
# 2  4 to 7 Days Out              1671914 2019-03-30               1.0
# 3      Over a Week              1671914 2019-03-30               1.0
# 4           Day Of              1732044 2019-03-30               2.0
#
#    frequency_opponent  frequency_eventDay  frequency_eventTime inMarket  \
# 0                 0.0                 0.0             0.022222     True
# 1                 0.0                 0.0             0.022222     True
# 2                 0.0                 0.0             0.022222     True
# 3                 0.0                 0.0             0.022222     True
# 4                 0.0                 0.0             0.000000     True
#
#    distanceToVenue  recent_openRate  recent_clickRate  tenure  Label  Score_0  \
# 0            31.58              NaN               NaN     599      0   0.9033
# 1            31.58              NaN               NaN     599      0   0.8740
# 2            31.58              NaN               NaN     599      0   0.8799
# 3            31.58              NaN               NaN     599      0   0.5789
# 4            18.70              0.0               0.0     601      0   0.9216
#
#    Score_1
# 0   0.0967
# 1   0.1260
# 2   0.1201
# 3   0.4211
# 4   0.0784

# %% [markdown]
# ### Included are some metrics on did and did_not purchase:

# %%
did_purchase = df_scoring["Label"].value_counts()[1]
did_not_purchase = df_scoring["Label"].value_counts()[0]
total_rows = df_scoring["Label"].count()
purchase_percentage = round((did_purchase / total_rows), 4) * 100

print("Would purchase:", did_purchase)
print("Would not purchase:", did_not_purchase)
print("Purchase percentage:", purchase_percentage)
# Out:
# Would purchase: 173047
# Would not purchase: 1475717
# Purchase percentage: 10.5

# %% [markdown]
# ### We can also see the correlation between the features and the target variable:

# %%
cor2 = df_scoring.corr()

df_correlated2 = df_scoring

corr2 = df_correlated2.corr()
corr2.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e0ad7_row0_col0,#T_e0ad7_row1_col1,#T_e0ad7_row2_col2,#T_e0ad7_row3_col3,#T_e0ad7_row4_col4,#T_e0ad7_row5_col5,#T_e0ad7_row6_col6,#T_e0ad7_row7_col7,#T_e0ad7_row8_col8,#T_e0ad7_row9_col9,#T_e0ad7_row10_col10,#T_e0ad7_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e0ad7_row0_col1{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_e0ad7_row0_col2,#T_e0ad7_row0_col3,#T_e0ad7_row3_col10,#T_e0ad7_row6_col8{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_e0ad7_row0_col4{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_e0ad7_row0_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_e0ad7_row0_col6{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_e0ad7_row0_col7,#T_e0ad7_row6_col3{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_e0ad7_row0_col8{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_e0ad7_row0_col9{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_e0ad7_row0_col10{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_e0ad7_row0_col11,#T_e0ad7_row11_col2{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_e0ad7_row1_col0,#T_e0ad7_row4_col6{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_e0ad7_row1_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_e0ad7_row1_col3{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_e0ad7_row1_col4,#T_e0ad7_row9_col2,#T_e0ad7_row9_col3,#T_e0ad7_row11_col7{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_e0ad7_row1_col5,#T_e0ad7_row3_col8,#T_e0ad7_row5_col6{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_e0ad7_row1_col6,#T_e0ad7_row7_col2,#T_e0ad7_row7_col3,#T_e0ad7_row7_col8,#T_e0ad7_row8_col11,#T_e0ad7_row11_col1{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_e0ad7_row1_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_e0ad7_row1_col8{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_e0ad7_row1_col9{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_e0ad7_row1_col10{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_e0ad7_row1_col11{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_e0ad7_row2_col0{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_e0ad7_row2_col1,#T_e0ad7_row6_col4{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_e0ad7_row2_col3{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_e0ad7_row2_col4{
#             background-color:  #f7a98b;
#             color:  #000000;
#         }#T_e0ad7_row2_col5{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_e0ad7_row2_col6,#T_e0ad7_row3_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_e0ad7_row2_col7,#T_e0ad7_row4_col7,#T_e0ad7_row4_col10{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_e0ad7_row2_col8,#T_e0ad7_row8_col5{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_e0ad7_row2_col9{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_e0ad7_row2_col10,#T_e0ad7_row6_col2{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_e0ad7_row2_col11{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_e0ad7_row3_col0,#T_e0ad7_row9_col5{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_e0ad7_row3_col1{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_e0ad7_row3_col2{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_e0ad7_row3_col4{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_e0ad7_row3_col5,#T_e0ad7_row5_col7{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_e0ad7_row3_col7{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_e0ad7_row3_col9,#T_e0ad7_row6_col11,#T_e0ad7_row11_col4{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_e0ad7_row3_col11{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_e0ad7_row4_col0,#T_e0ad7_row8_col0{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_e0ad7_row4_col1{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_e0ad7_row4_col2{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_e0ad7_row4_col3{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_e0ad7_row4_col5,#T_e0ad7_row6_col5,#T_e0ad7_row8_col6{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_e0ad7_row4_col8{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_e0ad7_row4_col9{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_e0ad7_row4_col11{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_e0ad7_row5_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_e0ad7_row5_col1{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_e0ad7_row5_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_e0ad7_row5_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_e0ad7_row5_col4,#T_e0ad7_row8_col9{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_e0ad7_row5_col8,#T_e0ad7_row8_col1{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_e0ad7_row5_col9{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_e0ad7_row5_col10{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_e0ad7_row5_col11{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_e0ad7_row6_col0,#T_e0ad7_row7_col1{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_e0ad7_row6_col1,#T_e0ad7_row8_col7,#T_e0ad7_row9_col1{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_e0ad7_row6_col7{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_e0ad7_row6_col9{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_e0ad7_row6_col10{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_e0ad7_row7_col0{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_e0ad7_row7_col4,#T_e0ad7_row7_col10,#T_e0ad7_row9_col6{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_e0ad7_row7_col5,#T_e0ad7_row8_col2{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_e0ad7_row7_col6{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_e0ad7_row7_col9{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_e0ad7_row7_col11{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_e0ad7_row8_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_e0ad7_row8_col4{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_e0ad7_row8_col10{
#             background-color:  #f7aa8c;
#             color:

# %% [markdown]
# ### Here we can see the distribution of fans who did and did not purchase : Score_0 = Did Not Purchase, Score_1 = Did Purchase

# %%
df_scoring.hist(column=['Score_0', 'Score_1'], figsize=(30,5), layout=(1,3));

# %%
scoring_list = df_scoring.to_dict('records')

# %%
max_dict = {}
for record in scoring_list:
    if record['dimCustomerMasterId'] not in max_dict:
        max_dict[record['dimCustomerMasterId']] = 0
    
    if record['Score_1'] > max_dict[record['dimCustomerMasterId']]:
        max_dict[record['dimCustomerMasterId']] = record['Score_1']

# %%
#max_scores = [{'id': k, 'score': v} for k, v in max_dict.items()]
#max_scores.sort(key = lambda v: -v["score"])

#df_max_scores = pd.DataFrame(max_scores)
#df_max_scores.to_csv('yankees_scoring_test.csv')
# Out:
# (412191, 2)

# %%
df_max_scores.head()
# Out:
#         id  score
# 0  1193100    1.0
# 1     8588    1.0
# 2  1715715    1.0
# 3  1836298    1.0
# 4    24188    1.0

# %%
#df1 = df_scoring.loc[df_scoring.groupby('dimCustomerMasterId', sort=False)['Score_1'].idxmax()]

# %%
#df1 = df1.sort_values(by='Score_1', ascending=False).reset_index()

# %%
#df1 = df1.filter(['dimCustomerMasterId','Score_1'], axis=1)

# %%
#df1.head()

# %% [markdown]
# ## Observations
# Here you can talk about next steps, did the experiment work? If yes, what to do next? If no, why?
