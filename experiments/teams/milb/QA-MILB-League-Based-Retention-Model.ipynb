# %% [markdown]
# # MILB League Based Retention Model (QA)
#
# * Stellar Algo
# * Nakiska Rad & Ryan Kazmerik
# * August 31, 2021

# %%
import getpass
import pyodbc
import pandas as pd

from pycaret.classification import *
from pycaret.utils import check_metric
from shared_utilities import helpers

# %% [markdown]
# ## Let's get our dataset from MSSQL. We will select the full season product only and seasons before 2020, since 2020 was a strange year due to covid, and 2021 does not have any repurchasing data available

# %%
CNXN = helpers.get_mssql_connection("QA")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# /Users/ryankazmerik/Git/data-sci/notebooks/experiments/milb/QA-MILB-League-Based-Retention-Model.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryankazmerik/Git/data-sci/notebooks/experiments/milb/QA-MILB-League-Based-Retention-Model.ipynb#ch0000003?line=0'>1</a> CNXN = helpers.get_mssql_connection("QA")
#       <a href='vscode-notebook-cell:/Users/ryankazmerik/Git/data-sci/notebooks/experiments/milb/QA-MILB-League-Based-Retention-Model.ipynb#ch0000003?line=1'>2</a> CNXN
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py:23, in get_mssql_connection(environment)
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=19'>20</a>     serv = "34.206.73.189"
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=21'>22</a> ssm_client = boto3.client("ssm", "us-east-1")
# ---> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=22'>23</a> response = ssm_client.get_parameter(
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=23'>24</a>     Name=f"/product/ai/notebook/db-connections/{env}",
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=24'>25</a>     WithDecryption=True,
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=25'>26</a> )["Parameter"]["Value"]
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=26'>27</a> sql_connection = json.loads(response)
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=28'>29</a> cnxn = pyodbc.connect(
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=29'>30</a>     "DRIVER={ODBC Driver 17 for SQL Server}"
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=30'>31</a>     + ";SERVER="+serv
#    (...)
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=33'>34</a>     + ";PWD="+sql_connection["password"]
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/shared_utilities/helpers.py?line=34'>35</a> )
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py:395, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=391'>392</a>     raise TypeError(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=392'>393</a>         "%s() only accepts keyword arguments." % py_operation_name)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=393'>394</a> # The "self" in this scope is referring to the BaseClient.
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=394'>395</a> return self._make_api_call(operation_name, kwargs)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py:711, in BaseClient._make_api_call(self, operation_name, api_params)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=708'>709</a> else:
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=709'>710</a>     apply_request_checksum(request_dict)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=710'>711</a>     http, parsed_response = self._make_request(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=711'>712</a>         operation_model, request_dict, request_context)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=713'>714</a> self.meta.events.emit(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=714'>715</a>     'after-call.{service_id}.{operation_name}'.format(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=715'>716</a>         service_id=service_id,
#    (...)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=718'>719</a>     model=operation_model, context=request_context
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=719'>720</a> )
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=721'>722</a> if http.status_code >= 300:
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py:731, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=728'>729</a> def _make_request(self, operation_model, request_dict, request_context):
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=729'>730</a>     try:
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=730'>731</a>         return self._endpoint.make_request(operation_model, request_dict)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=731'>732</a>     except Exception as e:
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=732'>733</a>         self.meta.events.emit(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=733'>734</a>             'after-call-error.{service_id}.{operation_name}'.format(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=734'>735</a>                 service_id=self._service_model.service_id.hyphenize(),
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=735'>736</a>                 operation_name=operation_model.name),
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=736'>737</a>             exception=e, context=request_context
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/client.py?line=737'>738</a>         )
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py:107, in Endpoint.make_request(self, operation_model, request_dict)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=103'>104</a> def make_request(self, operation_model, request_dict):
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=104'>105</a>     logger.debug("Making request for %s with params: %s",
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=105'>106</a>                  operation_model, request_dict)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=106'>107</a>     return self._send_request(request_dict, operation_model)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py:180, in Endpoint._send_request(self, request_dict, operation_model)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=177'>178</a> context = request_dict['context']
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=178'>179</a> self._update_retries_context(context, attempts)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=179'>180</a> request = self.create_request(request_dict, operation_model)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=180'>181</a> success_response, exception = self._get_response(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=181'>182</a>     request, operation_model, context)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=182'>183</a> while self._needs_retry(attempts, operation_model, request_dict,
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=183'>184</a>                         success_response, exception):
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py:120, in Endpoint.create_request(self, params, operation_model)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=115'>116</a>     service_id = operation_model.service_model.service_id.hyphenize()
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=116'>117</a>     event_name = 'request-created.{service_id}.{op_name}'.format(
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=117'>118</a>         service_id=service_id,
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=118'>119</a>         op_name=operation_model.name)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=119'>120</a>     self._event_emitter.emit(event_name, request=request,
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=120'>121</a>                              operation_name=operation_model.name)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=121'>122</a> prepared_request = self.prepare_request(request)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/endpoint.py?line=122'>123</a> return prepared_request
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py:357, in EventAliaser.emit(self, event_name, **kwargs)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=354'>355</a> def emit(self, event_name, **kwargs):
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=355'>356</a>     aliased_event_name = self._alias_event_name(event_name)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=356'>357</a>     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py:228, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=216'>217</a> def emit(self, event_name, **kwargs):
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=217'>218</a>     """
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=218'>219</a>     Emit an event by name with arguments passed as keyword args.
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=219'>220</a>
#    (...)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=225'>226</a>              handlers.
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=226'>227</a>     """
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=227'>228</a>     return self._emit(event_name, kwargs)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py:211, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=208'>209</a> for handler in handlers_to_call:
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=209'>210</a>     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=210'>211</a>     response = handler(**kwargs)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=211'>212</a>     responses.append((handler, response))
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/hooks.py?line=212'>213</a>     if stop_on_response and response is not None:
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py:93, in RequestSigner.handler(self, operation_name, request, **kwargs)
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=87'>88</a> def handler(self, operation_name=None, request=None, **kwargs):
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=88'>89</a>     # This is typically hooked up to the "request-created" event
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=89'>90</a>     # from a client's event emitter.  When a new request is created
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=90'>91</a>     # this method is invoked to sign the request.
#      <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=91'>92</a>     # Don't call this method directly.
# ---> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=92'>93</a>     return self.sign(operation_name, request)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py:165, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=161'>162</a>     else:
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=162'>163</a>         raise e
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/signers.py?line=164'>165</a> auth.add_auth(request)
#
# File /opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py:388, in SigV4Auth.add_auth(self, request)
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py?line=385'>386</a> def add_auth(self, request):
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py?line=386'>387</a>     if self.credentials is None:
# --> <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py?line=387'>388</a>         raise NoCredentialsError()
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py?line=388'>389</a>     datetime_now = datetime.datetime.utcnow()
#     <a href='file:///opt/miniconda3/envs/stellar/lib/python3.8/site-packages/botocore/auth.py?line=389'>390</a>     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
cursor = CNXN.cursor()

product = "Full Season"
train_season_year = 2019

query =  f"""
    SELECT 
        r.dimcustomermasterid,
        recency,
        attendancePercent,
        totalSpent,
        distToVenue,
        source_tenure,
        renewedBeforeDays,
        missed_games_1,
        missed_games_2,
        missed_games_over_2,
        isnextyear_buyer
    FROM 
        ds.retentionscoring r 
    WHERE 
        lkupclientid in(9,11,12,15,17,19,20,21,24,25,26,27,28,30,34,40,43,44,46,47,48,49,51,59) 
    AND 
        productgrouping = {"'"+ str(product) + "'"} 
    AND 
        year < {train_season_year};
    """
    
df = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16752 entries, 0 to 16751
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dimcustomermasterid  16752 non-null  object
#  1   recency              16752 non-null  int64
#  2   attendancePercent    16752 non-null  object
#  3   totalSpent           16752 non-null  object
#  4   distToVenue          16752 non-null  object
#  5   source_tenure        16752 non-null  int64
#  6   renewedBeforeDays    16752 non-null  int64
#  7   missed_games_1       16752 non-null  int64
#  8   missed_games_2       16752 non-null  int64
#  9   missed_games_over_2  16752 non-null  int64
#  10  isnextyear_buyer     16533 non-null  float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## We have some missing values for our target variable (isnextyear_buyer) so let's fill in those missing values

# %%
df['isnextyear_buyer'] = df['isnextyear_buyer'].fillna(0.0)
df['isnextyear_buyer'] = df['isnextyear_buyer'].round(0).astype(int)
                            
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16752 entries, 0 to 16751
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dimcustomermasterid  16752 non-null  object
#  1   recency              16752 non-null  int64
#  2   attendancePercent    16752 non-null  object
#  3   totalSpent           16752 non-null  object
#  4   distToVenue          16752 non-null  object
#  5   source_tenure        16752 non-null  int64
#  6   renewedBeforeDays    16752 non-null  int64
#  7   missed_games_1       16752 non-null  int64
#  8   missed_games_2       16752 non-null  int64
#  9   missed_games_over_2  16752 non-null  int64
#  10  isnextyear_buyer     16752 non-null  int64
# dtypes: int64(7), object(4)
# memory usage: 1.4+ MB
#   dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 0           303661788        0          0.580986       2485       26.49
# 1           303663474        1          0.527778       4032       23.92
# 2           303659570        0          0.548611     1641.6       24.07
# 3           303658983        3          0.313869     1561.8       18.21
# 4           303659912        0          0.280992     1379.4        5.16
#
#    source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 0           1460                  8               8               8
# 1           1460                198               0               2
# 2           1460                185              14               4
# 3           1460                197               2               2
# 4           1460                202               0               0
#
#    missed_games_over_2  isnextyear_buyer
# 0                    3                 1
# 1                    7                 1
# 2                    3                 1
# 3                    3                 1
# 4                    4                 1

# %% [markdown]
# ## Let's check the balance of our target variable to understand what performance metric will be the best measure of model performance

# %%
df['isnextyear_buyer'].value_counts()
# Out:
# 1    11288
# 0     5464
# Name: isnextyear_buyer, dtype: int64

# %% [markdown]
# ## We need to hold back some samples from the dataset for evalution, so let's create the training and evaluation dataset with a hold-back of 10%.

# %%
df_train = df.sample(frac=0.90, random_state=786).reset_index(drop=True)
df_eval = df.drop(df_train.index).reset_index(drop=True)

print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape))
# Out:
# Data for Modeling: (15077, 11)
# Unseen Data For Predictions: (1675, 11)

# %% [markdown]
# ## Now we can model the data using PyCaret, with a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
model = setup(
    data= df_train, 
    target='isnextyear_buyer', 
    train_size = 0.80,
    data_split_shuffle=True,
    silent=True,
    ignore_features=['dimcustomermasterid'],
    numeric_features=[
        "attendancePercent",
        "distToVenue",
        "missed_games_1",
        "missed_games_2",
        "missed_games_over_2",
        "recency",
        "renewedBeforeDays",
        "source_tenure",
        "totalSpent"
    ]
)
# Out:
# <style  type="text/css" >
# #T_a3055_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_a3055_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3055_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a3055_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a3055_row0_col1" class="data row0 col1" >5921</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a3055_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_a3055_row1_col1" class="data row1 col1" >isnextyear_buyer</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a3055_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_a3055_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a3055_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_a3055_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a3055_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_a3055_row4_col1" class="data row4 col1" >(15077, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a3055_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_a3055_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a3055_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_a3055_row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_a3055_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_a3055_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_a3055_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_a3055_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_a3055_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_a3055_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_a3055_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_a3055_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_a3055_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_a3055_row11_col1" class="data row11 col1" >(12061, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_a3055_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_a3055_row12_col1" class="data row12 col1" >(3016, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_a3055_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_a3055_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_a3055_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_a3055_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_a3055_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_a3055_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_a3055_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_a3055_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_a3055_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_a3055_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_a3055_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_a3055_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_a3055_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_a3055_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_a3055_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_a3055_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_a3055_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_a3055_row21_col1" class="data row21 col1" >2ff8</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_a3055_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_a3055_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_a3055_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_a3055_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_a3055_level0_row24" class="row_heading level0

# %% [markdown]
# ### Let's compare all models to evaluate performance. This function trains all models in the model library and scores them using k-fold cross validation for metric evaluation. The output prints a score grid that shows average Accuracy, AUC, Recall, Precision, F1 and Kappa accross the folds (10 by default) along with training time.

# %%
model_matrix = compare_models(
    fold=10,
    include=["ada","dt","gbc","et","knn","lightgbm","lr","rf","ridge","xgboost"]
)
# Out:
# <style  type="text/css" >
#     #T_40237_ th {
#           text-align: left;
#     }#T_40237_row0_col0,#T_40237_row0_col3,#T_40237_row0_col4,#T_40237_row1_col0,#T_40237_row1_col1,#T_40237_row1_col2,#T_40237_row1_col3,#T_40237_row1_col5,#T_40237_row1_col6,#T_40237_row1_col7,#T_40237_row2_col0,#T_40237_row2_col1,#T_40237_row2_col2,#T_40237_row2_col3,#T_40237_row2_col4,#T_40237_row2_col5,#T_40237_row2_col6,#T_40237_row2_col7,#T_40237_row3_col0,#T_40237_row3_col1,#T_40237_row3_col2,#T_40237_row3_col3,#T_40237_row3_col4,#T_40237_row3_col5,#T_40237_row3_col6,#T_40237_row3_col7,#T_40237_row4_col0,#T_40237_row4_col1,#T_40237_row4_col2,#T_40237_row4_col3,#T_40237_row4_col4,#T_40237_row4_col5,#T_40237_row4_col6,#T_40237_row4_col7,#T_40237_row5_col0,#T_40237_row5_col1,#T_40237_row5_col2,#T_40237_row5_col3,#T_40237_row5_col4,#T_40237_row5_col5,#T_40237_row5_col6,#T_40237_row5_col7,#T_40237_row6_col0,#T_40237_row6_col1,#T_40237_row6_col2,#T_40237_row6_col3,#T_40237_row6_col4,#T_40237_row6_col5,#T_40237_row6_col6,#T_40237_row6_col7,#T_40237_row7_col0,#T_40237_row7_col1,#T_40237_row7_col2,#T_40237_row7_col3,#T_40237_row7_col4,#T_40237_row7_col5,#T_40237_row7_col6,#T_40237_row7_col7,#T_40237_row8_col0,#T_40237_row8_col1,#T_40237_row8_col2,#T_40237_row8_col3,#T_40237_row8_col4,#T_40237_row8_col5,#T_40237_row8_col6,#T_40237_row8_col7,#T_40237_row9_col0,#T_40237_row9_col1,#T_40237_row9_col2,#T_40237_row9_col3,#T_40237_row9_col4,#T_40237_row9_col5,#T_40237_row9_col6,#T_40237_row9_col7,#T_40237_row10_col0,#T_40237_row10_col1,#T_40237_row10_col2,#T_40237_row10_col4,#T_40237_row10_col5,#T_40237_row10_col6,#T_40237_row10_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_40237_row0_col1,#T_40237_row0_col2,#T_40237_row0_col5,#T_40237_row0_col6,#T_40237_row0_col7,#T_40237_row1_col4,#T_40237_row10_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_40237_row0_col8,#T_40237_row1_col8,#T_40237_row2_col8,#T_40237_row3_col8,#T_40237_row4_col8,#T_40237_row5_col8,#T_40237_row6_col8,#T_40237_row7_col8,#T_40237_row8_col8,#T_40237_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_40237_row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_40237_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40237_level0_row0" class="row_heading level0 row0" >5</th>
#                         <td id="T_40237_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_40237_row0_col1" class="data row0 col1" >0.7780</td>
#                         <td id="T_40237_row0_col2" class="data row0 col2" >0.8068</td>
#                         <td id="T_40237_row0_col3" class="data row0 col3" >0.9198</td>
#                         <td id="T_40237_row0_col4" class="data row0 col4" >0.7886</td>
#                         <td id="T_40237_row0_col5" class="data row0 col5" >0.8491</td>
#                         <td id="T_40237_row0_col6" class="data row0 col6" >0.4389</td>
#                         <td id="T_40237_row0_col7" class="data row0 col7" >0.4581</td>
#                         <td id="T_40237_row0_col8" class="data row0 col8" >0.0300</td>
#             </tr>
#             <tr>
#                         <th id="T_40237_level0_row1" class="row_heading level0 row1" >10</th>
#                         <td id="T_40237_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_40237_row1_col1" class="data row1 col1" >0.7712</td>
#                         <td id="T_40237_row1_col2" class="data row1 col2" >0.7978</td>
#                         <td id="T_40237_row1_col3" class="data row1 col3" >0.8980</td>
#                         <td id="T_40237_row1_col4" class="data row1 col4" >0.7927</td>
#                         <td id="T_40237_row1_col5" class="data row1 col5" >0.8420</td>
#                         <td id="T_40237_row1_col6" class="data row1 col6" >0.4332</td>
#                         <td id="T_40237_row1_col7" class="data row1 col7" >0.4446</td>
#                         <td id="T_40237_row1_col8" class="data row1 col8" >0.4310</td>
#             </tr>
#             <tr>
#                         <th id="T_40237_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_40237_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_40237_row2_col1" class="data row2 col1" >0.7698</td>
#                         <td id="T_40237_row2_col2" class="data row2 col2" >0.7996</td>
#                         <td id="T_40237_row2_col3" class="data row2 col3" >0.9348</td>
#                         <td id="T_40237_row2_col4" class="data row2 col4" >0.7735</td>
#                         <td id="T_40237_row2_col5" class="data row2 col5" >0.8465</td>
#                         <td id="T_40237_row2_col6" class="data row2 col6" >0.4027</td>
#                         <td id="T_40237_row2_col7" class="data row2 col7" >0.4332</td>
#                         <td id="T_40237_row2_col8" class="data row2 col8" >0.1500</td>
#             </tr>
#             <tr>
#                         <th id="T_40237_level0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_40237_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#                         <td id="T_40237_row3_col1" class="data row3 col1" >0.7669</td>
#                         <td id="T_40237_row3_col2" class="data row3 col2" >0.7935</td>
#                         <td id="T_40237_row3_col3" class="data row3 col3" >0.9084</td>
#                         <td id="T_40237_row3_col4" class="data row3 col4" >0.7831</td>
#                         <td id="T_40237_row3_col5" class="data row3 col5" >0.8411</td>
#                         <td id="T_40237_row3_col6" class="data row3 col6" >0.4130</td>
#                         <td id="T_40237_row3_col7" class="data row3 col7" >0.4295</td>
#                         <td id="T_40237_row3_col8" class="data row3 col8" >0.2630</td>
#             </tr>
#             <tr>
#                         <th id="T_40237_level0_row4" class="row_heading level0 row4" >9</th>
#                         <td id="T_40237_row4_col0" class="data row4 col0" >NGBClassifier</td>
#                         <td id="T_40237_row4_col1" class="data row4 col1" >0.7621</td>
#                         <td id="T_40237_row4_col2" class="data row4 col2" >0.7820</td>
#                         <td id="T_40237_row4_col3" class="data row4 col3" >0.9441</td>
#                         <td id="T_40237_row4_col4" class="data row4 col4" >0.7623</td>
#                         <td id="T_40237_row4_col5" class="data row4 col5" >0.8435</td>
#                         <td id="T_40237_row4_col6" class="data row4 col6" >0.3707</td>
#                         <td id="T_40237_row4_col7" class="data row4 col7" >0.4104</td>
#                         <td id="T_40237_row4_col8" class="data row4 col8" >2.0350</td>
#             </tr>
#             <tr>
#                         <th id="T_40237_level0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_40237_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#                         <td id="T_40237_row5_col1" class="data row5 col1" >0.7578</td>
#                         <td
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5252 val_loss=0.0000 scale=2.0000 norm=3.7612
# [iter 200] loss=0.5043 val_loss=0.0000 scale=1.0000 norm=1.8844
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8893
# [iter 400] loss=0.4916 val_loss=0.0000 scale=1.0000 norm=1.8925
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5223 val_loss=0.0000 scale=2.0000 norm=3.7558
# [iter 200] loss=0.5022 val_loss=0.0000 scale=1.0000 norm=1.8838
# [iter 300] loss=0.4943 val_loss=0.0000 scale=2.0000 norm=3.7811
# [iter 400] loss=0.4888 val_loss=0.0000 scale=1.0000 norm=1.8933
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5249 val_loss=0.0000 scale=2.0000 norm=3.7622
# [iter 200] loss=0.5031 val_loss=0.0000 scale=1.0000 norm=1.8837
# [iter 300] loss=0.4949 val_loss=0.0000 scale=1.0000 norm=1.8877
# [iter 400] loss=0.4902 val_loss=0.0000 scale=1.0000 norm=1.8917
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5241 val_loss=0.0000 scale=2.0000 norm=3.7578
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8845
# [iter 300] loss=0.4958 val_loss=0.0000 scale=2.0000 norm=3.7805
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8938
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5252 val_loss=0.0000 scale=2.0000 norm=3.7612
# [iter 200] loss=0.5043 val_loss=0.0000 scale=1.0000 norm=1.8844
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8893
# [iter 400] loss=0.4916 val_loss=0.0000 scale=1.0000 norm=1.8925
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5254 val_loss=0.0000 scale=2.0000 norm=3.7598
# [iter 200] loss=0.5049 val_loss=0.0000 scale=1.0000 norm=1.8842
# [iter 300] loss=0.4957 val_loss=0.0000 scale=2.0000 norm=3.7778
# [iter 400] loss=0.4901 val_loss=0.0000 scale=1.0000 norm=1.8949
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5249 val_loss=0.0000 scale=2.0000 norm=3.7622
# [iter 200] loss=0.5031 val_loss=0.0000 scale=1.0000 norm=1.8837
# [iter 300] loss=0.4949 val_loss=0.0000 scale=1.0000 norm=1.8877
# [iter 400] loss=0.4902 val_loss=0.0000 scale=1.0000 norm=1.8917
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.1219e-09): result may not be accurate.
#   overwrite_a=True).T
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5228 val_loss=0.0000 scale=2.0000 norm=3.7594
# [iter 200] loss=0.5029 val_loss=0.0000 scale=1.0000 norm=1.8820
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8887
# [iter 400] loss=0.4917 val_loss=0.0000 scale=1.0000 norm=1.8920
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5249 val_loss=0.0000 scale=2.0000 norm=3.7622
# [iter 200] loss=0.5031 val_loss=0.0000 scale=1.0000 norm=1.8837
# [iter 300] loss=0.4949 val_loss=0.0000 scale=1.0000 norm=1.8877
# [iter 400] loss=0.4902 val_loss=0.0000 scale=1.0000 norm=1.8917
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5252 val_loss=0.0000 scale=2.0000 norm=3.7612
# [iter 200] loss=0.5043 val_loss=0.0000 scale=1.0000 norm=1.8844
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8893
# [iter 400] loss=0.4916 val_loss=0.0000 scale=1.0000 norm=1.8925
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.35447e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5234 val_loss=0.0000 scale=2.0000 norm=3.7562
# [iter 200] loss=0.5050 val_loss=0.0000 scale=1.0000 norm=1.8803
# [iter 300] loss=0.4980 val_loss=0.0000 scale=1.0000 norm=1.8832
# [iter 400] loss=0.4942 val_loss=0.0000 scale=1.0000 norm=1.8870
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5241 val_loss=0.0000 scale=2.0000 norm=3.7578
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8845
# [iter 300] loss=0.4958 val_loss=0.0000 scale=2.0000 norm=3.7805
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8938
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5234 val_loss=0.0000 scale=2.0000 norm=3.7562
# [iter 200] loss=0.5050 val_loss=0.0000 scale=1.0000 norm=1.8803
# [iter 300] loss=0.4980 val_loss=0.0000 scale=1.0000 norm=1.8832
# [iter 400] loss=0.4942 val_loss=0.0000 scale=1.0000 norm=1.8870
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5223 val_loss=0.0000 scale=2.0000 norm=3.7558
# [iter 200] loss=0.5022 val_loss=0.0000 scale=1.0000 norm=1.8838
# [iter 300] loss=0.4943 val_loss=0.0000 scale=2.0000 norm=3.7811
# [iter 400] loss=0.4888 val_loss=0.0000 scale=1.0000 norm=1.8933
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.16069e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5249 val_loss=0.0000 scale=2.0000 norm=3.7622
# [iter 200] loss=0.5031 val_loss=0.0000 scale=1.0000 norm=1.8837
# [iter 300] loss=0.4949 val_loss=0.0000 scale=1.0000 norm=1.8877
# [iter 400] loss=0.4902 val_loss=0.0000 scale=1.0000 norm=1.8917
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5234 val_loss=0.0000 scale=2.0000 norm=3.7562
# [iter 200] loss=0.5050 val_loss=0.0000 scale=1.0000 norm=1.8803
# [iter 300] loss=0.4980 val_loss=0.0000 scale=1.0000 norm=1.8832
# [iter 400] loss=0.4942 val_loss=0.0000 scale=1.0000 norm=1.8870
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5223 val_loss=0.0000 scale=2.0000 norm=3.7558
# [iter 200] loss=0.5022 val_loss=0.0000 scale=1.0000 norm=1.8838
# [iter 300] loss=0.4943 val_loss=0.0000 scale=2.0000 norm=3.7811
# [iter 400] loss=0.4888 val_loss=0.0000 scale=1.0000 norm=1.8933
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5254 val_loss=0.0000 scale=2.0000 norm=3.7598
# [iter 200] loss=0.5049 val_loss=0.0000 scale=1.0000 norm=1.8842
# [iter 300] loss=0.4957 val_loss=0.0000 scale=2.0000 norm=3.7778
# [iter 400] loss=0.4901 val_loss=0.0000 scale=1.0000 norm=1.8949
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5240 val_loss=0.0000 scale=2.0000 norm=3.7602
# [iter 200] loss=0.5044 val_loss=0.0000 scale=1.0000 norm=1.8815
# [iter 300] loss=0.4976 val_loss=0.0000 scale=1.0000 norm=1.8865
# [iter 400] loss=0.4935 val_loss=0.0000 scale=1.0000 norm=1.8914
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5240 val_loss=0.0000 scale=2.0000 norm=3.7602
# [iter 200] loss=0.5044 val_loss=0.0000 scale=1.0000 norm=1.8815
# [iter 300] loss=0.4976 val_loss=0.0000 scale=1.0000 norm=1.8865
# [iter 400] loss=0.4935 val_loss=0.0000 scale=1.0000 norm=1.8914
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5240 val_loss=0.0000 scale=2.0000 norm=3.7602
# [iter 200] loss=0.5044 val_loss=0.0000 scale=1.0000 norm=1.8815
# [iter 300] loss=0.4976 val_loss=0.0000 scale=1.0000 norm=1.8865
# [iter 400] loss=0.4935 val_loss=0.0000 scale=1.0000 norm=1.8914
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5241 val_loss=0.0000 scale=2.0000 norm=3.7578
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8845
# [iter 300] loss=0.4958 val_loss=0.0000 scale=2.0000 norm=3.7805
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8938
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.16484e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.15936e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5254 val_loss=0.0000 scale=2.0000 norm=3.7598
# [iter 200] loss=0.5049 val_loss=0.0000 scale=1.0000 norm=1.8842
# [iter 300] loss=0.4957 val_loss=0.0000 scale=2.0000 norm=3.7778
# [iter 400] loss=0.4901 val_loss=0.0000 scale=1.0000 norm=1.8949
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5216 val_loss=0.0000 scale=2.0000 norm=3.7493
# [iter 200] loss=0.5008 val_loss=0.0000 scale=2.0000 norm=3.7547
# [iter 300] loss=0.4922 val_loss=0.0000 scale=1.0000 norm=1.8835
# [iter 400] loss=0.4884 val_loss=0.0000 scale=2.0000 norm=3.7750
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5234 val_loss=0.0000 scale=2.0000 norm=3.7562
# [iter 200] loss=0.5050 val_loss=0.0000 scale=1.0000 norm=1.8803
# [iter 300] loss=0.4980 val_loss=0.0000 scale=1.0000 norm=1.8832
# [iter 400] loss=0.4942 val_loss=0.0000 scale=1.0000 norm=1.8870
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.1582e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.12596e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5228 val_loss=0.0000 scale=2.0000 norm=3.7594
# [iter 200] loss=0.5029 val_loss=0.0000 scale=1.0000 norm=1.8820
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8887
# [iter 400] loss=0.4917 val_loss=0.0000 scale=1.0000 norm=1.8920
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5246 val_loss=0.0000 scale=2.0000 norm=3.7632
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8848
# [iter 300] loss=0.4968 val_loss=0.0000 scale=1.0000 norm=1.8899
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8930
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5228 val_loss=0.0000 scale=2.0000 norm=3.7594
# [iter 200] loss=0.5029 val_loss=0.0000 scale=1.0000 norm=1.8820
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8887
# [iter 400] loss=0.4917 val_loss=0.0000 scale=1.0000 norm=1.8920
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.27223e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5254 val_loss=0.0000 scale=2.0000 norm=3.7598
# [iter 200] loss=0.5049 val_loss=0.0000 scale=1.0000 norm=1.8842
# [iter 300] loss=0.4957 val_loss=0.0000 scale=2.0000 norm=3.7778
# [iter 400] loss=0.4901 val_loss=0.0000 scale=1.0000 norm=1.8949
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5216 val_loss=0.0000 scale=2.0000 norm=3.7493
# [iter 200] loss=0.5008 val_loss=0.0000 scale=2.0000 norm=3.7547
# [iter 300] loss=0.4922 val_loss=0.0000 scale=1.0000 norm=1.8835
# [iter 400] loss=0.4884 val_loss=0.0000 scale=2.0000 norm=3.7750
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5228 val_loss=0.0000 scale=2.0000 norm=3.7594
# [iter 200] loss=0.5029 val_loss=0.0000 scale=1.0000 norm=1.8820
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8887
# [iter 400] loss=0.4917 val_loss=0.0000 scale=1.0000 norm=1.8920
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5252 val_loss=0.0000 scale=2.0000 norm=3.7612
# [iter 200] loss=0.5043 val_loss=0.0000 scale=1.0000 norm=1.8844
# [iter 300] loss=0.4959 val_loss=0.0000 scale=1.0000 norm=1.8893
# [iter 400] loss=0.4916 val_loss=0.0000 scale=1.0000 norm=1.8925
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5246 val_loss=0.0000 scale=2.0000 norm=3.7632
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8848
# [iter 300] loss=0.4968 val_loss=0.0000 scale=1.0000 norm=1.8899
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8930
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.11113e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [iter 0] loss=0.6277 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5240 val_loss=0.0000 scale=2.0000 norm=3.7602
# [iter 200] loss=0.5044 val_loss=0.0000 scale=1.0000 norm=1.8815
# [iter 300] loss=0.4976 val_loss=0.0000 scale=1.0000 norm=1.8865
# [iter 400] loss=0.4935 val_loss=0.0000 scale=1.0000 norm=1.8914
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5246 val_loss=0.0000 scale=2.0000 norm=3.7632
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8848
# [iter 300] loss=0.4968 val_loss=0.0000 scale=1.0000 norm=1.8899
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8930
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5246 val_loss=0.0000 scale=2.0000 norm=3.7632
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8848
# [iter 300] loss=0.4968 val_loss=0.0000 scale=1.0000 norm=1.8899
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8930
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5241 val_loss=0.0000 scale=2.0000 norm=3.7578
# [iter 200] loss=0.5040 val_loss=0.0000 scale=1.0000 norm=1.8845
# [iter 300] loss=0.4958 val_loss=0.0000 scale=2.0000 norm=3.7805
# [iter 400] loss=0.4920 val_loss=0.0000 scale=1.0000 norm=1.8938
# [iter 0] loss=0.6278 val_loss=0.0000 scale=2.0000 norm=4.0000
# [iter 100] loss=0.5216 val_loss=0.0000 scale=2.0000 norm=3.7493
# [iter 200] loss=0.5008 val_loss=0.0000 scale=2.0000 norm=3.7547
# [iter 300] loss=0.4922 val_loss=0.0000 scale=1.0000 norm=1.8835
# [iter 400] loss=0.4884 val_loss=0.0000 scale=2.0000 norm=3.7750
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.17235e-09): result may not be accurate.
#   overwrite_a=True).T
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ## Now we can create the best model based on performance and train and evaluate the model.

# %%
best_model = create_model(model_matrix)
best_model
# Out:
# <style  type="text/css" >
# #T_932ac_row10_col0,#T_932ac_row10_col1,#T_932ac_row10_col2,#T_932ac_row10_col3,#T_932ac_row10_col4,#T_932ac_row10_col5,#T_932ac_row10_col6{
#             background:  yellow;
#         }</style><table id="T_932ac_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_932ac_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_932ac_row0_col0" class="data row0 col0" >0.7655</td>
#                         <td id="T_932ac_row0_col1" class="data row0 col1" >0.7966</td>
#                         <td id="T_932ac_row0_col2" class="data row0 col2" >0.9231</td>
#                         <td id="T_932ac_row0_col3" class="data row0 col3" >0.7746</td>
#                         <td id="T_932ac_row0_col4" class="data row0 col4" >0.8423</td>
#                         <td id="T_932ac_row0_col5" class="data row0 col5" >0.3985</td>
#                         <td id="T_932ac_row0_col6" class="data row0 col6" >0.4227</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_932ac_row1_col0" class="data row1 col0" >0.7736</td>
#                         <td id="T_932ac_row1_col1" class="data row1 col1" >0.7718</td>
#                         <td id="T_932ac_row1_col2" class="data row1 col2" >0.9182</td>
#                         <td id="T_932ac_row1_col3" class="data row1 col3" >0.7850</td>
#                         <td id="T_932ac_row1_col4" class="data row1 col4" >0.8464</td>
#                         <td id="T_932ac_row1_col5" class="data row1 col5" >0.4263</td>
#                         <td id="T_932ac_row1_col6" class="data row1 col6" >0.4457</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_932ac_row2_col0" class="data row2 col0" >0.7819</td>
#                         <td id="T_932ac_row2_col1" class="data row2 col1" >0.8169</td>
#                         <td id="T_932ac_row2_col2" class="data row2 col2" >0.9243</td>
#                         <td id="T_932ac_row2_col3" class="data row2 col3" >0.7902</td>
#                         <td id="T_932ac_row2_col4" class="data row2 col4" >0.8520</td>
#                         <td id="T_932ac_row2_col5" class="data row2 col5" >0.4473</td>
#                         <td id="T_932ac_row2_col6" class="data row2 col6" >0.4677</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_932ac_row3_col0" class="data row3 col0" >0.7703</td>
#                         <td id="T_932ac_row3_col1" class="data row3 col1" >0.8091</td>
#                         <td id="T_932ac_row3_col2" class="data row3 col2" >0.9243</td>
#                         <td id="T_932ac_row3_col3" class="data row3 col3" >0.7788</td>
#                         <td id="T_932ac_row3_col4" class="data row3 col4" >0.8453</td>
#                         <td id="T_932ac_row3_col5" class="data row3 col5" >0.4117</td>
#                         <td id="T_932ac_row3_col6" class="data row3 col6" >0.4353</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_932ac_row4_col0" class="data row4 col0" >0.7786</td>
#                         <td id="T_932ac_row4_col1" class="data row4 col1" >0.8082</td>
#                         <td id="T_932ac_row4_col2" class="data row4 col2" >0.9096</td>
#                         <td id="T_932ac_row4_col3" class="data row4 col3" >0.7942</td>
#                         <td id="T_932ac_row4_col4" class="data row4 col4" >0.8480</td>
#                         <td id="T_932ac_row4_col5" class="data row4 col5" >0.4472</td>
#                         <td id="T_932ac_row4_col6" class="data row4 col6" >0.4614</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_932ac_row5_col0" class="data row5 col0" >0.7952</td>
#                         <td id="T_932ac_row5_col1" class="data row5 col1" >0.8270</td>
#                         <td id="T_932ac_row5_col2" class="data row5 col2" >0.9243</td>
#                         <td id="T_932ac_row5_col3" class="data row5 col3" >0.8036</td>
#                         <td id="T_932ac_row5_col4" class="data row5 col4" >0.8597</td>
#                         <td id="T_932ac_row5_col5" class="data row5 col5" >0.4871</td>
#                         <td id="T_932ac_row5_col6" class="data row5 col6" >0.5038</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_932ac_row6_col0" class="data row6 col0" >0.7645</td>
#                         <td id="T_932ac_row6_col1" class="data row6 col1" >0.7987</td>
#                         <td id="T_932ac_row6_col2" class="data row6 col2" >0.9072</td>
#                         <td id="T_932ac_row6_col3" class="data row6 col3" >0.7813</td>
#                         <td id="T_932ac_row6_col4" class="data row6 col4" >0.8395</td>
#                         <td id="T_932ac_row6_col5" class="data row6 col5" >0.4063</td>
#                         <td id="T_932ac_row6_col6" class="data row6 col6" >0.4227</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_932ac_row7_col0" class="data row7 col0" >0.7745</td>
#                         <td id="T_932ac_row7_col1" class="data row7 col1" >0.8045</td>
#                         <td id="T_932ac_row7_col2" class="data row7 col2" >0.9108</td>
#                         <td id="T_932ac_row7_col3" class="data row7 col3" >0.7892</td>
#                         <td id="T_932ac_row7_col4" class="data row7 col4" >0.8456</td>
#                         <td id="T_932ac_row7_col5" class="data row7 col5" >0.4350</td>
#                         <td id="T_932ac_row7_col6" class="data row7 col6" >0.4507</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_932ac_row8_col0" class="data row8 col0" >0.7836</td>
#                         <td id="T_932ac_row8_col1" class="data row8 col1" >0.8170</td>
#                         <td id="T_932ac_row8_col2" class="data row8 col2" >0.9193</td>
#                         <td id="T_932ac_row8_col3" class="data row8 col3" >0.7941</td>
#                         <td id="T_932ac_row8_col4" class="data row8 col4" >0.8521</td>
#                         <td id="T_932ac_row8_col5" class="data row8 col5" >0.4566</td>
#                         <td id="T_932ac_row8_col6" class="data row8 col6" >0.4741</td>
#             </tr>
#             <tr>
#                         <th id="T_932ac_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_932ac_row9_col0" class="data row9 col0" >0.7927</td>
#                         <td id="T_932ac_row9_col1" class="data row9 col1" >0.8180</td>
#                         <td id="T_932ac_row9_col2" class="data row9 col2" >0.9364</td>
#                         <td id="T_932ac_row9_col3" class="data row9 col3" >0.7946</td>
#                         <td id="T_932ac_row9_col4" class="data row9 col4" >0.8597</td>
#                         <td id="T_932ac_row9_col5" class="data row9 col5" >0.4729</td>
#                         <td id=
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=5921, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# ## Now let's tune the model. In order to tune hyperparameters, the tune_model function is used. This function automatically tunes the hyperparameters of a model using Random Grid Search on a pre-defined search space. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold.

# %%
tuned_model = tune_model(best_model)
tuned_model

# %% [markdown]
# ## Let's plot the feature importance. The plot_model() function can be used to analyze the  feature Importance etc. This function takes a trained model object and returns a plot based on the test / hold-out set.

# %%
plot_model(tuned_model, plot='feature')
#evaluate_model(tuned_model)

# %% [markdown]
# ## Let's finalize the model for deployment. The finalize_model() function fits the model onto the complete dataset including the test/evaluation sample (10% in this case). The purpose of this function is to train the model on the complete dataset before it is deployed in production.

# %%
final_model = finalize_model(tuned_model)

print(final_model)

# %% [markdown]
# ## Now we can predict on the unseen data and review some evaluation metrics to understand the model performance

# %%
unseen_predictions = predict_model(final_model, data=df_eval)
unseen_predictions.head()

# %%
accuracy = check_metric(unseen_predictions['isnextyear_buyer'], unseen_predictions['Label'], metric = 'Accuracy')
precision = check_metric(unseen_predictions['isnextyear_buyer'], unseen_predictions['Label'], metric = 'Precision')
recall = check_metric(unseen_predictions['isnextyear_buyer'], unseen_predictions['Label'], metric = 'Recall')
f1 = check_metric(unseen_predictions['isnextyear_buyer'], unseen_predictions['Label'], metric = 'F1')
auc = check_metric(unseen_predictions['isnextyear_buyer'], unseen_predictions['Label'], metric = 'AUC')

print("> MODEL PERFORMANCE CALCULATED", end="\n\n")
print(" * ACCURACY=", accuracy)
print(" * PRECISION=", precision)
print(" * RECALL=", recall)
print(" * F1= ", f1)
print(" * AUC= ", auc)

# %% [markdown]
# ## We can now save the final model. PyCaret's inbuilt function save_model() allows you to save the model along with entire transformation pipeline for later use.

# %%
save_model(final_model,'../models/QA-MILB-League-Based-Retention-Model')

# %% [markdown]
# ## Now that we have an exported model we can use it to score new data. To load a saved model at a future date in the same or an alternative environment, we would use PyCaret's load_model() function and then easily apply the saved model on new unseen data for prediction.

# %%
saved_final_model = load_model('../models/QA-MILB-League-Based-Retention-Model')

new_prediction = predict_model(saved_final_model, data=df_eval)
new_prediction.head()
