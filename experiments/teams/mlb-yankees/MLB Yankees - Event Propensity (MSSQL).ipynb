# %% [markdown]
# # Yankees - Event Propensity - Next Event Buyer
# * Ryan Kazmerik, Nakisa Rad, Joey Lai, Shawn Sutherland, Matt Bahler, Pat Faith
# * Feb 09, 2022

# %% [markdown]
# ## Hypothesis
# Each team has different tier (or quality) of games, based on day of the week, time of the season, opponent, etc. We think that by using previous buyer behaviour we can make a prediction on whether the fan will purchase for the next game or not.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import matplotlib.pyplot as plt
import pyodbc
import pandas as pd
import warnings

from pandas_profiling import ProfileReport
from pycaret.classification import *
from shared_utilities import helpers

warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
# connect to SQL Server.
SERVER = '54.164.224.129'  
DATABASE = 'stlrRays' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)

# %%
cursor = CNXN.cursor()

query = "SELECT * FROM datascience.yankees.event_propensity_training_noFirstPurchases2"
    
df = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266386 entries, 0 to 266385
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   daysOut              266386 non-null  object
#  1   minDaysOut           266386 non-null  int64
#  2   maxDaysOut           147819 non-null  float64
#  3   dimCustomerMasterId  266386 non-null  int64
#  4   recent_openRate      266386 non-null  float64
#  5   recent_clickRate     266386 non-null  float64
#  6   eventDate            266386 non-null  datetime64[ns]
#  7   eventName            266386 non-null  object
#  8   inMarket             242800 non-null  object
#  9   distanceToVenue      242800 non-null  float64
#  10  tenure               266386 non-null  int64
#  11  did_purchase         266386 non-null  int64
#  12  events_purchased     266386 non-null  int64
#  13  frequency_opponent   266386 non-null  float64
#  14  frequency_eventDay   266386 non-null  float64
#  15  frequency_eventTime  266386 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(3)
# memory usage: 32.5+ MB

# %% [markdown]
# ### We should create separate out some data for training the model and some for evaluating:

# %%
# copy your main dataframe
df_dataset = df

df_train = df_dataset.sample(frac=0.85, random_state=786)
df_eval = df_dataset.drop(df_train.index)

df_train.reset_index(drop=True)
df_eval.reset_index(drop=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (226428, 16)
# Unseen Data For Predictions: (39958, 16)

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the target field to see how likely a customer is to purchase:

# %%
setup(
    data= df_train, 
    target="did_purchase", 
    train_size = 0.80,
    data_split_shuffle=True,
    categorical_features=["inMarket"],
    date_features=["eventDate"],
    ignore_features=[
        "dimCustomerMasterId",
        "eventName",
        "minDaysOut",
        "maxDaysOut"
    ],
    silent=True,
    verbose=False,
    numeric_features=[
        "distanceToVenue",
        "events_purchased",
        "frequency_eventDay",
        "frequency_opponent",
        "frequency_eventTime",
        "recent_clickRate",
        "recent_openRate",
        "tenure"
    ]
);

# %%
model_matrix = compare_models(
    fold= 10, 
    include= ["lr"]
)
# Out:
# <style type="text/css">
# #T_0e1e9 th {
#   text-align: left;
# }
# #T_0e1e9_row0_col0 {
#   text-align: left;
# }
# #T_0e1e9_row0_col1, #T_0e1e9_row0_col2, #T_0e1e9_row0_col3, #T_0e1e9_row0_col4, #T_0e1e9_row0_col5, #T_0e1e9_row0_col6, #T_0e1e9_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0e1e9_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0e1e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e1e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0e1e9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0e1e9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0e1e9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0e1e9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0e1e9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0e1e9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0e1e9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0e1e9_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e1e9_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_0e1e9_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_0e1e9_row0_col1" class="data row0 col1" >0.8025</td>
#       <td id="T_0e1e9_row0_col2" class="data row0 col2" >0.8793</td>
#       <td id="T_0e1e9_row0_col3" class="data row0 col3" >0.7844</td>
#       <td id="T_0e1e9_row0_col4" class="data row0 col4" >0.8142</td>
#       <td id="T_0e1e9_row0_col5" class="data row0 col5" >0.7990</td>
#       <td id="T_0e1e9_row0_col6" class="data row0 col6" >0.6049</td>
#       <td id="T_0e1e9_row0_col7" class="data row0 col7" >0.6054</td>
#       <td id="T_0e1e9_row0_col8" class="data row0 col8" >6.5430</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### The top model is performing well, so let's compare it against our test dataset:

# %%
best_model = create_model(
    model_matrix, 
    fold= 10
)
# Out:
# <style type="text/css">
# #T_089e8_row10_col0, #T_089e8_row10_col1, #T_089e8_row10_col2, #T_089e8_row10_col3, #T_089e8_row10_col4, #T_089e8_row10_col5, #T_089e8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_089e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_089e8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_089e8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_089e8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_089e8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_089e8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_089e8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_089e8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_089e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_089e8_row0_col0" class="data row0 col0" >0.8014</td>
#       <td id="T_089e8_row0_col1" class="data row0 col1" >0.8773</td>
#       <td id="T_089e8_row0_col2" class="data row0 col2" >0.7850</td>
#       <td id="T_089e8_row0_col3" class="data row0 col3" >0.8120</td>
#       <td id="T_089e8_row0_col4" class="data row0 col4" >0.7983</td>
#       <td id="T_089e8_row0_col5" class="data row0 col5" >0.6029</td>
#       <td id="T_089e8_row0_col6" class="data row0 col6" >0.6032</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_089e8_row1_col0" class="data row1 col0" >0.8012</td>
#       <td id="T_089e8_row1_col1" class="data row1 col1" >0.8796</td>
#       <td id="T_089e8_row1_col2" class="data row1 col2" >0.7802</td>
#       <td id="T_089e8_row1_col3" class="data row1 col3" >0.8147</td>
#       <td id="T_089e8_row1_col4" class="data row1 col4" >0.7971</td>
#       <td id="T_089e8_row1_col5" class="data row1 col5" >0.6023</td>
#       <td id="T_089e8_row1_col6" class="data row1 col6" >0.6029</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_089e8_row2_col0" class="data row2 col0" >0.7984</td>
#       <td id="T_089e8_row2_col1" class="data row2 col1" >0.8768</td>
#       <td id="T_089e8_row2_col2" class="data row2 col2" >0.7795</td>
#       <td id="T_089e8_row2_col3" class="data row2 col3" >0.8106</td>
#       <td id="T_089e8_row2_col4" class="data row2 col4" >0.7947</td>
#       <td id="T_089e8_row2_col5" class="data row2 col5" >0.5969</td>
#       <td id="T_089e8_row2_col6" class="data row2 col6" >0.5973</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_089e8_row3_col0" class="data row3 col0" >0.8007</td>
#       <td id="T_089e8_row3_col1" class="data row3 col1" >0.8786</td>
#       <td id="T_089e8_row3_col2" class="data row3 col2" >0.7791</td>
#       <td id="T_089e8_row3_col3" class="data row3 col3" >0.8147</td>
#       <td id="T_089e8_row3_col4" class="data row3 col4" >0.7965</td>
#       <td id="T_089e8_row3_col5" class="data row3 col5" >0.6014</td>
#       <td id="T_089e8_row3_col6" class="data row3 col6" >0.6020</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_089e8_row4_col0" class="data row4 col0" >0.8028</td>
#       <td id="T_089e8_row4_col1" class="data row4 col1" >0.8757</td>
#       <td id="T_089e8_row4_col2" class="data row4 col2" >0.7848</td>
#       <td id="T_089e8_row4_col3" class="data row4 col3" >0.8145</td>
#       <td id="T_089e8_row4_col4" class="data row4 col4" >0.7994</td>
#       <td id="T_089e8_row4_col5" class="data row4 col5" >0.6056</td>
#       <td id="T_089e8_row4_col6" class="data row4 col6" >0.6060</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_089e8_row5_col0" class="data row5 col0" >0.8029</td>
#       <td id="T_089e8_row5_col1" class="data row5 col1" >0.8816</td>
#       <td id="T_089e8_row5_col2" class="data row5 col2" >0.7923</td>
#       <td id="T_089e8_row5_col3" class="data row5 col3" >0.8097</td>
#       <td id="T_089e8_row5_col4" class="data row5 col4" >0.8009</td>
#       <td id="T_089e8_row5_col5" class="data row5 col5" >0.6057</td>
#       <td id="T_089e8_row5_col6" class="data row5 col6" >0.6059</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_089e8_row6_col0" class="data row6 col0" >0.8023</td>
#       <td id="T_089e8_row6_col1" class="data row6 col1" >0.8790</td>
#       <td id="T_089e8_row6_col2" class="data row6 col2" >0.7863</td>
#       <td id="T_089e8_row6_col3" class="data row6 col3" >0.8127</td>
#       <td id="T_089e8_row6_col4" class="data row6 col4" >0.7993</td>
#       <td id="T_089e8_row6_col5" class="data row6 col5" >0.6046</td>
#       <td id="T_089e8_row6_col6" class="data row6 col6" >0.6049</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_089e8_row7_col0" class="data row7 col0" >0.8061</td>
#       <td id="T_089e8_row7_col1" class="data row7 col1" >0.8815</td>
#       <td id="T_089e8_row7_col2" class="data row7 col2" >0.7817</td>
#       <td id="T_089e8_row7_col3" class="data row7 col3" >0.8221</td>
#       <td id="T_089e8_row7_col4" class="data row7 col4" >0.8014</td>
#       <td id="T_089e8_row7_col5" class="data row7 col5" >0.6121</td>
#       <td id="T_089e8_row7_col6" class="data row7 col6" >0.6129</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_089e8_row8_col0" class="data row8 col0" >0.8048</td>
#       <td id="T_089e8_row8_col1" class="data row8 col1" >0.8823</td>
#       <td id="T_089e8_row8_col2" class="data row8 col2" >0.7878</td>
#       <td id="T_089e8_row8_col3" class="data row8 col3" >0.8159</td>
#       <td id="T_089e8_row8_col4" class="data row8 col4" >0.8016</td>
#       <td id="T_089e8_row8_col5" class="data row8 col5" >0.6096</td>
#       <td id="T_089e8_row8_col6" class="data row8 col6" >0.6100</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_089e8_row9_col0" class="data row9 col0" >0.8041</td>
#       <td id="T_089e8_row9_col1" class="data row9 col1" >0.8808</td>
#       <td id="T_089e8_row9_col2" class="data row9 col2" >0.7871</td>
#       <td id="T_089e8_row9_col3" class="data row9 col3" >0.8151</td>
#       <td id="T_089e8_row9_col4" class="data row9 col4" >0.8009</td>
#       <td id="T_089e8_row9_col5" class="data row9 col5" >0.6082</td>
#       <td id="T_089e8_row9_col6" class="data row9 col6" >0.6085</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_089e8_row10_col0" class="data row10 col0" >0.8025</td>
#       <td id="T_089e8_row10_col1" class="data row10 col1" >0.8793</td>
#       <td id="T_089e8_row10_col2" class="data row10 col2" >0.7844</td>
#       <td id="T_089e8_row10_col3" class="data row10 col3" >0.8142</td>
#       <td id="T_089e8_row10_col4" class="data row10 col4" >0.7990</td>
#       <td id="T_089e8_row10_col5" class="data row10 col5" >0.6049</td>
#       <td id="T_089e8_row10_col6" class="data row10 col6" >0.6054</td>
#     </tr>
#     <tr>
#       <th id="T_089e8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_089e8_row11_col0" class="data row11 col0" >0.0021</td>
#       <td id="T_089e8_row11_col1" class="data row11 col1" >0.0021</td>
#       <td id="T_089e8_row11_col2" class="data row11 col2" >0.0040</td>
#       <td id="T_089e8_row11_col3" class="data row11 col3" >0.0033</td>
#       <td id="T_089e8_row11_col4

# %% [markdown]
# ### We can also see the correlation between the features and the target variable:

# %%
cor = df.corr()

df_correlated = df

corr = df_correlated.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_2386f_row0_col0, #T_2386f_row1_col1, #T_2386f_row2_col2, #T_2386f_row3_col3, #T_2386f_row4_col4, #T_2386f_row5_col5, #T_2386f_row6_col6, #T_2386f_row7_col7, #T_2386f_row8_col8, #T_2386f_row9_col9, #T_2386f_row10_col10, #T_2386f_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col1, #T_2386f_row1_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col2, #T_2386f_row3_col10 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col3, #T_2386f_row0_col4, #T_2386f_row1_col9, #T_2386f_row3_col0, #T_2386f_row5_col2, #T_2386f_row5_col7, #T_2386f_row6_col10, #T_2386f_row6_col11, #T_2386f_row7_col5, #T_2386f_row11_col1, #T_2386f_row11_col6, #T_2386f_row11_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col5, #T_2386f_row10_col5, #T_2386f_row11_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col6, #T_2386f_row1_col7, #T_2386f_row3_col5, #T_2386f_row4_col9, #T_2386f_row7_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_2386f_row0_col8, #T_2386f_row8_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col9, #T_2386f_row2_col4, #T_2386f_row11_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col10, #T_2386f_row5_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_2386f_row0_col11, #T_2386f_row7_col8, #T_2386f_row9_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col2, #T_2386f_row4_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col3, #T_2386f_row9_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col4, #T_2386f_row10_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col5, #T_2386f_row6_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col6, #T_2386f_row2_col8 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_2386f_row1_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col10, #T_2386f_row6_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_2386f_row1_col11, #T_2386f_row10_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col0, #T_2386f_row4_col10, #T_2386f_row8_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col1, #T_2386f_row5_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col3, #T_2386f_row3_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col5, #T_2386f_row5_col10, #T_2386f_row7_col6, #T_2386f_row10_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col6, #T_2386f_row10_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2386f_row2_col7, #T_2386f_row10_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_2386f_row2_col9, #T_2386f_row4_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_2386f_row2_col10, #T_2386f_row3_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_2386f_row2_col11 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_2386f_row3_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_2386f_row3_col2, #T_2386f_row3_col9, #T_2386f_row6_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_2386f_row3_col6, #T_2386f_row4_col5, #T_2386f_row6_col2, #T_2386f_row9_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_2386f_row3_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_2386f_row3_col8, #T_2386f_row4_col8, #T_2386f_row8_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_2386f_row4_col0, #T_2386f_row10_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_2386f_row4_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_2386f_row4_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_2386f_row4_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_2386f_row4_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col4, #T_2386f_row8_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_2386f_row5_col11, #T_2386f_row7_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_2386f_row6_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_2386f_row6_col4, #T_2386f_row6_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_2386f_row6_col7, #T_2386f_row9_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_2386f_row6_col8, #T_2386f_row8_col6 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_2386f_row7_col0, #T_2386f_row7_col11 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_2386f_row7_col1, #T_2386f_row8_col0, #T_2386f_row10_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_2386f_row7_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_2386f_row7_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_2386f_row7_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_2386f_row8_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_2386f_row8_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2386f_row8_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2386f_row8_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2386f_row8_col11, #T_2386f_row9_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_2386f_row9_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_2386f_row9_col6, #T_2386f_row9_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_2386f_row9_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_2386f_row9_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_2386f_row9_col11 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_2386f_row10_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_2386f_row10_col7, #T_2386f_row11_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_2386f_row10_col11 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_2386f_row11_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2386f_row11_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2386f_row11_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_2386f_row11_col9 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_2386f_row11_col10 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_2386f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2386f_level0_col0" class="col_heading level0 col0" >minDaysOut</th>
#       <th id="T_2386f_level0_col1" class="col_heading level0 col1" >maxDaysOut</th>
#       <th id="T_2386f_level0_col2" class="col_heading level0 col2" >dimCustomerMasterId</th>
#       <th id="T_2386f_level0_col3" class="col_heading level0 col3" >recent_openRate</th>
#       <th id="T_2386f_level0_col4" class="col_heading level0 col4" >recent_clickRate</th>
#       <th id="T_2386f_level0_col5" class="col_heading level0 col5" >distanceToVenue</th>
#       <th id="T_2386f_level0_col6" class="col_heading level0 col6" >tenure</th>
#       <th id="T_2386f_level0_col7" class="col_heading level0 col7" >did_purchase</th>
#       <th id="T_2386f_level0_col8" class="col_heading level0 col8" >events_purchased</th>
#       <th id="T_2386f_level0_col9" class="col_heading level0 col9" >frequency_opponent</th>
#       <th id="T_2386f_level0_col10" class="col_heading level0 col10" >frequency_eventDay</th>
#       <th id="T_2386f_level0_col11" class="col_heading level0 col11" >frequency_eventTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2386f_level0_row0" class="row_heading level0 row0" >minDaysOut</th>
#       <td id="T_2386f_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_2386f_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_2386f_row0_col2" class="data row0 col2" >0.10</td>
#       <td id="

# %% [markdown]
# ### This plot lists the most important features for a correct prediction (either Score_0 or Score_1) in the model:

# %%
plot_model(best_model, plot='feature')

# %% [markdown]
# ### This confusion matrix helps understand where the model guessed correctly or incorrectly based on the evaluation data:

# %%
plot_model(best_model, plot='confusion_matrix')

# %% [markdown]
# ### The AUC curve tells how much the model is capable of distinguishing between classes. The higher the curve, the better the model is at distiguishing classes:

# %%
plot_model(best_model, plot='auc')

# %% [markdown]
# ### Let's load up some real events from previous events to see how the model scores the data:

# %%
cursor = CNXN.cursor()

query = """
    SELECT
        daysOut,
        dimCustomerMasterId,
        eventDate,
        events_purchased,
        frequency_opponent,
        frequency_eventDay,
        frequency_eventTime,
        inMarket,
        distanceToVenue,
        recent_openRate,
        recent_clickRate,
        tenure
    FROM 
        DataScience.yankees.event_propensity_scoring_20190330
"""
    
df_inference = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

# %%
df_inference.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648764 entries, 0 to 1648763
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   daysOut              1648764 non-null  object
#  1   dimCustomerMasterId  1648764 non-null  int64
#  2   eventDate            1648764 non-null  datetime64[ns]
#  3   events_purchased     1648764 non-null  float64
#  4   frequency_opponent   1648764 non-null  float64
#  5   frequency_eventDay   1647368 non-null  float64
#  6   frequency_eventTime  1648764 non-null  float64
#  7   inMarket             1406432 non-null  object
#  8   distanceToVenue      1406432 non-null  float64
#  9   recent_openRate      415456 non-null   float64
#  10  recent_clickRate     415456 non-null   float64
#  11  tenure               1648764 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 150.9+ MB

# %%
df_inference.eventDate.value_counts()
# Out:
# 2019-03-30    1648764
# Name: eventDate, dtype: int64

# %%
df_inference.to_csv("asdf.csv")

# %% [markdown]
# ### Let's run the previous scores through the model for predictions:

# %%
df_scores = predict_model(best_model, data=df_inference, raw_score=True)
df_scores.head()
# Out:
#            daysOut  dimCustomerMasterId  eventDate  events_purchased  \
# 0           Day Of              1671914 2019-03-30               1.0
# 1  1 to 3 Days Out              1671914 2019-03-30               1.0
# 2  4 to 7 Days Out              1671914 2019-03-30               1.0
# 3      Over a Week              1671914 2019-03-30               1.0
# 4           Day Of              1732044 2019-03-30               2.0
#
#    frequency_opponent  frequency_eventDay  frequency_eventTime inMarket  \
# 0                 0.0                 0.0             0.022222     True
# 1                 0.0                 0.0             0.022222     True
# 2                 0.0                 0.0             0.022222     True
# 3                 0.0                 0.0             0.022222     True
# 4                 0.0                 0.0             0.000000     True
#
#    distanceToVenue  recent_openRate  recent_clickRate  tenure  Label  Score_0  \
# 0            31.58              NaN               NaN     599      0   0.9103
# 1            31.58              NaN               NaN     599      0   0.8783
# 2            31.58              NaN               NaN     599      0   0.8830
# 3            31.58              NaN               NaN     599      0   0.5724
# 4            18.70              0.0               0.0     601      0   0.9256
#
#    Score_1
# 0   0.0897
# 1   0.1217
# 2   0.1170
# 3   0.4276
# 4   0.0744

# %% [markdown]
# ### Included are some metrics on did and did_not purchase:

# %%
did_purchase = df_scores["Label"].value_counts()[1]
did_not_purchase = df_scores["Label"].value_counts()[0]
total_rows = df_scores["Label"].count()
purchase_percentage = round((did_purchase / total_rows), 4) * 100

print("Would purchase:", did_purchase)
print("Would not purchase:", did_not_purchase)
print("Purchase percentage:", purchase_percentage)
# Out:
# Would purchase: 170165
# Would not purchase: 1478599
# Purchase percentage: 10.32

# %%
df_inference_2 = helpers.get_event_propensity_scoring_dataset(
    cluster="prod-app",
    database="stlryankees",
    lkupclientid="53",
    game_date="2019-03-30"
)

df_inference_2.shape
# Out:
# Authorized as AROASQ4JELIXYLYV6P4UV:rkazmerik@stellaralgo.com
# (3218440, 12)

# %%
df_scores_2 = predict_model(best_model, data=df_inference_2, raw_score=True)
df_scores_2.shape

# %%
did_purchase = df_scores_2["Label"].value_counts()[1]
did_not_purchase = df_scores_2["Label"].value_counts()[0]
total_rows = df_scores_2["Label"].count()
purchase_percentage = round((did_purchase / total_rows), 4) * 100

print("Would purchase:", did_purchase)
print("Would not purchase:", did_not_purchase)
print("Purchase percentage:", purchase_percentage)
# Out:
# Would purchase: 1702050
# Would not purchase: 1516390
# Purchase percentage: 52.88

# %% [markdown]
# ### Here we can see the distribution of fans who did and did not purchase : Score_0 = Did Not Purchase, Score_1 = Did Purchase

# %%
df_scoring.hist(column=['Score_0', 'Score_1'], figsize=(30,5), layout=(1,3));

# %%
# scoring_list = df_scoring.to_dict('records')

# %%
# max_dict = {}
# for record in scoring_list:
#     if record['dimCustomerMasterId'] not in max_dict:
#         max_dict[record['dimCustomerMasterId']] = 0
    
#     if record['Score_1'] > max_dict[record['dimCustomerMasterId']]:
#         max_dict[record['dimCustomerMasterId']] = record['Score_1']

# %%
#max_scores = [{'id': k, 'score': v} for k, v in max_dict.items()]
#max_scores.sort(key = lambda v: -v["score"])

#df_max_scores = pd.DataFrame(max_scores)
#df_max_scores.to_csv('yankees_scoring_test.csv')

# %%
#df_max_scores.head()

# %%
#df1 = df_scoring.loc[df_scoring.groupby('dimCustomerMasterId', sort=False)['Score_1'].idxmax()]

# %%
#df1 = df1.sort_values(by='Score_1', ascending=False).reset_index()

# %%
#df1 = df1.filter(['dimCustomerMasterId','Score_1'], axis=1)

# %%
#df1.head()

# %% [markdown]
# ## Observations
# Here you can talk about next steps, did the experiment work? If yes, what to do next? If no, why?

# %%
lkupclientid = 53 # Yankees

cursor = CNXN.cursor()

storedProc = (f"""Exec [stlrYankees].[ds].[getPropensityEventScoring] {lkupclientid}""")

df = pd.read_sql(storedProc, CNXN)

# apply some data transformations
df["year"] = pd.to_numeric(df["year"]) 

CNXN.commit()
cursor.close()

df.shape
