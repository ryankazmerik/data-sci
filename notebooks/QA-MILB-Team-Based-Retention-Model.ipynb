# %% [markdown]
# # MILB Team Based Retention Model (QA)
#
# * Stellar Algo
# * Nakiska Rad & Ryan Kazmerik
# * August 31, 2021

# %%
import getpass
import pyodbc
import pandas as pd
import numpy as np

import warnings

from pycaret.classification import *

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Let's get our dataset from MSSQL. We will select the full season product only and seasons before 2020, since 2020 was a strange year due to covid, and 2021 does not have any repurchasing data available

# %%
SERVER = '52.44.171.130' 
DATABASE = 'datascience' 
USERNAME = getpass.getpass(prompt='Enter your username') 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your username ············
# Enter your password ····················

# %%
cursor = CNXN.cursor()

client_id = 11 #bulls
product = "Full Season"
train_season_year = 2019
test_season_year = 2021

query =  f"""
    SELECT 
        r.dimcustomermasterid,
        recency,
        attendancePercent,
        totalSpent,
        distToVenue,
        source_tenure,
        renewedBeforeDays,
        missed_games_1,
        missed_games_2,
        missed_games_over_2,
        isnextyear_buyer
    FROM 
        ds.retentionscoring r 
    WHERE 
        lkupclientid = {client_id} 
    AND 
        productgrouping = {"'"+ str(product) + "'"} 
    AND 
        year < {train_season_year};
    """
    
df = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dimcustomermasterid  1070 non-null   object
#  1   recency              1070 non-null   int64
#  2   attendancePercent    1070 non-null   object
#  3   totalSpent           1070 non-null   object
#  4   distToVenue          1070 non-null   object
#  5   source_tenure        1070 non-null   int64
#  6   renewedBeforeDays    1070 non-null   int64
#  7   missed_games_1       1070 non-null   int64
#  8   missed_games_2       1070 non-null   int64
#  9   missed_games_over_2  1070 non-null   int64
#  10  isnextyear_buyer     1070 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 92.1+ KB
#   dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 0           303661788        0          0.580986       2485       26.49
# 1           303663474        1          0.527778       4032       23.92
# 2           303659570        0          0.548611     1641.6       24.07
# 3           303658983        3          0.313869     1561.8       18.21
# 4           303659912        0          0.280992     1379.4        5.16
#
#    source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 0           1460                  8               8               8
# 1           1460                198               0               2
# 2           1460                185              14               4
# 3           1460                197               2               2
# 4           1460                202               0               0
#
#    missed_games_over_2  isnextyear_buyer
# 0                    3                 1
# 1                    7                 1
# 2                    3                 1
# 3                    3                 1
# 4                    4                 1

# %% [markdown]
# ## We need to hold back some samples from the dataset for evalution, so let's create the training and evaluation dataset with a hold-back of 10%.

# %%
df_train = df.sample(frac=0.9, random_state=786)
df_eval = df.drop(df_train.index)

print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape))
# Out:
# Data for Modeling: (963, 11)
# Unseen Data For Predictions: (107, 11)

# %% [markdown]
# ## Now we can model the data using PyCaret, with a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
model = setup(df_train, target='isnextyear_buyer', train_size = 0.8)
# Out:
# <style  type="text/css" >
# #T_8dac3_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_8dac3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8dac3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8dac3_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8dac3_row0_col1" class="data row0 col1" >1129</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8dac3_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_8dac3_row1_col1" class="data row1 col1" >isnextyear_buyer</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8dac3_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_8dac3_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8dac3_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_8dac3_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8dac3_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_8dac3_row4_col1" class="data row4 col1" >(963, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8dac3_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_8dac3_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8dac3_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_8dac3_row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8dac3_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_8dac3_row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8dac3_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_8dac3_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8dac3_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_8dac3_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_8dac3_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_8dac3_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_8dac3_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_8dac3_row11_col1" class="data row11 col1" >(770, 820)</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_8dac3_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_8dac3_row12_col1" class="data row12 col1" >(193, 820)</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_8dac3_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_8dac3_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_8dac3_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_8dac3_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_8dac3_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_8dac3_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_8dac3_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_8dac3_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_8dac3_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_8dac3_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_8dac3_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_8dac3_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_8dac3_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_8dac3_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_8dac3_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_8dac3_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_8dac3_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_8dac3_row21_col1" class="data row21 col1" >b17f</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_8dac3_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_8dac3_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_8dac3_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_8dac3_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_8dac3_level0_row24" class="row_heading level0 r

# %%
get_config('X_train').columns
# Out:
# Index(['dimcustomermasterid', 'recency', 'source_tenure', 'renewedBeforeDays',
#        'attendancePercent_0', 'attendancePercent_0.0142857',
#        'attendancePercent_0.0214286', 'attendancePercent_0.0277778',
#        'attendancePercent_0.028169', 'attendancePercent_0.0285714',
#        ...
#        'missed_games_over_2_10', 'missed_games_over_2_11',
#        'missed_games_over_2_2', 'missed_games_over_2_3',
#        'missed_games_over_2_4', 'missed_games_over_2_5',
#        'missed_games_over_2_6', 'missed_games_over_2_7',
#        'missed_games_over_2_8', 'missed_games_over_2_9'],
#       dtype='object', length=820)

# %% [markdown]
# ## Now we can compare all models to evaluate performance. This function trains all models in the model library and scores them using k-fold cross validation for metric evaluation. The output prints a score grid that shows average MAE, MSE, RMSE, R2, RMSLE and MAPE accross the folds (10 by default) along with training time.

# %%
model_matrix = compare_models(fold=10, sort="F1")
# Out:
# <style  type="text/css" >
#     #T_6ef88_ th {
#           text-align: left;
#     }#T_6ef88_row0_col0,#T_6ef88_row0_col2,#T_6ef88_row0_col3,#T_6ef88_row0_col4,#T_6ef88_row1_col0,#T_6ef88_row1_col1,#T_6ef88_row1_col2,#T_6ef88_row1_col3,#T_6ef88_row1_col4,#T_6ef88_row1_col5,#T_6ef88_row1_col6,#T_6ef88_row1_col7,#T_6ef88_row2_col0,#T_6ef88_row2_col1,#T_6ef88_row2_col2,#T_6ef88_row2_col3,#T_6ef88_row2_col4,#T_6ef88_row2_col5,#T_6ef88_row2_col6,#T_6ef88_row2_col7,#T_6ef88_row3_col0,#T_6ef88_row3_col1,#T_6ef88_row3_col2,#T_6ef88_row3_col3,#T_6ef88_row3_col4,#T_6ef88_row3_col5,#T_6ef88_row3_col6,#T_6ef88_row3_col7,#T_6ef88_row4_col0,#T_6ef88_row4_col1,#T_6ef88_row4_col2,#T_6ef88_row4_col3,#T_6ef88_row4_col4,#T_6ef88_row4_col5,#T_6ef88_row4_col6,#T_6ef88_row4_col7,#T_6ef88_row5_col0,#T_6ef88_row5_col1,#T_6ef88_row5_col3,#T_6ef88_row5_col4,#T_6ef88_row5_col5,#T_6ef88_row5_col6,#T_6ef88_row5_col7,#T_6ef88_row6_col0,#T_6ef88_row6_col1,#T_6ef88_row6_col2,#T_6ef88_row6_col3,#T_6ef88_row6_col5,#T_6ef88_row6_col6,#T_6ef88_row6_col7,#T_6ef88_row7_col0,#T_6ef88_row7_col1,#T_6ef88_row7_col2,#T_6ef88_row7_col3,#T_6ef88_row7_col4,#T_6ef88_row7_col5,#T_6ef88_row7_col6,#T_6ef88_row7_col7,#T_6ef88_row8_col0,#T_6ef88_row8_col1,#T_6ef88_row8_col2,#T_6ef88_row8_col3,#T_6ef88_row8_col4,#T_6ef88_row8_col5,#T_6ef88_row8_col6,#T_6ef88_row8_col7,#T_6ef88_row9_col0,#T_6ef88_row9_col1,#T_6ef88_row9_col2,#T_6ef88_row9_col4,#T_6ef88_row9_col5,#T_6ef88_row9_col6,#T_6ef88_row9_col7,#T_6ef88_row10_col0,#T_6ef88_row10_col1,#T_6ef88_row10_col2,#T_6ef88_row10_col3,#T_6ef88_row10_col4,#T_6ef88_row10_col5,#T_6ef88_row10_col6,#T_6ef88_row10_col7,#T_6ef88_row11_col0,#T_6ef88_row11_col1,#T_6ef88_row11_col2,#T_6ef88_row11_col3,#T_6ef88_row11_col4,#T_6ef88_row11_col5,#T_6ef88_row11_col6,#T_6ef88_row11_col7,#T_6ef88_row12_col0,#T_6ef88_row12_col1,#T_6ef88_row12_col2,#T_6ef88_row12_col3,#T_6ef88_row12_col4,#T_6ef88_row12_col5,#T_6ef88_row12_col6,#T_6ef88_row12_col7,#T_6ef88_row13_col0,#T_6ef88_row13_col1,#T_6ef88_row13_col2,#T_6ef88_row13_col3,#T_6ef88_row13_col4,#T_6ef88_row13_col5,#T_6ef88_row13_col6,#T_6ef88_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_6ef88_row0_col1,#T_6ef88_row0_col5,#T_6ef88_row0_col6,#T_6ef88_row0_col7,#T_6ef88_row5_col2,#T_6ef88_row6_col4,#T_6ef88_row9_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6ef88_row0_col8,#T_6ef88_row1_col8,#T_6ef88_row2_col8,#T_6ef88_row3_col8,#T_6ef88_row4_col8,#T_6ef88_row5_col8,#T_6ef88_row7_col8,#T_6ef88_row8_col8,#T_6ef88_row9_col8,#T_6ef88_row10_col8,#T_6ef88_row11_col8,#T_6ef88_row12_col8,#T_6ef88_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_6ef88_row6_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6ef88_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ef88_level0_row0" class="row_heading level0 row0" >gbc</th>
#                         <td id="T_6ef88_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_6ef88_row0_col1" class="data row0 col1" >0.7844</td>
#                         <td id="T_6ef88_row0_col2" class="data row0 col2" >0.7855</td>
#                         <td id="T_6ef88_row0_col3" class="data row0 col3" >0.9615</td>
#                         <td id="T_6ef88_row0_col4" class="data row0 col4" >0.7419</td>
#                         <td id="T_6ef88_row0_col5" class="data row0 col5" >0.8370</td>
#                         <td id="T_6ef88_row0_col6" class="data row0 col6" >0.5342</td>
#                         <td id="T_6ef88_row0_col7" class="data row0 col7" >0.5766</td>
#                         <td id="T_6ef88_row0_col8" class="data row0 col8" >0.1250</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef88_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_6ef88_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_6ef88_row1_col1" class="data row1 col1" >0.7519</td>
#                         <td id="T_6ef88_row1_col2" class="data row1 col2" >0.7748</td>
#                         <td id="T_6ef88_row1_col3" class="data row1 col3" >0.9299</td>
#                         <td id="T_6ef88_row1_col4" class="data row1 col4" >0.7203</td>
#                         <td id="T_6ef88_row1_col5" class="data row1 col5" >0.8114</td>
#                         <td id="T_6ef88_row1_col6" class="data row1 col6" >0.4656</td>
#                         <td id="T_6ef88_row1_col7" class="data row1 col7" >0.5013</td>
#                         <td id="T_6ef88_row1_col8" class="data row1 col8" >0.1590</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef88_level0_row2" class="row_heading level0 row2" >nb</th>
#                         <td id="T_6ef88_row2_col0" class="data row2 col0" >Naive Bayes</td>
#                         <td id="T_6ef88_row2_col1" class="data row2 col1" >0.7312</td>
#                         <td id="T_6ef88_row2_col2" class="data row2 col2" >0.7508</td>
#                         <td id="T_6ef88_row2_col3" class="data row2 col3" >0.9932</td>
#                         <td id="T_6ef88_row2_col4" class="data row2 col4" >0.6835</td>
#                         <td id="T_6ef88_row2_col5" class="data row2 col5" >0.8095</td>
#                         <td id="T_6ef88_row2_col6" class="data row2 col6" >0.4024</td>
#                         <td id="T_6ef88_row2_col7" class="data row2 col7" >0.4952</td>
#                         <td id="T_6ef88_row2_col8" class="data row2 col8" >0.0270</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef88_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_6ef88_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_6ef88_row3_col1" class="data row3 col1" >0.7390</td>
#                         <td id="T_6ef88_row3_col2" class="data row3 col2" >0.7909</td>
#                         <td id="T_6ef88_row3_col3" class="data row3 col3" >0.8440</td>
#                         <td id="T_6ef88_row3_col4" class="data row3 col4" >0.7403</td>
#                         <td id="T_6ef88_row3_col5" class="data row3 col5" >0.7878</td>
#                         <td id="T_6ef88_row3_col6" class="data row3 col6" >0.4525</td>
#                         <td id="T_6ef88_row3_col7" class="data row3 col7" >0.4611</td>
#                         <td id="T_6ef88_row3_col8" class="data row3 col8" >0.6300</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef88_level0_row4" class="row_heading level0 row4" >ada</th>
#                         <td id="T_6ef88_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#                         <td id="T_6ef88_row4_col1" class="data row4 col1" >0.7338</td>
#                         <td id="T_6ef88_row4_col2" class="data row4 col2" >0.7420</td>
#                         <td id="T_6ef88_row4_col3" class="data row4 col3" >0.8485</td>
#                         <td id="T_6ef88_row4_col4" class="data row4 col4" >0.7328</td>
#                         <td id="T_6ef88_row4_col5" class="data row4 col5" >0.7856</td>
#                         <td id="T_6ef88_row4_col6" class="dat

# %% [markdown]
# ## Now we can create the best model based on performance and train and evaluate the model. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold which by default is set to 10.

# %%
best_model = create_model(model_matrix)
# Out:
# <style  type="text/css" >
# #T_2604f_row10_col0,#T_2604f_row10_col1,#T_2604f_row10_col2,#T_2604f_row10_col3,#T_2604f_row10_col4,#T_2604f_row10_col5,#T_2604f_row10_col6{
#             background:  yellow;
#         }</style><table id="T_2604f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2604f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2604f_row0_col0" class="data row0 col0" >0.8182</td>
#                         <td id="T_2604f_row0_col1" class="data row0 col1" >0.7738</td>
#                         <td id="T_2604f_row0_col2" class="data row0 col2" >0.9545</td>
#                         <td id="T_2604f_row0_col3" class="data row0 col3" >0.7778</td>
#                         <td id="T_2604f_row0_col4" class="data row0 col4" >0.8571</td>
#                         <td id="T_2604f_row0_col5" class="data row0 col5" >0.6142</td>
#                         <td id="T_2604f_row0_col6" class="data row0 col6" >0.6389</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2604f_row1_col0" class="data row1 col0" >0.7662</td>
#                         <td id="T_2604f_row1_col1" class="data row1 col1" >0.8182</td>
#                         <td id="T_2604f_row1_col2" class="data row1 col2" >0.9545</td>
#                         <td id="T_2604f_row1_col3" class="data row1 col3" >0.7241</td>
#                         <td id="T_2604f_row1_col4" class="data row1 col4" >0.8235</td>
#                         <td id="T_2604f_row1_col5" class="data row1 col5" >0.4960</td>
#                         <td id="T_2604f_row1_col6" class="data row1 col6" >0.5392</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2604f_row2_col0" class="data row2 col0" >0.7143</td>
#                         <td id="T_2604f_row2_col1" class="data row2 col1" >0.7028</td>
#                         <td id="T_2604f_row2_col2" class="data row2 col2" >0.9773</td>
#                         <td id="T_2604f_row2_col3" class="data row2 col3" >0.6719</td>
#                         <td id="T_2604f_row2_col4" class="data row2 col4" >0.7963</td>
#                         <td id="T_2604f_row2_col5" class="data row2 col5" >0.3689</td>
#                         <td id="T_2604f_row2_col6" class="data row2 col6" >0.4504</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2604f_row3_col0" class="data row3 col0" >0.7662</td>
#                         <td id="T_2604f_row3_col1" class="data row3 col1" >0.7545</td>
#                         <td id="T_2604f_row3_col2" class="data row3 col2" >0.9545</td>
#                         <td id="T_2604f_row3_col3" class="data row3 col3" >0.7241</td>
#                         <td id="T_2604f_row3_col4" class="data row3 col4" >0.8235</td>
#                         <td id="T_2604f_row3_col5" class="data row3 col5" >0.4960</td>
#                         <td id="T_2604f_row3_col6" class="data row3 col6" >0.5392</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2604f_row4_col0" class="data row4 col0" >0.8182</td>
#                         <td id="T_2604f_row4_col1" class="data row4 col1" >0.8402</td>
#                         <td id="T_2604f_row4_col2" class="data row4 col2" >0.9773</td>
#                         <td id="T_2604f_row4_col3" class="data row4 col3" >0.7679</td>
#                         <td id="T_2604f_row4_col4" class="data row4 col4" >0.8600</td>
#                         <td id="T_2604f_row4_col5" class="data row4 col5" >0.6111</td>
#                         <td id="T_2604f_row4_col6" class="data row4 col6" >0.6482</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2604f_row5_col0" class="data row5 col0" >0.7792</td>
#                         <td id="T_2604f_row5_col1" class="data row5 col1" >0.8237</td>
#                         <td id="T_2604f_row5_col2" class="data row5 col2" >0.9773</td>
#                         <td id="T_2604f_row5_col3" class="data row5 col3" >0.7288</td>
#                         <td id="T_2604f_row5_col4" class="data row5 col4" >0.8350</td>
#                         <td id="T_2604f_row5_col5" class="data row5 col5" >0.5221</td>
#                         <td id="T_2604f_row5_col6" class="data row5 col6" >0.5758</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2604f_row6_col0" class="data row6 col0" >0.8182</td>
#                         <td id="T_2604f_row6_col1" class="data row6 col1" >0.7972</td>
#                         <td id="T_2604f_row6_col2" class="data row6 col2" >0.9545</td>
#                         <td id="T_2604f_row6_col3" class="data row6 col3" >0.7778</td>
#                         <td id="T_2604f_row6_col4" class="data row6 col4" >0.8571</td>
#                         <td id="T_2604f_row6_col5" class="data row6 col5" >0.6142</td>
#                         <td id="T_2604f_row6_col6" class="data row6 col6" >0.6389</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2604f_row7_col0" class="data row7 col0" >0.7792</td>
#                         <td id="T_2604f_row7_col1" class="data row7 col1" >0.8113</td>
#                         <td id="T_2604f_row7_col2" class="data row7 col2" >0.9091</td>
#                         <td id="T_2604f_row7_col3" class="data row7 col3" >0.7547</td>
#                         <td id="T_2604f_row7_col4" class="data row7 col4" >0.8247</td>
#                         <td id="T_2604f_row7_col5" class="data row7 col5" >0.5333</td>
#                         <td id="T_2604f_row7_col6" class="data row7 col6" >0.5504</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2604f_row8_col0" class="data row8 col0" >0.8052</td>
#                         <td id="T_2604f_row8_col1" class="data row8 col1" >0.7840</td>
#                         <td id="T_2604f_row8_col2" class="data row8 col2" >0.9778</td>
#                         <td id="T_2604f_row8_col3" class="data row8 col3" >0.7586</td>
#                         <td id="T_2604f_row8_col4" class="data row8 col4" >0.8544</td>
#                         <td id="T_2604f_row8_col5" class="data row8 col5" >0.5740</td>
#                         <td id="T_2604f_row8_col6" class="data row8 col6" >0.6176</td>
#             </tr>
#             <tr>
#                         <th id="T_2604f_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2604f_row9_col0" class="data row9 col0" >0.7792</td>
#                         <td id="T_2604f_row9_col1" class="data row9 col1" >0.7497</td>
#                         <td id="T_2604f_row9_col2" class="data row9 col2" >0.9778</td>
#                         <td id="T_2604f_row9_col3" class="data row9 col3" >0.7333</td>
#                         <td id="T_2604f_row9_col4" class="data row9 col4" >0.8381</td>
#                         <td id="T_2604f_row9_col5" class="data row9 col5" >0.5125</td>
#                         <td id=

# %%
type(best_model)
# Out:
# sklearn.ensemble._gb.GradientBoostingClassifier

# %% [markdown]
# ## Now let's tune the model. In order to tune hyperparameters, the tune_model function is used. This function automatically tunes the hyperparameters of a model using Random Grid Search on a pre-defined search space. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold.

# %%
tuned_model = tune_model(best_model, optimize = 'F1')
# Out:
# <style  type="text/css" >
# #T_3c1cf_row10_col0,#T_3c1cf_row10_col1,#T_3c1cf_row10_col2,#T_3c1cf_row10_col3,#T_3c1cf_row10_col4,#T_3c1cf_row10_col5,#T_3c1cf_row10_col6{
#             background:  yellow;
#         }</style><table id="T_3c1cf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3c1cf_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3c1cf_row0_col0" class="data row0 col0" >0.8052</td>
#                         <td id="T_3c1cf_row0_col1" class="data row0 col1" >0.8051</td>
#                         <td id="T_3c1cf_row0_col2" class="data row0 col2" >0.9545</td>
#                         <td id="T_3c1cf_row0_col3" class="data row0 col3" >0.7636</td>
#                         <td id="T_3c1cf_row0_col4" class="data row0 col4" >0.8485</td>
#                         <td id="T_3c1cf_row0_col5" class="data row0 col5" >0.5850</td>
#                         <td id="T_3c1cf_row0_col6" class="data row0 col6" >0.6141</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3c1cf_row1_col0" class="data row1 col0" >0.7792</td>
#                         <td id="T_3c1cf_row1_col1" class="data row1 col1" >0.8113</td>
#                         <td id="T_3c1cf_row1_col2" class="data row1 col2" >0.9545</td>
#                         <td id="T_3c1cf_row1_col3" class="data row1 col3" >0.7368</td>
#                         <td id="T_3c1cf_row1_col4" class="data row1 col4" >0.8317</td>
#                         <td id="T_3c1cf_row1_col5" class="data row1 col5" >0.5259</td>
#                         <td id="T_3c1cf_row1_col6" class="data row1 col6" >0.5643</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3c1cf_row2_col0" class="data row2 col0" >0.7013</td>
#                         <td id="T_3c1cf_row2_col1" class="data row2 col1" >0.6722</td>
#                         <td id="T_3c1cf_row2_col2" class="data row2 col2" >0.9318</td>
#                         <td id="T_3c1cf_row2_col3" class="data row2 col3" >0.6721</td>
#                         <td id="T_3c1cf_row2_col4" class="data row2 col4" >0.7810</td>
#                         <td id="T_3c1cf_row2_col5" class="data row2 col5" >0.3482</td>
#                         <td id="T_3c1cf_row2_col6" class="data row2 col6" >0.3973</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3c1cf_row3_col0" class="data row3 col0" >0.7662</td>
#                         <td id="T_3c1cf_row3_col1" class="data row3 col1" >0.7941</td>
#                         <td id="T_3c1cf_row3_col2" class="data row3 col2" >0.9091</td>
#                         <td id="T_3c1cf_row3_col3" class="data row3 col3" >0.7407</td>
#                         <td id="T_3c1cf_row3_col4" class="data row3 col4" >0.8163</td>
#                         <td id="T_3c1cf_row3_col5" class="data row3 col5" >0.5039</td>
#                         <td id="T_3c1cf_row3_col6" class="data row3 col6" >0.5242</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3c1cf_row4_col0" class="data row4 col0" >0.7792</td>
#                         <td id="T_3c1cf_row4_col1" class="data row4 col1" >0.7865</td>
#                         <td id="T_3c1cf_row4_col2" class="data row4 col2" >0.9091</td>
#                         <td id="T_3c1cf_row4_col3" class="data row4 col3" >0.7547</td>
#                         <td id="T_3c1cf_row4_col4" class="data row4 col4" >0.8247</td>
#                         <td id="T_3c1cf_row4_col5" class="data row4 col5" >0.5333</td>
#                         <td id="T_3c1cf_row4_col6" class="data row4 col6" >0.5504</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3c1cf_row5_col0" class="data row5 col0" >0.7273</td>
#                         <td id="T_3c1cf_row5_col1" class="data row5 col1" >0.8278</td>
#                         <td id="T_3c1cf_row5_col2" class="data row5 col2" >0.9318</td>
#                         <td id="T_3c1cf_row5_col3" class="data row5 col3" >0.6949</td>
#                         <td id="T_3c1cf_row5_col4" class="data row5 col4" >0.7961</td>
#                         <td id="T_3c1cf_row5_col5" class="data row5 col5" >0.4096</td>
#                         <td id="T_3c1cf_row5_col6" class="data row5 col6" >0.4518</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3c1cf_row6_col0" class="data row6 col0" >0.7532</td>
#                         <td id="T_3c1cf_row6_col1" class="data row6 col1" >0.8182</td>
#                         <td id="T_3c1cf_row6_col2" class="data row6 col2" >0.8864</td>
#                         <td id="T_3c1cf_row6_col3" class="data row6 col3" >0.7358</td>
#                         <td id="T_3c1cf_row6_col4" class="data row6 col4" >0.8041</td>
#                         <td id="T_3c1cf_row6_col5" class="data row6 col5" >0.4784</td>
#                         <td id="T_3c1cf_row6_col6" class="data row6 col6" >0.4937</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3c1cf_row7_col0" class="data row7 col0" >0.7662</td>
#                         <td id="T_3c1cf_row7_col1" class="data row7 col1" >0.8264</td>
#                         <td id="T_3c1cf_row7_col2" class="data row7 col2" >0.8636</td>
#                         <td id="T_3c1cf_row7_col3" class="data row7 col3" >0.7600</td>
#                         <td id="T_3c1cf_row7_col4" class="data row7 col4" >0.8085</td>
#                         <td id="T_3c1cf_row7_col5" class="data row7 col5" >0.5116</td>
#                         <td id="T_3c1cf_row7_col6" class="data row7 col6" >0.5185</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3c1cf_row8_col0" class="data row8 col0" >0.7532</td>
#                         <td id="T_3c1cf_row8_col1" class="data row8 col1" >0.7965</td>
#                         <td id="T_3c1cf_row8_col2" class="data row8 col2" >0.8444</td>
#                         <td id="T_3c1cf_row8_col3" class="data row8 col3" >0.7600</td>
#                         <td id="T_3c1cf_row8_col4" class="data row8 col4" >0.8000</td>
#                         <td id="T_3c1cf_row8_col5" class="data row8 col5" >0.4803</td>
#                         <td id="T_3c1cf_row8_col6" class="data row8 col6" >0.4848</td>
#             </tr>
#             <tr>
#                         <th id="T_3c1cf_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3c1cf_row9_col0" class="data row9 col0" >0.7532</td>
#                         <td id="T_3c1cf_row9_col1" class="data row9 col1" >0.7917</td>
#                         <td id="T_3c1cf_row9_col2" class="data row9 col2" >0.8889</td>
#                         <td id="T_3c1cf_row9_col3" class="data row9 col3" >0.7407</td>
#                         <td id="T_3c1cf_row9_col4" class="data row9 col4" >0.8081</td>
#                         <td id="T_3c1cf_row9_col5" class="data row9 col5" >0.4705</td>
#                         <td id=

# %% [markdown]
# ## Let's plot the feature importance. The plot_model() function can be used to analyze the  feature Importance etc. This function takes a trained model object and returns a plot based on the test / hold-out set.

# %%
plot_model(tuned_model, plot='feature')

# %% [markdown]
# ## Now we can predict on the test / evaluation sample. Before finalizing the model, it is advisable to perform one final check by predicting the test/evaluation set and reviewing the evaluation metrics.

# %%
predict_model(tuned_model)

unseen_predictions = predict_model(tuned_model, data=df_eval)
unseen_predictions.head()
# Out:
# <style  type="text/css" >
# </style><table id="T_91a50_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_91a50_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_91a50_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_91a50_row0_col1" class="data row0 col1" >0.7824</td>
#                         <td id="T_91a50_row0_col2" class="data row0 col2" >0.7946</td>
#                         <td id="T_91a50_row0_col3" class="data row0 col3" >0.9008</td>
#                         <td id="T_91a50_row0_col4" class="data row0 col4" >0.8027</td>
#                         <td id="T_91a50_row0_col5" class="data row0 col5" >0.8489</td>
#                         <td id="T_91a50_row0_col6" class="data row0 col6" >0.4646</td>
#                         <td id="T_91a50_row0_col7" class="data row0 col7" >0.4746</td>
#             </tr>
#     </tbody></table>
#    dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 3            303658983        3          0.313869     1561.8       18.21
# 5            272911264        0          0.378472       2088        4.02
# 13           272869206        0          0.367816     761.25       75.91
# 17           272872610        3          0.104167       1152        29.3
# 48           272820865        0          0.722222       1152       42.92
#
#     source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 3            1460                197               2               2
# 5            1460                 23               3               2
# 13            305                160               1               1
# 17            294                149               0               0
# 48            362                217              11               1
#
#     missed_games_over_2  isnextyear_buyer  Label   Score
# 3                     3                 1      1  0.7825
# 5                     7                 1      1  0.9032
# 13                    5                 1      0  0.9098
# 17                    2                 1      0  0.9206
# 48                    3                 1      0  0.6248

# %% [markdown]
# ## Let's finalize the model for deployment. The finalize_model() function fits the model onto the complete dataset including the test/evaluation sample (10% in this case). The purpose of this function is to train the model on the complete dataset before it is deployed in production.

# %%
final_model = finalize_model(tuned_model)
# Out:
# <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>

# %% [markdown]
# ## We can now save the final model. PyCaret's inbuilt function save_model() allows you to save the model along with entire transformation pipeline for later use.

# %%
save_model(final_model,'../models/QA-MILB-Team-Based-Retention-Model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='isnextyear_buyer',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  num...
#                                              learning_rate=0.01, loss='deviance',
#                                              max_depth=9, max_features=1.0,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.001,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=3,
#                                              min_samples_split=5,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=270,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=6882, subsample=0.75,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  '../models/QA-MILB-Team-Based-Retention-Model.pkl')

# %% [markdown]
# ## Now that we have an exported model we can use it to score new data. To load a saved model at a future date in the same or an alternative environment, we would use PyCaret's load_model() function and then easily apply the saved model on new unseen data for prediction.

# %%
saved_final_model = load_model('../models/QA-MILB-Team-Based-Retention-Model')

new_prediction = predict_model(saved_final_model, data=df_eval)
new_prediction.head()
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 3            303658983        3          0.313869     1561.8       18.21
# 5            272911264        0          0.378472       2088        4.02
# 13           272869206        0          0.367816     761.25       75.91
# 17           272872610        3          0.104167       1152        29.3
# 48           272820865        0          0.722222       1152       42.92
#
#     source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 3            1460                197               2               2
# 5            1460                 23               3               2
# 13            305                160               1               1
# 17            294                149               0               0
# 48            362                217              11               1
#
#     missed_games_over_2  isnextyear_buyer  Label   Score
# 3                     3                 1      1  0.8282
# 5                     7                 1      1  0.8697
# 13                    5                 1      0  0.8796
# 17                    2                 1      0  0.8328
# 48                    3                 1      1  0.5935

# %%
saved_final_model._final_estimator.feature_importances_
# Out:
# array([4.34028065e-01, 4.42733004e-02, 8.76080050e-02, 1.72641730e-01,
#        1.19909393e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.73947796e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.51990182e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.05166181e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.66778701e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.06714066e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.26981391e-05, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.47469024e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.55509855e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 8.30649517e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.80071239e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.58315927e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.29864764e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.39074951e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.39594867e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.15410487e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 7.96958680e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.57478482e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.19975929e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.88406514e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.20749164e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.39500154e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.61167249e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.87674414e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.49000688e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.49325200e-03,
#        4.17845029e-03, 7.07883886e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.71091013e-04, 3.19734543e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.20711034e-05, 6.61568270e-03, 4.52289867e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16009792e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 7.17511327e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.39919065e-05, 2.57928649e-03, 0.00000000e+00,
#        1.42770188e-03, 7.86350891e-04, 8.11851764e-05, 0.00000000e+00,
#        1.16126146e-03, 3.20073789e-03, 9.61708285e-04, 0.00000000e+00,
#        2.25843013e-05, 0.00000000e+00, 3.29561625e-03, 0.00000000e+00,
#        0.00000000e+00, 1.02779497e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.25375830e-03,
#        6.70607055e-05, 1.05127223e-04, 1.74150721e-04, 1.23954199e-03,
#        7.97176005e-04, 1.68789056e-05, 9.39844770e-07, 1.16843324e-04,
#        1.96004530e-04, 1.61680302e-03, 0.00000000e+00, 1.70993163e-05,
#        1.69618071e-04, 0.00000000e+00, 1.11960090e-04, 0.00000000e+00,
#        1.81915810e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.49711547e-04, 2.38279537e-04, 0.00000000e+00, 0.00000000e+00,
#        2.18031583e-04, 4.70922175e-04, 1.04959858e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.26695626e-03,
#        0.00000000e+00, 1.93085645e-03, 7.51895416e-04, 1.35026851e-03,
#        4.08278979e-05, 1.85350318e-04, 0.00000000e+00, 0.00000000e+00,
#        2.05672839e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.59416083e-03, 0.00000000e+00, 6.88868661e-03,
#        2.72848559e-03, 8.50318060e-04, 1.85231482e-04, 3.97391601e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.68853046e-03,
#        2.34192587e-03, 3.40233762e-03, 4.40320471e-03, 4.73463481e-03,
#        4.29225463e-03, 1.28570116e-03, 6.55102707e-03, 6.81780719e-03,
#        1.41767657e-02, 9.85766214e-03, 7.45253603e-03, 3.42720042e-03,
#        1.73208297e-03, 1.44874566e-03, 4.69427152e-04, 0.00000000e+00,
#        0.00000000e+00, 6.93640396e-04, 2.28855294e-03, 2.52584344e-03,
#        0.00000000e+00, 3.16696397e-03, 2.37381301e-03, 1.38353570e-02,
#        7.47866854e-03, 3.76568461e-03, 3.23102334e-03, 4.68364405e-03,
#        1.77182315e-03])

# %% [markdown]
# ## FIN!!
