# %% [markdown]
# # MILB Team Based Retention Model (QA)
#
# * Stellar Algo
# * Nakiska Rad & Ryan Kazmerik
# * August 31, 2021

# %%
import getpass
import pyodbc
import pandas as pd
import numpy as np

import warnings

from pycaret.classification import *

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Let's get our dataset from MSSQL. We will select the full season product only and seasons before 2020, since 2020 was a strange year due to covid, and 2021 does not have any repurchasing data available

# %%
SERVER = '52.44.171.130' 
DATABASE = 'datascience' 
USERNAME = getpass.getpass(prompt='Enter your username') 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your username········
# Enter your password········
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /var/folders/kp/vwm5bxcd72j3yf54l1xtsts80000gp/T/ipykernel_72908/3609989251.py in <module>
#       3 USERNAME = getpass.getpass(prompt='Enter your username')
#       4 PASSWORD = getpass.getpass(prompt='Enter your password')
# ----> 5 CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
#
# InterfaceError: ('28000', "[28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Login failed for user 'dsWrite'. (18456) (SQLDriverConnect)")

# %%
cursor = CNXN.cursor()

client_id = 11 #bulls
product = "Full Season"
train_season_year = 2019
test_season_year = 2021

query =  f"""
    SELECT 
        r.dimcustomermasterid,
        recency,
        attendancePercent,
        totalSpent,
        distToVenue,
        source_tenure,
        renewedBeforeDays,
        missed_games_1,
        missed_games_2,
        missed_games_over_2,
        isnextyear_buyer
    FROM 
        ds.retentionscoring r 
    WHERE 
        lkupclientid = {client_id} 
    AND 
        productgrouping = {"'"+ str(product) + "'"} 
    AND 
        year < {train_season_year};
    """
    
df = pd.read_sql(query, CNXN)
    
CNXN.commit()
cursor.close()

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dimcustomermasterid  1070 non-null   object
#  1   recency              1070 non-null   int64
#  2   attendancePercent    1070 non-null   object
#  3   totalSpent           1070 non-null   object
#  4   distToVenue          1070 non-null   object
#  5   source_tenure        1070 non-null   int64
#  6   renewedBeforeDays    1070 non-null   int64
#  7   missed_games_1       1070 non-null   int64
#  8   missed_games_2       1070 non-null   int64
#  9   missed_games_over_2  1070 non-null   int64
#  10  isnextyear_buyer     1070 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 92.1+ KB
#   dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 0           303661788        0          0.580986       2485       26.49
# 1           303663474        1          0.527778       4032       23.92
# 2           303659570        0          0.548611     1641.6       24.07
# 3           303658983        3          0.313869     1561.8       18.21
# 4           303659912        0          0.280992     1379.4        5.16
#
#    source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 0           1460                  8               8               8
# 1           1460                198               0               2
# 2           1460                185              14               4
# 3           1460                197               2               2
# 4           1460                202               0               0
#
#    missed_games_over_2  isnextyear_buyer
# 0                    3                 1
# 1                    7                 1
# 2                    3                 1
# 3                    3                 1
# 4                    4                 1

# %% [markdown]
# ## We need to hold back some samples from the dataset for evalution, so let's create the training and evaluation dataset with a hold-back of 10%.

# %%
df_train = df.sample(frac=0.9, random_state=786)
df_eval = df.drop(df_train.index)

print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape))
# Out:
# Data for Modeling: (963, 11)
# Unseen Data For Predictions: (107, 11)

# %% [markdown]
# ## Now we can model the data using PyCaret, with a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
model = setup(df_train, target='isnextyear_buyer', train_size = 0.8)
# Out:
# <style type="text/css">
# #T_caa21_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_caa21_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caa21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caa21_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_caa21_row0_col1" class="data row0 col1" >4070</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_caa21_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_caa21_row1_col1" class="data row1 col1" >isnextyear_buyer</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_caa21_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_caa21_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_caa21_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_caa21_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_caa21_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_caa21_row4_col1" class="data row4 col1" >(963, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_caa21_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_caa21_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_caa21_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_caa21_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_caa21_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_caa21_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_caa21_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_caa21_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_caa21_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_caa21_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_caa21_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_caa21_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_caa21_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_caa21_row11_col1" class="data row11 col1" >(770, 837)</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_caa21_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_caa21_row12_col1" class="data row12 col1" >(193, 837)</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_caa21_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_caa21_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_caa21_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_caa21_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_caa21_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_caa21_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_caa21_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_caa21_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_caa21_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_caa21_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_caa21_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_caa21_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_caa21_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_caa21_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_caa21_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_caa21_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_caa21_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_caa21_row21_col1" class="data row21 col1" >2f9e</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_caa21_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_caa21_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_caa21_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_caa21_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_caa21_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_caa21_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_caa21_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_caa21_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_caa21_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_caa21_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_caa21_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_caa21_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_caa21_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_caa21_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_caa21_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_caa21_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_caa21_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_caa21_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_caa21_row30_col1" class="data row30 col1" >None</td>
#     <

# %% [markdown]
# ## Now we can compare all models to evaluate performance. This function trains all models in the model library and scores them using k-fold cross validation for metric evaluation. The output prints a score grid that shows average MAE, MSE, RMSE, R2, RMSLE and MAPE accross the folds (10 by default) along with training time.

# %%
model_matrix = compare_models(fold=10, sort="F1")
# Out:
# <style type="text/css">
# #T_546be_ th {
#   text-align: left;
# }
# #T_546be_row0_col0, #T_546be_row0_col3, #T_546be_row0_col4, #T_546be_row1_col0, #T_546be_row1_col1, #T_546be_row1_col2, #T_546be_row1_col3, #T_546be_row1_col4, #T_546be_row1_col5, #T_546be_row1_col6, #T_546be_row1_col7, #T_546be_row2_col0, #T_546be_row2_col1, #T_546be_row2_col2, #T_546be_row2_col3, #T_546be_row2_col4, #T_546be_row2_col5, #T_546be_row2_col6, #T_546be_row2_col7, #T_546be_row3_col0, #T_546be_row3_col1, #T_546be_row3_col2, #T_546be_row3_col3, #T_546be_row3_col4, #T_546be_row3_col5, #T_546be_row3_col6, #T_546be_row3_col7, #T_546be_row4_col0, #T_546be_row4_col1, #T_546be_row4_col2, #T_546be_row4_col3, #T_546be_row4_col4, #T_546be_row4_col5, #T_546be_row4_col6, #T_546be_row4_col7, #T_546be_row5_col0, #T_546be_row5_col1, #T_546be_row5_col2, #T_546be_row5_col3, #T_546be_row5_col4, #T_546be_row5_col5, #T_546be_row5_col6, #T_546be_row5_col7, #T_546be_row6_col0, #T_546be_row6_col1, #T_546be_row6_col2, #T_546be_row6_col3, #T_546be_row6_col5, #T_546be_row6_col6, #T_546be_row6_col7, #T_546be_row7_col0, #T_546be_row7_col1, #T_546be_row7_col2, #T_546be_row7_col3, #T_546be_row7_col4, #T_546be_row7_col5, #T_546be_row7_col6, #T_546be_row7_col7, #T_546be_row8_col0, #T_546be_row8_col1, #T_546be_row8_col2, #T_546be_row8_col3, #T_546be_row8_col4, #T_546be_row8_col5, #T_546be_row8_col6, #T_546be_row8_col7, #T_546be_row9_col0, #T_546be_row9_col1, #T_546be_row9_col2, #T_546be_row9_col4, #T_546be_row9_col5, #T_546be_row9_col6, #T_546be_row9_col7, #T_546be_row10_col0, #T_546be_row10_col1, #T_546be_row10_col2, #T_546be_row10_col3, #T_546be_row10_col4, #T_546be_row10_col5, #T_546be_row10_col6, #T_546be_row10_col7, #T_546be_row11_col0, #T_546be_row11_col1, #T_546be_row11_col2, #T_546be_row11_col3, #T_546be_row11_col4, #T_546be_row11_col5, #T_546be_row11_col6, #T_546be_row11_col7, #T_546be_row12_col0, #T_546be_row12_col1, #T_546be_row12_col2, #T_546be_row12_col3, #T_546be_row12_col4, #T_546be_row12_col5, #T_546be_row12_col6, #T_546be_row12_col7, #T_546be_row13_col0, #T_546be_row13_col1, #T_546be_row13_col2, #T_546be_row13_col3, #T_546be_row13_col4, #T_546be_row13_col5, #T_546be_row13_col6, #T_546be_row13_col7 {
#   text-align: left;
# }
# #T_546be_row0_col1, #T_546be_row0_col2, #T_546be_row0_col5, #T_546be_row0_col6, #T_546be_row0_col7, #T_546be_row6_col4, #T_546be_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_546be_row0_col8, #T_546be_row1_col8, #T_546be_row2_col8, #T_546be_row3_col8, #T_546be_row4_col8, #T_546be_row5_col8, #T_546be_row8_col8, #T_546be_row9_col8, #T_546be_row10_col8, #T_546be_row11_col8, #T_546be_row12_col8, #T_546be_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_546be_row6_col8, #T_546be_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_546be_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_546be_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_546be_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_546be_row0_col1" class="data row0 col1" >0.7948</td>
#       <td id="T_546be_row0_col2" class="data row0 col2" >0.8161</td>
#       <td id="T_546be_row0_col3" class="data row0 col3" >0.9600</td>
#       <td id="T_546be_row0_col4" class="data row0 col4" >0.7561</td>
#       <td id="T_546be_row0_col5" class="data row0 col5" >0.8457</td>
#       <td id="T_546be_row0_col6" class="data row0 col6" >0.5518</td>
#       <td id="T_546be_row0_col7" class="data row0 col7" >0.5897</td>
#       <td id="T_546be_row0_col8" class="data row0 col8" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_546be_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_546be_row1_col1" class="data row1 col1" >0.7766</td>
#       <td id="T_546be_row1_col2" class="data row1 col2" >0.8076</td>
#       <td id="T_546be_row1_col3" class="data row1 col3" >0.9378</td>
#       <td id="T_546be_row1_col4" class="data row1 col4" >0.7479</td>
#       <td id="T_546be_row1_col5" class="data row1 col5" >0.8313</td>
#       <td id="T_546be_row1_col6" class="data row1 col6" >0.5129</td>
#       <td id="T_546be_row1_col7" class="data row1 col7" >0.5464</td>
#       <td id="T_546be_row1_col8" class="data row1 col8" >0.1540</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_546be_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_546be_row2_col1" class="data row2 col1" >0.7688</td>
#       <td id="T_546be_row2_col2" class="data row2 col2" >0.8098</td>
#       <td id="T_546be_row2_col3" class="data row2 col3" >0.8645</td>
#       <td id="T_546be_row2_col4" class="data row2 col4" >0.7700</td>
#       <td id="T_546be_row2_col5" class="data row2 col5" >0.8136</td>
#       <td id="T_546be_row2_col6" class="data row2 col6" >0.5108</td>
#       <td id="T_546be_row2_col7" class="data row2 col7" >0.5205</td>
#       <td id="T_546be_row2_col8" class="data row2 col8" >0.4470</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_546be_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_546be_row3_col1" class="data row3 col1" >0.7610</td>
#       <td id="T_546be_row3_col2" class="data row3 col2" >0.7853</td>
#       <td id="T_546be_row3_col3" class="data row3 col3" >0.8802</td>
#       <td id="T_546be_row3_col4" class="data row3 col4" >0.7539</td>
#       <td id="T_546be_row3_col5" class="data row3 col5" >0.8113</td>
#       <td id="T_546be_row3_col6" class="data row3 col6" >0.4900</td>
#       <td id="T_546be_row3_col7" class="data row3 col7" >0.5048</td>
#       <td id="T_546be_row3_col8" class="data row3 col8" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_546be_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_546be_row4_col1" class="data row4 col1" >0.7623</td>
#       <td id="T_546be_row4_col2" class="data row4 col2" >0.8151</td>
#       <td id="T_546be_row4_col3" class="data row4 col3" >0.8513</td>
#       <td id="T_546be_row4_col4" class="data row4 col4" >0.7694</td>
#       <td id="T_546be_row4_col5" class="data row4 col5" >0.8070</td>
#       <td id="T_546be_row4_col6" class="data row4 col6" >0.4985</td>
#       <td id="T_546be_row4_col7" class="data row4 col7" >0.5070</td>
#       <td id="T_546be_row4_col8" class="data row4 col8" >0.5440</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_546be_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_546be_row5_col1" class="data row5 col1" >0.7481</td>
#       <td id="T_546be_row5_col2" class="data row5 col2" >0.7866</td>
#       <td id="T_546be_row5_col3" class="data row5 col3" >0.8670</td>
#       <td id="T_546be_row5_col4" class="data row5 col4" >0.7471</td>
#       <td id="T_546be_row5_col5" class="data row5 col5" >0.8011</td>
#       <td id="T_546be_row5_col6" class="data row5 col6" >0.4622</td>
#       <td id="T_546be_row5_col7" class="data row5 col7" >0.4766</td>
#       <td id="T_546be_row5_col8" class="data row5 col8" >0.1420</td>
#     </tr>
#     <tr>
#       <th id="T_546be_level0_row6" class="row_heading level0 row6" >dt</th>
#       <td id="T_546be_row6_col0" class="data row6 col0

# %% [markdown]
# ## Now we can create the best model based on performance and train and evaluate the model. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold which by default is set to 10.

# %%
best_model = create_model(model_matrix)
# Out:
# <style type="text/css">
# #T_d2f36_row10_col0, #T_d2f36_row10_col1, #T_d2f36_row10_col2, #T_d2f36_row10_col3, #T_d2f36_row10_col4, #T_d2f36_row10_col5, #T_d2f36_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d2f36_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2f36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2f36_row0_col0" class="data row0 col0" >0.7792</td>
#       <td id="T_d2f36_row0_col1" class="data row0 col1" >0.8114</td>
#       <td id="T_d2f36_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_d2f36_row0_col3" class="data row0 col3" >0.7377</td>
#       <td id="T_d2f36_row0_col4" class="data row0 col4" >0.8411</td>
#       <td id="T_d2f36_row0_col5" class="data row0 col5" >0.5017</td>
#       <td id="T_d2f36_row0_col6" class="data row0 col6" >0.5586</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2f36_row1_col0" class="data row1 col0" >0.8442</td>
#       <td id="T_d2f36_row1_col1" class="data row1 col1" >0.8747</td>
#       <td id="T_d2f36_row1_col2" class="data row1 col2" >0.9778</td>
#       <td id="T_d2f36_row1_col3" class="data row1 col3" >0.8000</td>
#       <td id="T_d2f36_row1_col4" class="data row1 col4" >0.8800</td>
#       <td id="T_d2f36_row1_col5" class="data row1 col5" >0.6640</td>
#       <td id="T_d2f36_row1_col6" class="data row1 col6" >0.6917</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2f36_row2_col0" class="data row2 col0" >0.8312</td>
#       <td id="T_d2f36_row2_col1" class="data row2 col1" >0.7986</td>
#       <td id="T_d2f36_row2_col2" class="data row2 col2" >0.9778</td>
#       <td id="T_d2f36_row2_col3" class="data row2 col3" >0.7857</td>
#       <td id="T_d2f36_row2_col4" class="data row2 col4" >0.8713</td>
#       <td id="T_d2f36_row2_col5" class="data row2 col5" >0.6343</td>
#       <td id="T_d2f36_row2_col6" class="data row2 col6" >0.6670</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2f36_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_d2f36_row3_col1" class="data row3 col1" >0.8198</td>
#       <td id="T_d2f36_row3_col2" class="data row3 col2" >0.8667</td>
#       <td id="T_d2f36_row3_col3" class="data row3 col3" >0.7222</td>
#       <td id="T_d2f36_row3_col4" class="data row3 col4" >0.7879</td>
#       <td id="T_d2f36_row3_col5" class="data row3 col5" >0.4148</td>
#       <td id="T_d2f36_row3_col6" class="data row3 col6" >0.4285</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2f36_row4_col0" class="data row4 col0" >0.7662</td>
#       <td id="T_d2f36_row4_col1" class="data row4 col1" >0.7698</td>
#       <td id="T_d2f36_row4_col2" class="data row4 col2" >0.9556</td>
#       <td id="T_d2f36_row4_col3" class="data row4 col3" >0.7288</td>
#       <td id="T_d2f36_row4_col4" class="data row4 col4" >0.8269</td>
#       <td id="T_d2f36_row4_col5" class="data row4 col5" >0.4863</td>
#       <td id="T_d2f36_row4_col6" class="data row4 col6" >0.5305</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2f36_row5_col0" class="data row5 col0" >0.8182</td>
#       <td id="T_d2f36_row5_col1" class="data row5 col1" >0.8333</td>
#       <td id="T_d2f36_row5_col2" class="data row5 col2" >0.9556</td>
#       <td id="T_d2f36_row5_col3" class="data row5 col3" >0.7818</td>
#       <td id="T_d2f36_row5_col4" class="data row5 col4" >0.8600</td>
#       <td id="T_d2f36_row5_col5" class="data row5 col5" >0.6080</td>
#       <td id="T_d2f36_row5_col6" class="data row5 col6" >0.6333</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2f36_row6_col0" class="data row6 col0" >0.8052</td>
#       <td id="T_d2f36_row6_col1" class="data row6 col1" >0.8656</td>
#       <td id="T_d2f36_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_d2f36_row6_col3" class="data row6 col3" >0.7500</td>
#       <td id="T_d2f36_row6_col4" class="data row6 col4" >0.8571</td>
#       <td id="T_d2f36_row6_col5" class="data row6 col5" >0.5698</td>
#       <td id="T_d2f36_row6_col6" class="data row6 col6" >0.6312</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2f36_row7_col0" class="data row7 col0" >0.7922</td>
#       <td id="T_d2f36_row7_col1" class="data row7 col1" >0.8083</td>
#       <td id="T_d2f36_row7_col2" class="data row7 col2" >0.9556</td>
#       <td id="T_d2f36_row7_col3" class="data row7 col3" >0.7544</td>
#       <td id="T_d2f36_row7_col4" class="data row7 col4" >0.8431</td>
#       <td id="T_d2f36_row7_col5" class="data row7 col5" >0.5477</td>
#       <td id="T_d2f36_row7_col6" class="data row7 col6" >0.5822</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2f36_row8_col0" class="data row8 col0" >0.8052</td>
#       <td id="T_d2f36_row8_col1" class="data row8 col1" >0.8003</td>
#       <td id="T_d2f36_row8_col2" class="data row8 col2" >0.9778</td>
#       <td id="T_d2f36_row8_col3" class="data row8 col3" >0.7586</td>
#       <td id="T_d2f36_row8_col4" class="data row8 col4" >0.8544</td>
#       <td id="T_d2f36_row8_col5" class="data row8 col5" >0.5740</td>
#       <td id="T_d2f36_row8_col6" class="data row8 col6" >0.6176</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2f36_row9_col0" class="data row9 col0" >0.7792</td>
#       <td id="T_d2f36_row9_col1" class="data row9 col1" >0.7788</td>
#       <td id="T_d2f36_row9_col2" class="data row9 col2" >0.9556</td>
#       <td id="T_d2f36_row9_col3" class="data row9 col3" >0.7414</td>
#       <td id="T_d2f36_row9_col4" class="data row9 col4" >0.8350</td>
#       <td id="T_d2f36_row9_col5" class="data row9 col5" >0.5172</td>
#       <td id="T_d2f36_row9_col6" class="data row9 col6" >0.5565</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d2f36_row10_col0" class="data row10 col0" >0.7948</td>
#       <td id="T_d2f36_row10_col1" class="data row10 col1" >0.8161</td>
#       <td id="T_d2f36_row10_col2" class="data row10 col2" >0.9600</td>
#       <td id="T_d2f36_row10_col3" class="data row10 col3" >0.7561</td>
#       <td id="T_d2f36_row10_col4" class="data row10 col4" >0.8457</td>
#       <td id="T_d2f36_row10_col5" class="data row10 col5" >0.5518</td>
#       <td id="T_d2f36_row10_col6" class="data row10 col6" >0.5897</td>
#     </tr>
#     <tr>
#       <th id="T_d2f36_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_d2f36_row11_col0" class="data row11 col0" >0.0322</td>
#       <td id="T_d2f36_row11_col1" class="data row11 col1" >0.0322</td>
#       <td id="T_d2f36_row11_col2" class="data row11 col2" >0.0342</td>
#       <td id="T_d2f36_row11_col3" class="data row11 col3" >0.0244</td>
#       <td id="T_d2f36_row11_col4" class="data row11 col4" >0.0247</td>
#       <td id="T_d2f36_row11_col5" class="data row11 col5" >0.0708</td>
#       <td id="T_d2f36_row11_col6" class="data row11 col6" >0.0724</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Now let's tune the model. In order to tune hyperparameters, the tune_model function is used. This function automatically tunes the hyperparameters of a model using Random Grid Search on a pre-defined search space. The output prints a score grid that shows MAE, MSE, RMSE, R2, RMSLE and MAPE by fold.

# %%
tuned_model = tune_model(best_model, optimize = 'F1')
# Out:
# <style type="text/css">
# #T_abea7_row10_col0, #T_abea7_row10_col1, #T_abea7_row10_col2, #T_abea7_row10_col3, #T_abea7_row10_col4, #T_abea7_row10_col5, #T_abea7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_abea7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abea7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abea7_row0_col0" class="data row0 col0" >0.7792</td>
#       <td id="T_abea7_row0_col1" class="data row0 col1" >0.7356</td>
#       <td id="T_abea7_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_abea7_row0_col3" class="data row0 col3" >0.7302</td>
#       <td id="T_abea7_row0_col4" class="data row0 col4" >0.8440</td>
#       <td id="T_abea7_row0_col5" class="data row0 col5" >0.4960</td>
#       <td id="T_abea7_row0_col6" class="data row0 col6" >0.5742</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abea7_row1_col0" class="data row1 col0" >0.8182</td>
#       <td id="T_abea7_row1_col1" class="data row1 col1" >0.8729</td>
#       <td id="T_abea7_row1_col2" class="data row1 col2" >0.9778</td>
#       <td id="T_abea7_row1_col3" class="data row1 col3" >0.7719</td>
#       <td id="T_abea7_row1_col4" class="data row1 col4" >0.8627</td>
#       <td id="T_abea7_row1_col5" class="data row1 col5" >0.6043</td>
#       <td id="T_abea7_row1_col6" class="data row1 col6" >0.6423</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abea7_row2_col0" class="data row2 col0" >0.7922</td>
#       <td id="T_abea7_row2_col1" class="data row2 col1" >0.8354</td>
#       <td id="T_abea7_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_abea7_row2_col3" class="data row2 col3" >0.7377</td>
#       <td id="T_abea7_row2_col4" class="data row2 col4" >0.8491</td>
#       <td id="T_abea7_row2_col5" class="data row2 col5" >0.5389</td>
#       <td id="T_abea7_row2_col6" class="data row2 col6" >0.6073</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abea7_row3_col0" class="data row3 col0" >0.7403</td>
#       <td id="T_abea7_row3_col1" class="data row3 col1" >0.7236</td>
#       <td id="T_abea7_row3_col2" class="data row3 col2" >0.9556</td>
#       <td id="T_abea7_row3_col3" class="data row3 col3" >0.7049</td>
#       <td id="T_abea7_row3_col4" class="data row3 col4" >0.8113</td>
#       <td id="T_abea7_row3_col5" class="data row3 col5" >0.4237</td>
#       <td id="T_abea7_row3_col6" class="data row3 col6" >0.4774</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abea7_row4_col0" class="data row4 col0" >0.7532</td>
#       <td id="T_abea7_row4_col1" class="data row4 col1" >0.8285</td>
#       <td id="T_abea7_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_abea7_row4_col3" class="data row4 col3" >0.7031</td>
#       <td id="T_abea7_row4_col4" class="data row4 col4" >0.8257</td>
#       <td id="T_abea7_row4_col5" class="data row4 col5" >0.4444</td>
#       <td id="T_abea7_row4_col6" class="data row4 col6" >0.5345</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_abea7_row5_col0" class="data row5 col0" >0.8182</td>
#       <td id="T_abea7_row5_col1" class="data row5 col1" >0.7875</td>
#       <td id="T_abea7_row5_col2" class="data row5 col2" >0.9778</td>
#       <td id="T_abea7_row5_col3" class="data row5 col3" >0.7719</td>
#       <td id="T_abea7_row5_col4" class="data row5 col4" >0.8627</td>
#       <td id="T_abea7_row5_col5" class="data row5 col5" >0.6043</td>
#       <td id="T_abea7_row5_col6" class="data row5 col6" >0.6423</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_abea7_row6_col0" class="data row6 col0" >0.7403</td>
#       <td id="T_abea7_row6_col1" class="data row6 col1" >0.7639</td>
#       <td id="T_abea7_row6_col2" class="data row6 col2" >0.9778</td>
#       <td id="T_abea7_row6_col3" class="data row6 col3" >0.6984</td>
#       <td id="T_abea7_row6_col4" class="data row6 col4" >0.8148</td>
#       <td id="T_abea7_row6_col5" class="data row6 col5" >0.4180</td>
#       <td id="T_abea7_row6_col6" class="data row6 col6" >0.4907</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_abea7_row7_col0" class="data row7 col0" >0.7662</td>
#       <td id="T_abea7_row7_col1" class="data row7 col1" >0.7833</td>
#       <td id="T_abea7_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_abea7_row7_col3" class="data row7 col3" >0.7143</td>
#       <td id="T_abea7_row7_col4" class="data row7 col4" >0.8333</td>
#       <td id="T_abea7_row7_col5" class="data row7 col5" >0.4762</td>
#       <td id="T_abea7_row7_col6" class="data row7 col6" >0.5590</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_abea7_row8_col0" class="data row8 col0" >0.7403</td>
#       <td id="T_abea7_row8_col1" class="data row8 col1" >0.7792</td>
#       <td id="T_abea7_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_abea7_row8_col3" class="data row8 col3" >0.6923</td>
#       <td id="T_abea7_row8_col4" class="data row8 col4" >0.8182</td>
#       <td id="T_abea7_row8_col5" class="data row8 col5" >0.4122</td>
#       <td id="T_abea7_row8_col6" class="data row8 col6" >0.5095</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_abea7_row9_col0" class="data row9 col0" >0.7403</td>
#       <td id="T_abea7_row9_col1" class="data row9 col1" >0.7514</td>
#       <td id="T_abea7_row9_col2" class="data row9 col2" >0.9778</td>
#       <td id="T_abea7_row9_col3" class="data row9 col3" >0.6984</td>
#       <td id="T_abea7_row9_col4" class="data row9 col4" >0.8148</td>
#       <td id="T_abea7_row9_col5" class="data row9 col5" >0.4180</td>
#       <td id="T_abea7_row9_col6" class="data row9 col6" >0.4907</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_abea7_row10_col0" class="data row10 col0" >0.7688</td>
#       <td id="T_abea7_row10_col1" class="data row10 col1" >0.7861</td>
#       <td id="T_abea7_row10_col2" class="data row10 col2" >0.9867</td>
#       <td id="T_abea7_row10_col3" class="data row10 col3" >0.7223</td>
#       <td id="T_abea7_row10_col4" class="data row10 col4" >0.8337</td>
#       <td id="T_abea7_row10_col5" class="data row10 col5" >0.4836</td>
#       <td id="T_abea7_row10_col6" class="data row10 col6" >0.5528</td>
#     </tr>
#     <tr>
#       <th id="T_abea7_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_abea7_row11_col0" class="data row11 col0" >0.0301</td>
#       <td id="T_abea7_row11_col1" class="data row11 col1" >0.0447</td>
#       <td id="T_abea7_row11_col2" class="data row11 col2" >0.0147</td>
#       <td id="T_abea7_row11_col3" class="data row11 col3" >0.0283</td>
#       <td id="T_abea7_row11_col4" class="data row11 col4" >0.0188</td>
#       <td id="T_abea7_row11_col5" class="data row11 col5" >0.0716</td>
#       <td id="T_abea7_row11_col6" class="data row11 col6" >0.0593</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Let's plot the feature importance. The plot_model() function can be used to analyze the  feature Importance etc. This function takes a trained model object and returns a plot based on the test / hold-out set.

# %%
plot_model(tuned_model, plot='feature')

# %% [markdown]
# ## Now we can predict on the test / evaluation sample. Before finalizing the model, it is advisable to perform one final check by predicting the test/evaluation set and reviewing the evaluation metrics.

# %%
predict_model(tuned_model)

unseen_predictions = predict_model(tuned_model, data=df_eval)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5071a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5071a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5071a_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_5071a_row0_col1" class="data row0 col1" >0.7098</td>
#       <td id="T_5071a_row0_col2" class="data row0 col2" >0.7367</td>
#       <td id="T_5071a_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5071a_row0_col4" class="data row0 col4" >0.6725</td>
#       <td id="T_5071a_row0_col5" class="data row0 col5" >0.8042</td>
#       <td id="T_5071a_row0_col6" class="data row0 col6" >0.3189</td>
#       <td id="T_5071a_row0_col7" class="data row0 col7" >0.4355</td>
#     </tr>
#   </tbody>
# </table>
#    dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 3            303658983        3          0.313869     1561.8       18.21
# 5            272911264        0          0.378472       2088        4.02
# 13           272869206        0          0.367816     761.25       75.91
# 17           272872610        3          0.104167       1152        29.3
# 48           272820865        0          0.722222       1152       42.92
#
#     source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 3            1460                197               2               2
# 5            1460                 23               3               2
# 13            305                160               1               1
# 17            294                149               0               0
# 48            362                217              11               1
#
#     missed_games_over_2  isnextyear_buyer  Label   Score
# 3                     3                 1      1  0.6870
# 5                     7                 1      1  0.6954
# 13                    5                 1      0  0.5439
# 17                    2                 1      0  0.5150
# 48                    3                 1      1  0.5537
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/miniconda3/envs/stellar/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ## Let's finalize the model for deployment. The finalize_model() function fits the model onto the complete dataset including the test/evaluation sample (10% in this case). The purpose of this function is to train the model on the complete dataset before it is deployed in production.

# %%
final_model = finalize_model(tuned_model)

print(final_model)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.01, loss='deviance', max_depth=10,
#                            max_features='sqrt', max_leaf_nodes=None,
#                            min_impurity_decrease=0.0002,
#                            min_impurity_split=None, min_samples_leaf=3,
#                            min_samples_split=7, min_weight_fraction_leaf=0.0,
#                            n_estimators=270, n_iter_no_change=None,
#                            presort='deprecated', random_state=4070,
#                            subsample=0.25, tol=0.0001, validation_fraction=0.1,
#                            verbose=0, warm_start=False)

# %% [markdown]
# ## We can now save the final model. PyCaret's inbuilt function save_model() allows you to save the model along with entire transformation pipeline for later use.

# %%
save_model(final_model,'../models/QA-MILB-Team-Based-Retention-Model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='isnextyear_buyer',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  num...
#                                              learning_rate=0.01, loss='deviance',
#                                              max_depth=10, max_features='sqrt',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0002,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=3,
#                                              min_samples_split=7,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=270,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=4070, subsample=0.25,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  '../models/QA-MILB-Team-Based-Retention-Model.pkl')

# %% [markdown]
# ## Now that we have an exported model we can use it to score new data. To load a saved model at a future date in the same or an alternative environment, we would use PyCaret's load_model() function and then easily apply the saved model on new unseen data for prediction.

# %%
saved_final_model = load_model('../models/QA-MILB-Team-Based-Retention-Model')

new_prediction = predict_model(saved_final_model, data=df_eval)
new_prediction.head()
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    dimcustomermasterid  recency attendancePercent totalSpent distToVenue  \
# 3            303658983        3          0.313869     1561.8       18.21
# 5            272911264        0          0.378472       2088        4.02
# 13           272869206        0          0.367816     761.25       75.91
# 17           272872610        3          0.104167       1152        29.3
# 48           272820865        0          0.722222       1152       42.92
#
#     source_tenure  renewedBeforeDays  missed_games_1  missed_games_2  \
# 3            1460                197               2               2
# 5            1460                 23               3               2
# 13            305                160               1               1
# 17            294                149               0               0
# 48            362                217              11               1
#
#     missed_games_over_2  isnextyear_buyer  Label   Score
# 3                     3                 1      1  0.6754
# 5                     7                 1      1  0.6870
# 13                    5                 1      0  0.5552
# 17                    2                 1      1  0.5334
# 48                    3                 1      0  0.5220

# %% [markdown]
# ## FIN!!
