# %% [markdown]
# # Ports Feature Selection
# * StellarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * October 27, 2021

# %% [markdown]
# ## Hypothesis
# Write about the hunch you have and why you're running this experiment.

# %% [markdown]
# ## Experiment
# Document the experiment including selecting data, data transformations, feature engineering and modelling

# %%
import getpass
import pyodbc
import pandas as pd
import warnings
from pycaret.classification import *
from ngboost import NGBClassifier

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'nrad' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password········

# %%
lkupclientid = 25 # ports

cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrMILB].[ds].[getRetentionScoringModelData] {lkupclientid}"""
)

df = pd.read_sql(storedProc, CNXN)

CNXN.commit()
cursor.close()

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lkupClientId              1962 non-null   int64
#  1   dimCustomerMasterId       1962 non-null   int64
#  2   customerNumber            1962 non-null   object
#  3   year                      1962 non-null   object
#  4   productGrouping           1962 non-null   object
#  5   totalSpent                1962 non-null   float64
#  6   recentDate                1962 non-null   object
#  7   attendancePercent         1962 non-null   float64
#  8   renewedBeforeDays         1962 non-null   int64
#  9   isBuyer                   1962 non-null   object
#  10  source_tenure             1962 non-null   int64
#  11  tenure                    1962 non-null   int64
#  12  distToVenue               1962 non-null   float64
#  13  totalGames                1962 non-null   int64
#  14  recency                   1962 non-null   int64
#  15  missed_games_1            1962 non-null   int64
#  16  missed_games_2            1962 non-null   int64
#  17  missed_games_over_2       1962 non-null   int64
#  18  click_link                1962 non-null   int64
#  19  fill_out_form             1962 non-null   int64
#  20  open_email                1962 non-null   int64
#  21  send_email                1962 non-null   int64
#  22  unsubscribe_email         1962 non-null   int64
#  23  openToSendRatio           1962 non-null   float64
#  24  clickToSendRatio          1962 non-null   float64
#  25  clickToOpenRatio          1962 non-null   float64
#  26  posting_records           1962 non-null   int64
#  27  resale_records            1962 non-null   int64
#  28  resale_atp                1962 non-null   float64
#  29  forward_records           1962 non-null   int64
#  30  cancel_records            1962 non-null   int64
#  31  email                     1962 non-null   int64
#  32  inbound_email             1962 non-null   int64
#  33  inbound_phonecall         1962 non-null   int64
#  34  inperson_contact          1962 non-null   int64
#  35  internal_note             1962 non-null   int64
#  36  left_message              1962 non-null   int64
#  37  outbound_email            1962 non-null   int64
#  38  outbound_phonecall        1962 non-null   int64
#  39  phonecall                 1962 non-null   int64
#  40  text                      1962 non-null   int64
#  41  unknown                   1962 non-null   int64
#  42  gender                    1962 non-null   object
#  43  childrenPresentInHH       1962 non-null   int64
#  44  maritalStatus             1962 non-null   int64
#  45  lengthOfResidenceInYrs    0 non-null      object
#  46  annualHHIncome            0 non-null      object
#  47  education                 0 non-null      object
#  48  urbanicity                0 non-null      object
#  49  isnextyear_buyer          0 non-null      object
#  50  isnextyear_samepkg_buyer  0 non-null      object
#  51  pkgupgrade_status         0 non-null      object
#  52  auto_renewal              0 non-null      object
#  53  credits_after_refund      1962 non-null   float64
#  54  isNextYear_Buyer          1962 non-null   int64
# dtypes: float64(8), int64(33), object(14)
# memory usage: 843.2+ KB

# %% [markdown]
# ### Let's drop the features that have lots of null values:

# %%
df.drop([ 
    'lengthOfResidenceInYrs',
    'annualHHIncome',
    'education',
    'urbanicity',
    'isnextyear_buyer',
    'isnextyear_samepkg_buyer',
    'pkgupgrade_status',
    'auto_renewal'],
    axis=1, 
    inplace=True
)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lkupClientId          1962 non-null   int64
#  1   dimCustomerMasterId   1962 non-null   int64
#  2   customerNumber        1962 non-null   object
#  3   year                  1962 non-null   object
#  4   productGrouping       1962 non-null   object
#  5   totalSpent            1962 non-null   float64
#  6   recentDate            1962 non-null   object
#  7   attendancePercent     1962 non-null   float64
#  8   renewedBeforeDays     1962 non-null   int64
#  9   isBuyer               1962 non-null   object
#  10  source_tenure         1962 non-null   int64
#  11  tenure                1962 non-null   int64
#  12  distToVenue           1962 non-null   float64
#  13  totalGames            1962 non-null   int64
#  14  recency               1962 non-null   int64
#  15  missed_games_1        1962 non-null   int64
#  16  missed_games_2        1962 non-null   int64
#  17  missed_games_over_2   1962 non-null   int64
#  18  click_link            1962 non-null   int64
#  19  fill_out_form         1962 non-null   int64
#  20  open_email            1962 non-null   int64
#  21  send_email            1962 non-null   int64
#  22  unsubscribe_email     1962 non-null   int64
#  23  openToSendRatio       1962 non-null   float64
#  24  clickToSendRatio      1962 non-null   float64
#  25  clickToOpenRatio      1962 non-null   float64
#  26  posting_records       1962 non-null   int64
#  27  resale_records        1962 non-null   int64
#  28  resale_atp            1962 non-null   float64
#  29  forward_records       1962 non-null   int64
#  30  cancel_records        1962 non-null   int64
#  31  email                 1962 non-null   int64
#  32  inbound_email         1962 non-null   int64
#  33  inbound_phonecall     1962 non-null   int64
#  34  inperson_contact      1962 non-null   int64
#  35  internal_note         1962 non-null   int64
#  36  left_message          1962 non-null   int64
#  37  outbound_email        1962 non-null   int64
#  38  outbound_phonecall    1962 non-null   int64
#  39  phonecall             1962 non-null   int64
#  40  text                  1962 non-null   int64
#  41  unknown               1962 non-null   int64
#  42  gender                1962 non-null   object
#  43  childrenPresentInHH   1962 non-null   int64
#  44  maritalStatus         1962 non-null   int64
#  45  credits_after_refund  1962 non-null   float64
#  46  isNextYear_Buyer      1962 non-null   int64
# dtypes: float64(8), int64(33), object(6)
# memory usage: 720.5+ KB

# %% [markdown]
# ### In order to compare two sets of features, we need to create some datasets for training and evalution:

# %%
df_train_A = df.sample(frac=0.9, random_state=786)
df_train_B = df.sample(frac=0.9, random_state=786)

df_eval_A = df.drop(df_train_A.index)
df_eval_B = df.drop(df_train_B.index)

print('Data for Modeling (A Class): ' + str(df_train_A.shape))
print('Unseen Data For Predictions: ' + str(df_eval_A.shape))

print('Data for Modeling (A Class): ' + str(df_train_A.shape))
print('Unseen Data For Predictions: ' + str(df_eval_A.shape))
# Out:
# Data for Modeling (A Class): (1766, 47)
# Unseen Data For Predictions: (196, 47)
# Data for Modeling (A Class): (1766, 47)
# Unseen Data For Predictions: (196, 47)

# %% [markdown]
# ### Let's also drop the features that only have a single value, as they won't add much differentiation to our model:

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        df.drop(col,inplace=True,axis=1)
        
df.shape
# Out:
# (1962, 17)

# %% [markdown]
# ### We should also drop features that have a low correlation with the target label as they won't be useful for prediction, we'll only keep features that have a correlation above a set threshold:

# %%
cor = df.corr()

threshold = 0.05

#Correlation with output variable
cor_target = abs(cor["isNextYear_Buyer"])

#Selecting highly correlated features
relevant_features = cor_target[cor_target > threshold]

feats = []
for name, val in relevant_features.items():
    feats.append(name)

df_correlated = df[feats]

df_correlated.shape

df_correlated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   totalSpent           1962 non-null   float64
#  1   renewedBeforeDays    1962 non-null   int64
#  2   source_tenure        1962 non-null   int64
#  3   tenure               1962 non-null   int64
#  4   totalGames           1962 non-null   int64
#  5   missed_games_1       1962 non-null   int64
#  6   missed_games_2       1962 non-null   int64
#  7   missed_games_over_2  1962 non-null   int64
#  8   isNextYear_Buyer     1962 non-null   int64
# dtypes: float64(1), int64(8)
# memory usage: 138.1 KB

# %% [markdown]
# ### Now that we have the right features we can look at the correlations between them, if features are highly correlated with each other it might negatively impact the model:

# %%
corr = df_correlated.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_171bd_row0_col0,#T_171bd_row1_col1,#T_171bd_row2_col2,#T_171bd_row2_col3,#T_171bd_row3_col2,#T_171bd_row3_col3,#T_171bd_row4_col4,#T_171bd_row5_col5,#T_171bd_row6_col6,#T_171bd_row7_col7,#T_171bd_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_171bd_row0_col1{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_171bd_row0_col2,#T_171bd_row0_col3,#T_171bd_row1_col4,#T_171bd_row6_col2,#T_171bd_row6_col3,#T_171bd_row8_col6{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_171bd_row0_col4{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_171bd_row0_col5{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_171bd_row0_col6,#T_171bd_row6_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_171bd_row0_col7{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_171bd_row0_col8,#T_171bd_row6_col7{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_171bd_row1_col0{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_171bd_row1_col2,#T_171bd_row1_col3,#T_171bd_row8_col7{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_171bd_row1_col5,#T_171bd_row6_col1,#T_171bd_row8_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_171bd_row1_col6{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_171bd_row1_col7{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_171bd_row1_col8{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_171bd_row2_col0,#T_171bd_row2_col1,#T_171bd_row2_col4,#T_171bd_row2_col5,#T_171bd_row2_col6,#T_171bd_row2_col7,#T_171bd_row2_col8,#T_171bd_row3_col0,#T_171bd_row3_col1,#T_171bd_row3_col4,#T_171bd_row3_col5,#T_171bd_row3_col6,#T_171bd_row3_col7,#T_171bd_row3_col8,#T_171bd_row8_col2,#T_171bd_row8_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_171bd_row4_col0{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_171bd_row4_col1{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_171bd_row4_col2,#T_171bd_row4_col3{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_171bd_row4_col5,#T_171bd_row5_col4{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_171bd_row4_col6{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_171bd_row4_col7{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_171bd_row4_col8,#T_171bd_row7_col8{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_171bd_row5_col0,#T_171bd_row7_col1{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_171bd_row5_col1{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_171bd_row5_col2,#T_171bd_row5_col3{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_171bd_row5_col6{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_171bd_row5_col7{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_171bd_row5_col8,#T_171bd_row7_col6{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_171bd_row6_col4{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_171bd_row6_col5{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_171bd_row6_col8{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_171bd_row7_col0{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_171bd_row7_col2,#T_171bd_row7_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_171bd_row7_col4{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_171bd_row7_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_171bd_row8_col0{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_171bd_row8_col1{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_171bd_row8_col4{
#             background-color:  #6788ee;
#             color:  #000000;
#         }</style><table id="T_171bd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >totalSpent</th>        <th class="col_heading level0 col1" >renewedBeforeDays</th>        <th class="col_heading level0 col2" >source_tenure</th>        <th class="col_heading level0 col3" >tenure</th>        <th class="col_heading level0 col4" >totalGames</th>        <th class="col_heading level0 col5" >missed_games_1</th>        <th class="col_heading level0 col6" >missed_games_2</th>        <th class="col_heading level0 col7" >missed_games_over_2</th>        <th class="col_heading level0 col8" >isNextYear_Buyer</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_171bd_level0_row0" class="row_heading level0 row0" >totalSpent</th>
#                         <td id="T_171bd_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_171bd_row0_col1" class="data row0 col1" >0.12</td>
#                         <td id="T_171bd_row0_col2" class="data row0 col2" >-0.02</td>
#                         <td id="T_171bd_row0_col3" class="data row0 col3" >-0.02</td>
#                         <td id="T_171bd_row0_col4" class="data row0 col4" >0.40</td>
#                         <td id="T_171bd_row0_col5" class="data row0 col5" >0.09</td>
#                         <td id="T_171bd_row0_col6" class="data row0 col6" >0.15</td>
#                         <td id="T_171bd_row0_col7" class="data row0 col7" >0.58</td>
#                         <td id="T_171bd_row0_col8" class="data row0 col8" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_171bd_level0_row1" class="row_heading level0 row1" >renewedBeforeDays</th>
#                         <td id="T_171bd_row1_col0" class="data row1 col0" >0.12</td>
#                         <td id="T_171bd_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_171bd_row1_col2" class="data row1 col2" >0.07</td>
#                         <td id="T_171bd_row1_col3" class="data row1 col3" >0.07</td>
#                         <td id="T_171bd_row1_col4" class="data row1 col4" >0.16</td>
#                         <td id="T_171bd_row1_col5" class="data row1 col5" >0.14</td>
#                         <td id="T_171bd_row1_col6" class="data row1 col6" >0.17</td>
#                         <td id="T_171bd_row1_col7" class="data row1 col7" >0.17</td>
#                         <td id="T_171bd_row1_col8" class="data row1 col8" >0.29</td>
#             </tr>
#             <tr>
#                         <th id="T_171bd_level0_row2" class="row_heading level0 row2" >source_tenure</th>
#                         <td id="T_171bd_row2_col0" class="data row2 col0" >-0.02</td>
#                         <td id="T_171bd_row2_col1" class="data row2 col1" >0.07</td>
#                         <td id="T_171bd_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_171bd_row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_171bd_row2_col4" class="data row2 col4" >0.03</td>
#                         <td id="T_171bd_row2_col5" class="data row2 col5" >0.03</td>
#                         <td id="T_171bd_row2_col6" class="data row2 col6" >-0.02</td>
#                         <td id="T_171bd_row2_col7" class="data row2 col7" >-0.06</td>
#                         <td id="T_171bd_row2_col8" class="data row2 col8" >-0.18</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### In order to compare two sets of features, we need to create some datasets for training and evalution:

# %%
# select % of the data for training
df_train = df_correlated.sample(frac=0.8, random_state=786).reset_index(drop=True)

# create the eval datasets for A and B
df_eval = df_correlated.drop(df_train.index).reset_index(drop=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (1570, 9)
# Unseen Data For Predictions: (392, 9)

# %% [markdown]
# ## Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
from sklearn.impute import SimpleImputer
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.80,
    data_split_shuffle=True,
    silent=True,
    numeric_features=[
        "totalSpent",
        "renewedBeforeDays",
        "source_tenure",
        "tenure",
        "totalGames",
        "missed_games_1",
        "missed_games_2",
        "missed_games_over_2"
    ]
)
# Out:
# <style  type="text/css" >
# #T_0ed3d_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_0ed3d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ed3d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ed3d_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0ed3d_row0_col1" class="data row0 col1" >5032</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0ed3d_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_0ed3d_row1_col1" class="data row1 col1" >isNextYear_Buyer</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0ed3d_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_0ed3d_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0ed3d_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_0ed3d_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0ed3d_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_0ed3d_row4_col1" class="data row4 col1" >(1570, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0ed3d_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_0ed3d_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0ed3d_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_0ed3d_row6_col1" class="data row6 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0ed3d_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_0ed3d_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0ed3d_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_0ed3d_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0ed3d_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_0ed3d_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_0ed3d_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_0ed3d_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_0ed3d_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_0ed3d_row11_col1" class="data row11 col1" >(1256, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_0ed3d_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_0ed3d_row12_col1" class="data row12 col1" >(314, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_0ed3d_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_0ed3d_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_0ed3d_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_0ed3d_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_0ed3d_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_0ed3d_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_0ed3d_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_0ed3d_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_0ed3d_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_0ed3d_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_0ed3d_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_0ed3d_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_0ed3d_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_0ed3d_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_0ed3d_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_0ed3d_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_0ed3d_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_0ed3d_row21_col1" class="data row21 col1" >d9f8</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_0ed3d_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_0ed3d_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_0ed3d_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_0ed3d_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed3d_level0_row24" class="row_heading level0 row2
# ({'acc': <pycaret.containers.metrics.classification.AccuracyMetricContainer at 0x7ffcea48f950>,
#   'auc': <pycaret.containers.metrics.classification.ROCAUCMetricContainer at 0x7ffcea48f990>,
#   'recall': <pycaret.containers.metrics.classification.RecallMetricContainer at 0x7ffcea48fa10>,
#   'precision': <pycaret.containers.metrics.classification.PrecisionMetricContainer at 0x7ffcea48fb10>,
#   'f1': <pycaret.containers.metrics.classification.F1MetricContainer at 0x7ffcea48fc10>,
#   'kappa': <pycaret.containers.metrics.classification.KappaMetricContainer at 0x7ffcea48fd50>,
#   'mcc': <pycaret.containers.metrics.classification.MCCMetricContainer at 0x7ffcea48fdd0>},
#  0       1
#  1       1
#  2       0
#  3       1
#  4       0
#         ..
#  1565    0
#  1566    1
#  1567    1
#  1568    0
#  1569    0
#  Name: isNextYear_Buyer, Length: 1570, dtype: int64,
#  594     1
#  806     0
#  776     1
#  427     1
#  1155    0
#         ..
#  886     0
#  778     0
#  353     0
#  1566    1
#  1198    0
#  Name: isNextYear_Buyer, Length: 314, dtype: int64,
#  None,
#  966     1
#  1169    1
#  1424    1
#  1352    0
#  99      0
#         ..
#  33      0
#  1557    0
#  703     1
#  753     0
#  858     0
#  Name: isNextYear_Buyer, Length: 1256, dtype: int64,
#  True,
#         totalSpent  renewedBeforeDays  source_tenure  totalGames  \
#  966    192.000000               10.0          159.0         0.0
#  1169   112.000000               31.0          164.0         6.0
#  1424    77.000000               48.0          378.0         0.0
#  1352   991.760010             -192.0          661.0         3.0
#  99     887.599976               86.0         1329.0         1.0
#  ...           ...                ...            ...         ...
#  33    2562.000000                2.0          153.0        16.0
#  1557   750.000000               58.0          521.0         0.0
#  703    320.000000              147.0          633.0        18.0
#  753     40.040001               10.0          580.0         0.0
#  858    293.019989                8.0          153.0         0.0
#
#        missed_games_1  missed_games_2  missed_games_over_2
#  966              0.0             0.0                  1.0
#  1169             1.0             0.0                  0.0
#  1424             0.0             0.0                  1.0
#  1352             0.0             0.0                  3.0
#  99               0.0             0.0                  1.0
#  ...              ...             ...                  ...
#  33               2.0             1.0                  6.0
#  1557             0.0             0.0                  1.0
#  703              2.0             1.0                  0.0
#  753              0.0             0.0                  1.0
#  858              0.0             0.0                  1.0
#
#  [1256 rows x 7 columns],
#  Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['totalSpent',
#                                                            'renewedBeforeDays',
#                                                            'source_tenure',
#                                                            'tenure',
#                                                            'totalGames',
#                                                            'missed_games_1',
#                                                            'missed_games_2',
#                                                            'missed_games_over_2'],
#                                        target='isNextYear_Buyer',
#                                        time_feature...
#                  ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='isNextYear_Buyer')),
#                  ('fix_perfect', Remove_100(target='isNextYear_Buyer')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough')],
#           verbose=False),
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x7ffcea482190>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x7ffcea482290>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x7ffcea4823d0>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x7ffcea482490>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x7ffcea482710>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x7ffcea482a50>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x7ffcea482b90>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x7ffcea482c50>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x7ffcea482ed0>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x7ffcea482790>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x7ffcea534410>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x7ffcea5344d0>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x7ffcea534690>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x7ffcea5349d0>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x7ffcea534ad0>,
#   'xgboost': <pycaret.containers.models.classification.XGBClassifierContainer at 0x7ffcea534e10>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x7ffcea48f250>,
#   'Bagging': <pycaret.containers.models.classification.BaggingClassifierContainer at 0x7ffcea48f350>,
#   'Stacking': <pycaret.containers.models.classification.StackingClassifierContainer at 0x7ffcea48f2d0>,
#   'Voting': <pycaret.containers.models.classification.VotingClassifierContainer at 0x7ffcea48f710>,
#   'CalibratedCV': <pycaret.containers.models.classification.CalibratedClassifierCVContainer at 0x7ffcea48f850>},
#  False,
#  False,
#  None,
#  {'parameter': 'Hyperparameters',
#   'auc': 'AUC',
#   'confusion_matrix': 'Confusion Matrix',
#   'threshold': 'Threshold',
#   'pr': 'Precision Recall',
#   'error': 'Prediction Error',
#   'class_report': 'Class Report',
#   'rfe': 'Feature Selection',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'calibration': 'Calibration Curve',
#   'vc': 'Validation Curve',
#   'dimension': 'Dimensions',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'boundary': 'Decision Boundary',
#   'lift': 'Lift Chart',
#   'gain': 'Gain Chart',
#   'tree': 'Decision Tree',
#   'ks': 'KS Statistic Plot'},
#  {'lr': <pycaret.containers.models.classification.LogisticRegressionClassifierContainer at 0x7ffcea2e4810>,
#   'knn': <pycaret.containers.models.classification.KNeighborsClassifierContainer at 0x7ffcea2e4690>,
#   'nb': <pycaret.containers.models.classification.GaussianNBClassifierContainer at 0x7ffcea2e4110>,
#   'dt': <pycaret.containers.models.classification.DecisionTreeClassifierContainer at 0x7ffcea214690>,
#   'svm': <pycaret.containers.models.classification.SGDClassifierContainer at 0x7ffcea3e6c50>,
#   'rbfsvm': <pycaret.containers.models.classification.SVCClassifierContainer at 0x7ffcea3e6f10>,
#   'gpc': <pycaret.containers.models.classification.GaussianProcessClassifierContainer at 0x7ffcea3e6cd0>,
#   'mlp': <pycaret.containers.models.classification.MLPClassifierContainer at 0x7ffcea2ea0d0>,
#   'ridge': <pycaret.containers.models.classification.RidgeClassifierContainer at 0x7ffcea453b10>,
#   'rf': <pycaret.containers.models.classification.RandomForestClassifierContainer at 0x7ffcea2147d0>,
#   'qda': <pycaret.containers.models.classification.QuadraticDiscriminantAnalysisContainer at 0x7ffcea453f50>,
#   'ada': <pycaret.containers.models.classification.AdaBoostClassifierContainer at 0x7ffcea453c10>,
#   'gbc': <pycaret.containers.models.classification.GradientBoostingClassifierContainer at 0x7ffcea458f10>,
#   'lda': <pycaret.containers.models.classification.LinearDiscriminantAnalysisContainer at 0x7ffcea2e4f90>,
#   'et': <pycaret.containers.models.classification.ExtraTreesClassifierContainer at 0x7ffcea479590>,
#   'xgboost': <pycaret.containers.models.classification.XGBClassifierContainer at 0x7ffcea479490>,
#   'lightgbm': <pycaret.containers.models.classification.LGBMClassifierContainer at 0x7ffcea479c10>},
#  [],
#  10,
#  'box-cox',
#  False,
#        totalSpent  renewedBeforeDays  source_tenure  tenure  totalGames  \
#  0         231.00                 37            590     590           5
#  1         288.00                126            655     655           9
#  2          49.98                 10            619     619           4
#  3         264.00                154            301     301           5
#  4         528.00                 56            205     205           9
#  ...          ...                ...            ...     ...         ...
#  1565       56.68                 17             89      89           1
#  1566      264.00                170            319     319           4
#  1567     3155.60                129            669     669          14
#  1568     2380.56                 15            143     143           0
#  1569     1555.26                  3            147     147          10
#
#        missed_games_1  missed_games_2  missed_games_over_2  isNextYear_Buyer
#  0                  0               1                    1                 1
#  1                  3               0                    1                 1
#  2                  0               0                    1                 0
#  3                  3               2                    0                 1
#  4                  2               0                    3                 0
#  ...              ...             ...                  ...               ...
#  1565               1               0                    0                 0
#  1566               0               2                    1                 1
#  1567               1               0                    2                 1
#  1568               0               0                    1                 0
#  1569               3               1                    5                 0
#
#  [1570 rows x 9 columns],
#  Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False),
#  None,
#  -1,
#  'isNextYear_Buyer',
#  'lightgbm',
#  [<pandas.io.formats.style.Styler at 0x7ffcea2e41d0>],
#  'clf-default-name',
#  False,
#  5032,
#  'lightgbm',
#  False,
#  [],
#  {'USI',
#   'X',
#   'X_test',
#   'X_train',
#   '_all_metrics',
#   '_all_models',
#   '_all_models_internal',
#   '_available_plots',
#   '_gpu_n_jobs_param',
#   '_internal_pipeline',
#   '_ml_usecase',
#   'create_model_container',
#   'data_before_preprocess',
#   'display_container',
#   'exp_name_log',
#   'experiment__',
#   'fix_imbalance_method_param',
#   'fix_imbalance_param',
#   'fold_generator',
#   'fold_groups_param',
#   'fold_groups_param_full',
#   'fold_param',
#   'fold_shuffle_param',
#   'gpu_param',
#   'html_param',
#   'imputation_classifier',
#   'imputation_regressor',
#   'iterative_imputation_iters_param',
#   'log_plots_param',
#   'logging_param',
#   'master_model_container',
#   'n_jobs_param',
#   'prep_pipe',
#   'pycaret_globals',
#   'seed',
#   'stratify_param',
#   'target_param',
#   'transform_target_method_param',
#   'transform_target_param',
#   'y',
#   'y_test',
#   'y_train'},
#  <MLUsecase.CLASSIFICATION: 1>,
#  False,
#  -1,
#  5,
#  False,
#         totalSpent  renewedBeforeDays  source_tenure  totalGames  \
#  0      231.000000               37.0          590.0         5.0
#  1      288.000000              126.0          655.0         9.0
#  2       49.980000               10.0          619.0         4.0
#  3      264.000000              154.0          301.0         5.0
#  4      528.000000               56.0          205.0         9.0
#  ...           ...                ...            ...         ...
#  1565    56.680000               17.0           89.0         1.0
#  1566   264.000000              170.0          319.0         4.0
#  1567  3155.600098              129.0          669.0        14.0
#  1568  2380.560059               15.0          143.0         0.0
#  1569  1555.260010                3.0          147.0        10.0
#
#        missed_games_1  missed_games_2  missed_games_over_2
#  0                0.0             1.0                  1.0
#  1                3.0             0.0                  1.0
#  2                0.0             0.0                  1.0
#  3                3.0             2.0                  0.0
#  4                2.0             0.0                  3.0
#  ...              ...             ...                  ...
#  1565             1.0             0.0                  0.0
#  1566             0.0             2.0                  1.0
#  1567             1.0             0.0                  2.0
#  1568             0.0             0.0                  1.0
#  1569             3.0             1.0                  5.0
#
#  [1570 rows x 7 columns],
#         totalSpent  renewedBeforeDays  source_tenure  totalGames  \
#  594    154.000000                0.0          908.0         5.0
#  806     24.990000               10.0          619.0         0.0
#  776   2562.000000               -1.0          150.0         4.0
#  427   1577.800049              153.0          691.0        51.0
#  1155   283.799988               32.0          914.0         0.0
#  ...           ...                ...            ...         ...
#  886   1555.260010              155.0         1071.0        40.0
#  778    991.760010             -192.0          571.0        43.0
#  353   1555.260010                3.0         1265.0         6.0
#  1566   264.000000              170.0          319.0         4.0
#  1198    35.000000                9.0          620.0         5.0
#
#        missed_games_1  missed_games_2  missed_games_over_2
#  594              1.0             0.0                  1.0
#  806              0.0             0.0                  1.0
#  776              0.0             0.0                  5.0
#  427             13.0             1.0                  2.0
#  1155             0.0             0.0                  1.0
#  ...              ...             ...                  ...
#  886              0.0             0.0                  2.0
#  778              6.0             0.0                  0.0
#  353              0.0             0.0                  5.0
#  1566             0.0             2.0                  1.0
#  1198             2.0             0.0                  0.0
#
#  [314 rows x 7 columns],
#  [('Setup Config',
#                                   Description             Value
#    0                               session_id              5032
#    1                                   Target  isNextYear_Buyer
#    2                              Target Type            Binary
#    3                            Label Encoded        0: 0, 1: 1
#    4                            Original Data         (1570, 9)
#    5                           Missing Values             False
#    6                         Numeric Features                 8
#    7                     Categorical Features                 0
#    8                         Ordinal Features             False
#    9                High Cardinality Features             False
#    10                 High Cardinality Method              None
#    11                   Transformed Train Set         (1256, 7)
#    12                    Transformed Test Set          (314, 7)
#    13                      Shuffle Train-Test              True
#    14                     Stratify Train-Test             False
#    15                          Fold Generator   StratifiedKFold
#    16                             Fold Number                10
#    17                                CPU Jobs                -1
#    18                                 Use GPU             False
#    19                          Log Experiment             False
#    20                         Experiment Name  clf-default-name
#    21                                     USI              d9f8
#    22                         Imputation Type            simple
#    23          Iterative Imputation Iteration              None
#    24                         Numeric Imputer              mean
#    25      Iterative Imputation Numeric Model              None
#    26                     Categorical Imputer          constant
#    27  Iterative Imputation Categorical Model              None
#    28           Unknown Categoricals Handling    least_frequent
#    29                               Normalize             False
#    30                        Normalize Method              None
#    31                          Transformation             False
#    32                   Transformation Method              None
#    33                                     PCA             False
#    34                              PCA Method              None
#    35                          PCA Components              None
#    36                     Ignore Low Variance             False
#    37                     Combine Rare Levels             False
#    38                    Rare Level Threshold              None
#    39                         Numeric Binning             False
#    40                         Remove Outliers             False
#    41                      Outliers Threshold              None
#    42                Remove Multicollinearity             False
#    43             Multicollinearity Threshold              None
#    44             Remove Perfect Collinearity              True
#    45                              Clustering             False
#    46                    Clustering Iteration              None
#    47                     Polynomial Features             False
#    48                       Polynomial Degree              None
#    49                    Trignometry Features             False
#    50                    Polynomial Threshold              None
#    51                          Group Features             False
#    52                       Feature Selection             False
#    53                Feature Selection Method           classic
#    54            Features Selection Threshold              None
#    55                     Feature Interaction             False
#    56                           Feature Ratio             False
#    57                   Interaction Threshold              None
#    58                           Fix Imbalance             False
#    59                    Fix Imbalance Method             SMOTE),
#   ('X_training Set',
#           totalSpent  renewedBeforeDays  source_tenure  totalGames  \
#    966    192.000000               10.0          159.0         0.0
#    1169   112.000000               31.0          164.0         6.0
#    1424    77.000000               48.0          378.0         0.0
#    1352   991.760010             -192.0          661.0         3.0
#    99     887.599976               86.0         1329.0         1.0
#    ...           ...                ...            ...         ...
#    33    2562.000000                2.0          153.0        16.0
#    1557   750.000000               58.0          521.0         0.0
#    703    320.000000              147.0          633.0        18.0
#    753     40.040001               10.0          580.0         0.0
#    858    293.019989                8.0          153.0         0.0
#
#          missed_games_1  missed_games_2  missed_games_over_2
#    966              0.0             0.0                  1.0
#    1169             1.0             0.0                  0.0
#    1424             0.0             0.0                  1.0
#    1352             0.0             0.0                  3.0
#    99               0.0             0.0                  1.0
#    ...              ...             ...                  ...
#    33               2.0             1.0                  6.0
#    1557             0.0             0.0                  1.0
#    703              2.0             1.0                  0.0
#    753              0.0             0.0                  1.0
#    858              0.0             0.0                  1.0
#
#    [1256 rows x 7 columns]),
#   ('y_training Set',
#    966     1
#    1169    1
#    1424    1
#    1352    0
#    99      0
#           ..
#    33      0
#    1557    0
#    703     1
#    753     0
#    858     0
#    Name: isNextYear_Buyer, Length: 1256, dtype: int64),
#   ('X_test Set',
#           totalSpent  renewedBeforeDays  source_tenure  totalGames  \
#    594    154.000000                0.0          908.0         5.0
#    806     24.990000               10.0          619.0         0.0
#    776   2562.000000               -1.0          150.0         4.0
#    427   1577.800049              153.0          691.0        51.0
#    1155   283.799988               32.0          914.0         0.0
#    ...           ...                ...            ...         ...
#    886   1555.260010              155.0         1071.0        40.0
#    778    991.760010             -192.0          571.0        43.0
#    353   1555.260010                3.0         1265.0         6.0
#    1566   264.000000              170.0          319.0         4.0
#    1198    35.000000                9.0          620.0         5.0
#
#          missed_games_1  missed_games_2  missed_games_over_2
#    594              1.0             0.0                  1.0
#    806              0.0             0.0                  1.0
#    776              0.0             0.0                  5.0
#    427             13.0             1.0                  2.0
#    1155             0.0             0.0                  1.0
#    ...              ...             ...                  ...
#    886              0.0             0.0                  2.0
#    778              6.0             0.0                  0.0
#    353              0.0             0.0                  5.0
#    1566             0.0             2.0                  1.0
#    1198             2.0             0.0                  0.0
#
#    [314 rows x 7 columns]),
#   ('y_test Set',
#    594     1
#    806     0
#    776     1
#    427     1
#    1155    0
#           ..
#    886     0
#    778     0
#    353     0
#    1566    1
#    1198    0
#    Name: isNextYear_Buyer, Length: 314, dtype: int64),
#   ('Transformation Pipeline',
#    Pipeline(memory=None,
#             steps=[('dtypes',
#                     DataTypes_Auto_infer(categorical_features=[],
#                                          display_types=False, features_todrop=[],
#                                          id_columns=[],
#                                          ml_usecase='classification',
#                                          numerical_features=['totalSpent',
#                                                              'renewedBeforeDays',
#                                                              'source_tenure',
#                                                              'tenure',
#                                                              'totalGames',
#                                                              'missed_games_1',
#                                                              'missed_games_2',
#                                                              'missed_games_over_2'],
#                                          target='isNextYear_Buyer',
#                                          time_feature...
#                    ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                    ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                    ('cluster_all', 'passthrough'),
#                    ('dummy', Dummify(target='isNextYear_Buyer')),
#                    ('fix_perfect', Remove_100(target='isNextYear_Buyer')),
#                    ('clean_names', Clean_Colum_Names()),
#                    ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                    ('dfs', 'passthrough'), ('pca', 'passthrough')],
#             verbose=False))],
#  StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#  'd9f8')

# %%
# adding an extra classifier ngboost
ngc = NGBClassifier()
ngboost = create_model(ngc)

model_matrix = compare_models(
    fold=10,
    include=["ada","dt","gbc","et","knn","lightgbm","lr","rf",ngboost,"xgboost"]
)
# Out:
# <style  type="text/css" >
#     #T_56e58_ th {
#           text-align: left;
#     }#T_56e58_row0_col0,#T_56e58_row0_col2,#T_56e58_row0_col4,#T_56e58_row1_col0,#T_56e58_row1_col1,#T_56e58_row1_col3,#T_56e58_row1_col4,#T_56e58_row1_col5,#T_56e58_row1_col6,#T_56e58_row1_col7,#T_56e58_row2_col0,#T_56e58_row2_col1,#T_56e58_row2_col2,#T_56e58_row2_col3,#T_56e58_row2_col4,#T_56e58_row2_col5,#T_56e58_row2_col6,#T_56e58_row2_col7,#T_56e58_row3_col0,#T_56e58_row3_col1,#T_56e58_row3_col2,#T_56e58_row3_col3,#T_56e58_row3_col5,#T_56e58_row3_col6,#T_56e58_row3_col7,#T_56e58_row4_col0,#T_56e58_row4_col1,#T_56e58_row4_col2,#T_56e58_row4_col3,#T_56e58_row4_col4,#T_56e58_row4_col5,#T_56e58_row4_col6,#T_56e58_row4_col7,#T_56e58_row5_col0,#T_56e58_row5_col1,#T_56e58_row5_col2,#T_56e58_row5_col3,#T_56e58_row5_col4,#T_56e58_row5_col5,#T_56e58_row5_col6,#T_56e58_row5_col7,#T_56e58_row6_col0,#T_56e58_row6_col1,#T_56e58_row6_col2,#T_56e58_row6_col3,#T_56e58_row6_col4,#T_56e58_row6_col5,#T_56e58_row6_col6,#T_56e58_row6_col7,#T_56e58_row7_col0,#T_56e58_row7_col1,#T_56e58_row7_col2,#T_56e58_row7_col3,#T_56e58_row7_col4,#T_56e58_row7_col5,#T_56e58_row7_col6,#T_56e58_row7_col7,#T_56e58_row8_col0,#T_56e58_row8_col1,#T_56e58_row8_col2,#T_56e58_row8_col3,#T_56e58_row8_col4,#T_56e58_row8_col5,#T_56e58_row8_col6,#T_56e58_row8_col7,#T_56e58_row9_col0,#T_56e58_row9_col1,#T_56e58_row9_col2,#T_56e58_row9_col3,#T_56e58_row9_col4,#T_56e58_row9_col5,#T_56e58_row9_col6,#T_56e58_row9_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_56e58_row0_col1,#T_56e58_row0_col3,#T_56e58_row0_col5,#T_56e58_row0_col6,#T_56e58_row0_col7,#T_56e58_row1_col2,#T_56e58_row3_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_56e58_row0_col8,#T_56e58_row1_col8,#T_56e58_row2_col8,#T_56e58_row3_col8,#T_56e58_row4_col8,#T_56e58_row5_col8,#T_56e58_row6_col8,#T_56e58_row7_col8,#T_56e58_row8_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_56e58_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_56e58_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56e58_level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_56e58_row0_col0" class="data row0 col0" >NGBClassifier</td>
#                         <td id="T_56e58_row0_col1" class="data row0 col1" >0.7126</td>
#                         <td id="T_56e58_row0_col2" class="data row0 col2" >0.7926</td>
#                         <td id="T_56e58_row0_col3" class="data row0 col3" >0.6738</td>
#                         <td id="T_56e58_row0_col4" class="data row0 col4" >0.5764</td>
#                         <td id="T_56e58_row0_col5" class="data row0 col5" >0.6182</td>
#                         <td id="T_56e58_row0_col6" class="data row0 col6" >0.3911</td>
#                         <td id="T_56e58_row0_col7" class="data row0 col7" >0.3970</td>
#                         <td id="T_56e58_row0_col8" class="data row0 col8" >0.7620</td>
#             </tr>
#             <tr>
#                         <th id="T_56e58_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_56e58_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_56e58_row1_col1" class="data row1 col1" >0.7118</td>
#                         <td id="T_56e58_row1_col2" class="data row1 col2" >0.7988</td>
#                         <td id="T_56e58_row1_col3" class="data row1 col3" >0.5773</td>
#                         <td id="T_56e58_row1_col4" class="data row1 col4" >0.5882</td>
#                         <td id="T_56e58_row1_col5" class="data row1 col5" >0.5806</td>
#                         <td id="T_56e58_row1_col6" class="data row1 col6" >0.3617</td>
#                         <td id="T_56e58_row1_col7" class="data row1 col7" >0.3633</td>
#                         <td id="T_56e58_row1_col8" class="data row1 col8" >0.0380</td>
#             </tr>
#             <tr>
#                         <th id="T_56e58_level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_56e58_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#                         <td id="T_56e58_row2_col1" class="data row2 col1" >0.7055</td>
#                         <td id="T_56e58_row2_col2" class="data row2 col2" >0.7909</td>
#                         <td id="T_56e58_row2_col3" class="data row2 col3" >0.5728</td>
#                         <td id="T_56e58_row2_col4" class="data row2 col4" >0.5790</td>
#                         <td id="T_56e58_row2_col5" class="data row2 col5" >0.5741</td>
#                         <td id="T_56e58_row2_col6" class="data row2 col6" >0.3496</td>
#                         <td id="T_56e58_row2_col7" class="data row2 col7" >0.3508</td>
#                         <td id="T_56e58_row2_col8" class="data row2 col8" >0.0310</td>
#             </tr>
#             <tr>
#                         <th id="T_56e58_level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_56e58_row3_col0" class="data row3 col0" >Logistic Regression</td>
#                         <td id="T_56e58_row3_col1" class="data row3 col1" >0.7022</td>
#                         <td id="T_56e58_row3_col2" class="data row3 col2" >0.7377</td>
#                         <td id="T_56e58_row3_col3" class="data row3 col3" >0.4136</td>
#                         <td id="T_56e58_row3_col4" class="data row3 col4" >0.6031</td>
#                         <td id="T_56e58_row3_col5" class="data row3 col5" >0.4861</td>
#                         <td id="T_56e58_row3_col6" class="data row3 col6" >0.2887</td>
#                         <td id="T_56e58_row3_col7" class="data row3 col7" >0.3006</td>
#                         <td id="T_56e58_row3_col8" class="data row3 col8" >0.0130</td>
#             </tr>
#             <tr>
#                         <th id="T_56e58_level0_row4" class="row_heading level0 row4" >7</th>
#                         <td id="T_56e58_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#                         <td id="T_56e58_row4_col1" class="data row4 col1" >0.7006</td>
#                         <td id="T_56e58_row4_col2" class="data row4 col2" >0.7765</td>
#                         <td id="T_56e58_row4_col3" class="data row4 col3" >0.5429</td>
#                         <td id="T_56e58_row4_col4" class="data row4 col4" >0.5719</td>
#                         <td id="T_56e58_row4_col5" class="data row4 col5" >0.5550</td>
#                         <td id="T_56e58_row4_col6" class="data row4 col6" >0.3305</td>
#                         <td id="T_56e58_row4_col7" class="data row4 col7" >0.3319</td>
#                         <td id="T_56e58_row4_col8" class="data row4 col8" >0.1960</td>
#             </tr>
#             <tr>
#                         <th id="T_56e58_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_56e58_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_56e58_row5_col1" class="data row5 col1" >0.6999</td>
#                         <td id="T_56e58_row5_col2" class="data row5 col2" >0.7714</td>
#                         <td id="T_56e58_row5_col3" class="data row5 col3" >0.5474</td>
#                         <td id="T_56e58_row5_col

# %% [markdown]
# ### The top model is performing well, so let's compare it against our unseen eval dataset:

# %%
best_model = create_model(model_matrix)

unseen_predictions = predict_model(best_model, data=df_eval)
# Out:
# <style  type="text/css" >
# #T_3b3be_row10_col0,#T_3b3be_row10_col1,#T_3b3be_row10_col2,#T_3b3be_row10_col3,#T_3b3be_row10_col4,#T_3b3be_row10_col5,#T_3b3be_row10_col6{
#             background:  yellow;
#         }</style><table id="T_3b3be_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3b3be_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3b3be_row0_col0" class="data row0 col0" >0.6984</td>
#                         <td id="T_3b3be_row0_col1" class="data row0 col1" >0.7889</td>
#                         <td id="T_3b3be_row0_col2" class="data row0 col2" >0.5455</td>
#                         <td id="T_3b3be_row0_col3" class="data row0 col3" >0.5714</td>
#                         <td id="T_3b3be_row0_col4" class="data row0 col4" >0.5581</td>
#                         <td id="T_3b3be_row0_col5" class="data row0 col5" >0.3294</td>
#                         <td id="T_3b3be_row0_col6" class="data row0 col6" >0.3296</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3b3be_row1_col0" class="data row1 col0" >0.7937</td>
#                         <td id="T_3b3be_row1_col1" class="data row1 col1" >0.8721</td>
#                         <td id="T_3b3be_row1_col2" class="data row1 col2" >0.7955</td>
#                         <td id="T_3b3be_row1_col3" class="data row1 col3" >0.6731</td>
#                         <td id="T_3b3be_row1_col4" class="data row1 col4" >0.7292</td>
#                         <td id="T_3b3be_row1_col5" class="data row1 col5" >0.5644</td>
#                         <td id="T_3b3be_row1_col6" class="data row1 col6" >0.5695</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3b3be_row2_col0" class="data row2 col0" >0.6429</td>
#                         <td id="T_3b3be_row2_col1" class="data row2 col1" >0.7510</td>
#                         <td id="T_3b3be_row2_col2" class="data row2 col2" >0.7045</td>
#                         <td id="T_3b3be_row2_col3" class="data row2 col3" >0.4921</td>
#                         <td id="T_3b3be_row2_col4" class="data row2 col4" >0.5794</td>
#                         <td id="T_3b3be_row2_col5" class="data row2 col5" >0.2857</td>
#                         <td id="T_3b3be_row2_col6" class="data row2 col6" >0.2997</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3b3be_row3_col0" class="data row3 col0" >0.7143</td>
#                         <td id="T_3b3be_row3_col1" class="data row3 col1" >0.7942</td>
#                         <td id="T_3b3be_row3_col2" class="data row3 col2" >0.6136</td>
#                         <td id="T_3b3be_row3_col3" class="data row3 col3" >0.5870</td>
#                         <td id="T_3b3be_row3_col4" class="data row3 col4" >0.6000</td>
#                         <td id="T_3b3be_row3_col5" class="data row3 col5" >0.3779</td>
#                         <td id="T_3b3be_row3_col6" class="data row3 col6" >0.3782</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3b3be_row4_col0" class="data row4 col0" >0.6984</td>
#                         <td id="T_3b3be_row4_col1" class="data row4 col1" >0.7597</td>
#                         <td id="T_3b3be_row4_col2" class="data row4 col2" >0.6136</td>
#                         <td id="T_3b3be_row4_col3" class="data row4 col3" >0.5625</td>
#                         <td id="T_3b3be_row4_col4" class="data row4 col4" >0.5870</td>
#                         <td id="T_3b3be_row4_col5" class="data row4 col5" >0.3502</td>
#                         <td id="T_3b3be_row4_col6" class="data row4 col6" >0.3510</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3b3be_row5_col0" class="data row5 col0" >0.7381</td>
#                         <td id="T_3b3be_row5_col1" class="data row5 col1" >0.7988</td>
#                         <td id="T_3b3be_row5_col2" class="data row5 col2" >0.6279</td>
#                         <td id="T_3b3be_row5_col3" class="data row5 col3" >0.6136</td>
#                         <td id="T_3b3be_row5_col4" class="data row5 col4" >0.6207</td>
#                         <td id="T_3b3be_row5_col5" class="data row5 col5" >0.4207</td>
#                         <td id="T_3b3be_row5_col6" class="data row5 col6" >0.4208</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3b3be_row6_col0" class="data row6 col0" >0.6960</td>
#                         <td id="T_3b3be_row6_col1" class="data row6 col1" >0.7429</td>
#                         <td id="T_3b3be_row6_col2" class="data row6 col2" >0.8140</td>
#                         <td id="T_3b3be_row6_col3" class="data row6 col3" >0.5385</td>
#                         <td id="T_3b3be_row6_col4" class="data row6 col4" >0.6481</td>
#                         <td id="T_3b3be_row6_col5" class="data row6 col5" >0.3995</td>
#                         <td id="T_3b3be_row6_col6" class="data row6 col6" >0.4261</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3b3be_row7_col0" class="data row7 col0" >0.7280</td>
#                         <td id="T_3b3be_row7_col1" class="data row7 col1" >0.8313</td>
#                         <td id="T_3b3be_row7_col2" class="data row7 col2" >0.6279</td>
#                         <td id="T_3b3be_row7_col3" class="data row7 col3" >0.6000</td>
#                         <td id="T_3b3be_row7_col4" class="data row7 col4" >0.6136</td>
#                         <td id="T_3b3be_row7_col5" class="data row7 col5" >0.4039</td>
#                         <td id="T_3b3be_row7_col6" class="data row7 col6" >0.4042</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3b3be_row8_col0" class="data row8 col0" >0.7440</td>
#                         <td id="T_3b3be_row8_col1" class="data row8 col1" >0.8327</td>
#                         <td id="T_3b3be_row8_col2" class="data row8 col2" >0.7209</td>
#                         <td id="T_3b3be_row8_col3" class="data row8 col3" >0.6078</td>
#                         <td id="T_3b3be_row8_col4" class="data row8 col4" >0.6596</td>
#                         <td id="T_3b3be_row8_col5" class="data row8 col5" >0.4568</td>
#                         <td id="T_3b3be_row8_col6" class="data row8 col6" >0.4611</td>
#             </tr>
#             <tr>
#                         <th id="T_3b3be_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3b3be_row9_col0" class="data row9 col0" >0.6720</td>
#                         <td id="T_3b3be_row9_col1" class="data row9 col1" >0.7540</td>
#                         <td id="T_3b3be_row9_col2" class="data row9 col2" >0.6744</td>
#                         <td id="T_3b3be_row9_col3" class="data row9 col3" >0.5179</td>
#                         <td id="T_3b3be_row9_col4" class="data row9 col4" >0.5859</td>
#                         <td id="T_3b3be_row9_col5" class="data row9 col5" >0.3220</td>
#                         <td id=

# %%
plot_model(best_model, plot='feature')
# Out:
# IntProgress(value=0, description='Processing: ', max=5)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-eab881a8bf49> in <module>
# ----> 1 plot_model(best_model, plot='feature')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1549         use_train_data=use_train_data,
#    1550         system=True,
# -> 1551         display_format=display_format,
#    1552     )
#    1553
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    7252
#    7253         # execute the plot method
# -> 7254         ret = locals()[plot]()
#    7255         if ret:
#    7256             plot_filename = ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/tabular.py in feature()
#    7164
#    7165         def feature():
# -> 7166             _feature(10)
#    7167
#    7168         def feature_all():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/tabular.py in _feature(n)
#    7185                 logger.warning("No coef_ found. Trying feature_importances_")
#    7186                 variables = abs(temp_model.feature_importances_)
# -> 7187             coef_df = pd.DataFrame({"Variable": data_X.columns, "Value": variables})
#    7188             sorted_df = (
#    7189                 coef_df.sort_values(by="Value", ascending=False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      83
#      84         # don't force copy because getting jammed in an ndarray anyway
# ---> 85         arrays = _homogenize(arrays, index, dtype)
#      86
#      87         columns = ensure_index(columns)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     354                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     355             val = sanitize_array(
# --> 356                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     357             )
#     358
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     527     elif subarr.ndim > 1:
#     528         if isinstance(data, np.ndarray):
# --> 529             raise ValueError("Data must be 1-dimensional")
#     530         else:
#     531             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# ValueError: Data must be 1-dimensional

# %%
plot_model(best_model, plot='confusion_matrix')
# Out:
# IntProgress(value=0, description='Processing: ', max=5)
# Finished loading model, total used 100 iterations
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-81127eb78954> in <module>
# ----> 1 plot_model(best_model, plot='confusion_matrix')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1549         use_train_data=use_train_data,
#    1550         system=True,
# -> 1551         display_format=display_format,
#    1552     )
#    1553
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    7252
#    7253         # execute the plot method
# -> 7254         ret = locals()[plot]()
#    7255         if ret:
#    7256             plot_filename = ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/tabular.py in confusion_matrix()
#    6552                 groups=groups,
#    6553                 display=display,
# -> 6554                 display_format=display_format,
#    6555             )
#    6556
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pycaret/internal/plots/yellowbrick.py in show_yellowbrick_plot(visualizer, X_train, y_train, X_test, y_test, name, handle_train, handle_test, scale, save, fit_kwargs, groups, display, display_format, **kwargs)
#      74     """
#      75     logger = get_logger()
# ---> 76     visualizer.fig.set_dpi(visualizer.fig.dpi * scale)
#      77
#      78     if not fit_kwargs:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yellowbrick/utils/wrapper.py in __getattr__(self, attr)
#      40     def __getattr__(self, attr):
#      41         # proxy to the wrapped object
# ---> 42         return getattr(self._wrapped, attr)
#
# AttributeError: 'Pipeline' object has no attribute 'fig'

# %% [markdown]
# ## Conclusions
# Here you can talk about next steps, did the experiment work? If yes, what to do next? If no, why?
