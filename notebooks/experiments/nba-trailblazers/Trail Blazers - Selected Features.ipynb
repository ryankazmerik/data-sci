# %% [markdown]
# # Portland Trail Blazers - Feature Selection
# * StellarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * October 8, 2021

# %% [markdown]
# ## Hypothesis
# Two very important components of a machine learning model are feature selection and feature engineering. Our idea is that adding some more features to the StellarAlgo retention model could improve performance of the model.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import pyodbc
import pandas as pd
import warnings
import matplotlib.pyplot as plt

from pycaret.classification import *
from ngboost import NGBClassifier

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password ··················

# %%
lkupclientid = 5 # Portland Trail Blazers

cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrTrailBlazers].[ds].[getRetentionScoringModelData] {lkupclientid}"""
)

df = pd.read_sql(storedProc, CNXN)

CNXN.commit()
cursor.close()

df.shape
# Out:
# (11004, 55)

# %% [markdown]
# ### Let's drop the features that have lots of null values, and any ID columns, as these won't be useful to our model:

# %%
df.drop([
    'dimCustomerMasterId',
    'source_tenure',
    'urbanicity', 
    'isnextyear_buyer', 
    'isnextyear_samepkg_buyer',
    'pkgupgrade_status',
    'auto_renewal'],
    axis=1, 
    inplace=True
)

df.shape
# Out:
# (11004, 48)

# %% [markdown]
# ### Let's also drop the features that only have a single value, as they won't add much differentiation to our model:

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        df.drop(col,inplace=True,axis=1)
        
df.shape
# Out:
# (11004, 30)

# %% [markdown]
# ### We should also drop features that have a low correlation with the target label as they won't be useful for prediction, we'll only keep features that have a correlation above a set threshold:

# %%
cor = df.corr()

threshold = 0.05

#Correlation with output variable
cor_target = abs(cor["isNextYear_Buyer"])

#Selecting highly correlated features
relevant_features = cor_target[cor_target > threshold]

feats = []
for name, val in relevant_features.items():
    feats.append(name)

df_correlated = df[feats]

df_correlated.shape

df_correlated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11004 entries, 0 to 11003
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   renewedBeforeDays    11004 non-null  int64
#  1   tenure               11004 non-null  int64
#  2   totalGames           11004 non-null  int64
#  3   recency              11004 non-null  int64
#  4   missed_games_1       11004 non-null  int64
#  5   missed_games_2       11004 non-null  int64
#  6   missed_games_over_2  11004 non-null  int64
#  7   click_link           11004 non-null  int64
#  8   fill_out_form        11004 non-null  int64
#  9   open_email           11004 non-null  int64
#  10  send_email           11004 non-null  int64
#  11  openToSendRatio      11004 non-null  float64
#  12  resale_records       11004 non-null  int64
#  13  resale_atp           11004 non-null  float64
#  14  isNextYear_Buyer     11004 non-null  int64
# dtypes: float64(2), int64(13)
# memory usage: 1.3 MB

# %% [markdown]
# ### Now that we have the right features we can look at the correlations between them, if features are highly correlated with each other it might negatively impact the model:

# %%
corr = df_correlated.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_a89d5_row0_col0,#T_a89d5_row1_col1,#T_a89d5_row2_col2,#T_a89d5_row3_col3,#T_a89d5_row4_col4,#T_a89d5_row5_col5,#T_a89d5_row6_col6,#T_a89d5_row7_col7,#T_a89d5_row8_col8,#T_a89d5_row9_col9,#T_a89d5_row10_col10,#T_a89d5_row11_col11,#T_a89d5_row12_col12,#T_a89d5_row13_col13,#T_a89d5_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a89d5_row0_col1{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_a89d5_row0_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_a89d5_row0_col3,#T_a89d5_row11_col3{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_a89d5_row0_col4{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_a89d5_row0_col5,#T_a89d5_row9_col11,#T_a89d5_row10_col7{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_a89d5_row0_col6,#T_a89d5_row0_col9,#T_a89d5_row3_col9{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_a89d5_row0_col7,#T_a89d5_row11_col4,#T_a89d5_row12_col4,#T_a89d5_row14_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_a89d5_row0_col8{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_a89d5_row0_col10{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_a89d5_row0_col11,#T_a89d5_row6_col2,#T_a89d5_row9_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_a89d5_row0_col12,#T_a89d5_row4_col8,#T_a89d5_row8_col3{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_a89d5_row0_col13,#T_a89d5_row2_col11,#T_a89d5_row7_col2{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_a89d5_row0_col14{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_a89d5_row1_col0{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_a89d5_row1_col2,#T_a89d5_row4_col11{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_a89d5_row1_col3,#T_a89d5_row1_col12,#T_a89d5_row1_col13{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_a89d5_row1_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_a89d5_row1_col5{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_a89d5_row1_col6{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_a89d5_row1_col7,#T_a89d5_row10_col13{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_a89d5_row1_col8{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_a89d5_row1_col9,#T_a89d5_row9_col5{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_a89d5_row1_col10,#T_a89d5_row2_col7,#T_a89d5_row7_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_a89d5_row1_col11,#T_a89d5_row4_col9{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_a89d5_row1_col14,#T_a89d5_row2_col1,#T_a89d5_row3_col1,#T_a89d5_row6_col3,#T_a89d5_row12_col1,#T_a89d5_row13_col1{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_a89d5_row2_col0,#T_a89d5_row10_col3,#T_a89d5_row13_col0,#T_a89d5_row14_col13{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_a89d5_row2_col3,#T_a89d5_row2_col4{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_a89d5_row2_col5{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_a89d5_row2_col6{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_a89d5_row2_col8,#T_a89d5_row7_col13,#T_a89d5_row8_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_a89d5_row2_col9{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_a89d5_row2_col10{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_a89d5_row2_col12,#T_a89d5_row10_col4,#T_a89d5_row13_col11{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_a89d5_row2_col13{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_a89d5_row2_col14,#T_a89d5_row7_col11{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_a89d5_row3_col0,#T_a89d5_row4_col10,#T_a89d5_row9_col12{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_a89d5_row3_col2,#T_a89d5_row4_col5{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_a89d5_row3_col4,#T_a89d5_row4_col6,#T_a89d5_row11_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_a89d5_row3_col5,#T_a89d5_row3_col10,#T_a89d5_row12_col5,#T_a89d5_row12_col13,#T_a89d5_row12_col14,#T_a89d5_row13_col5,#T_a89d5_row13_col12{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_a89d5_row3_col6,#T_a89d5_row7_col14{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_a89d5_row3_col7,#T_a89d5_row14_col0{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_a89d5_row3_col8,#T_a89d5_row7_col3{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_a89d5_row3_col11{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_a89d5_row3_col12{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_a89d5_row3_col13,#T_a89d5_row8_col13,#T_a89d5_row11_col12{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_a89d5_row3_col14{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_a89d5_row4_col0,#T_a89d5_row14_col2{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_a89d5_row4_col1{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_a89d5_row4_col2{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_a89d5_row4_col3{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_a89d5_row4_col7,#T_a89d5_row6_col11,#T_a89d5_row8_col12,#T_a89d5_row13_col3{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_a89d5_row4_col12,#T_a89d5_row8_col2,#T_a89d5_row12_col2{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_a89d5_row4_col13{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_a89d5_row4_col14{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_a89d5_row5_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_a89d5_row5_col1,#T_a89d5_row7_col6{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_a89d5_row5_col2,#T_a89d5_row5_col3,#T_a89d5_row5_col6,#T_a89d5_row5_col7,#T_a89d5_row5_col8,#T_a89d5_row5_col9,#T_a89d5_row5_col10,#T_a89d5_row5_col11,#T_a89d5_row5_col12,#T_a89d5_row5_col13,#T_a89d5_row5_col14,#T_a89d5_row6_col0,#T_a89d5_row6_col1,#T_a89d5_row6_col4,#T_a89d5_row6_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_a89d5_row5_col4,#T_a89d5_row9_col2,#T_a89d5_row10_col2,#T_a89d5_row12_col11{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_a89d5_row6_col7,#T_a89d5_row13_col6,#T_a89d5_row14_col7{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_a89d5_row6_col8,#T_a89d5_row13_col7{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_a89d5_row6_col9{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_a89d5_row6_col10{
#             background-co

# %% [markdown]
# ### In order to compare two sets of features, we need to create some datasets for training and evalution:

# %%
# select % of the data for training
df_train = df_correlated.sample(frac=0.8, random_state=786).reset_index(drop=True)

# create the eval datasets for A and B
df_eval = df_correlated.drop(df_train.index).reset_index(drop=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (8803, 15)
# Unseen Data For Predictions: (2201, 15)

# %% [markdown]
# ## Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.80,
    data_split_shuffle=True,
    silent=True,
    numeric_features=[
        "click_link",
        "fill_out_form",
        "missed_games_1",
        "missed_games_2",
        "missed_games_over_2",
        "open_email",
        "openToSendRatio",
        "recency",
        "renewedBeforeDays",
        "send_email"
    ]
)

# %%
# adding an extra classifier ngboost
ngc = NGBClassifier()
ngboost = create_model(ngc)

model_matrix = compare_models(
    fold=10,
    include=["ada","dt","gbc","et","knn","lightgbm","lr","rf",ngboost,"xgboost"]
)
# Out:
# <style  type="text/css" >
#     #T_abe9c_ th {
#           text-align: left;
#     }#T_abe9c_row0_col0,#T_abe9c_row0_col2,#T_abe9c_row0_col3,#T_abe9c_row0_col5,#T_abe9c_row0_col6,#T_abe9c_row0_col7,#T_abe9c_row1_col0,#T_abe9c_row1_col1,#T_abe9c_row1_col2,#T_abe9c_row1_col3,#T_abe9c_row1_col4,#T_abe9c_row1_col7,#T_abe9c_row2_col0,#T_abe9c_row2_col1,#T_abe9c_row2_col4,#T_abe9c_row2_col5,#T_abe9c_row2_col6,#T_abe9c_row3_col0,#T_abe9c_row3_col1,#T_abe9c_row3_col2,#T_abe9c_row3_col3,#T_abe9c_row3_col4,#T_abe9c_row3_col5,#T_abe9c_row3_col6,#T_abe9c_row3_col7,#T_abe9c_row4_col0,#T_abe9c_row4_col1,#T_abe9c_row4_col2,#T_abe9c_row4_col3,#T_abe9c_row4_col4,#T_abe9c_row4_col5,#T_abe9c_row4_col6,#T_abe9c_row4_col7,#T_abe9c_row5_col0,#T_abe9c_row5_col1,#T_abe9c_row5_col2,#T_abe9c_row5_col3,#T_abe9c_row5_col4,#T_abe9c_row5_col5,#T_abe9c_row5_col6,#T_abe9c_row5_col7,#T_abe9c_row6_col0,#T_abe9c_row6_col1,#T_abe9c_row6_col2,#T_abe9c_row6_col3,#T_abe9c_row6_col4,#T_abe9c_row6_col5,#T_abe9c_row6_col6,#T_abe9c_row6_col7,#T_abe9c_row7_col0,#T_abe9c_row7_col1,#T_abe9c_row7_col2,#T_abe9c_row7_col3,#T_abe9c_row7_col4,#T_abe9c_row7_col5,#T_abe9c_row7_col6,#T_abe9c_row7_col7,#T_abe9c_row8_col0,#T_abe9c_row8_col1,#T_abe9c_row8_col2,#T_abe9c_row8_col3,#T_abe9c_row8_col4,#T_abe9c_row8_col5,#T_abe9c_row8_col6,#T_abe9c_row8_col7,#T_abe9c_row9_col0,#T_abe9c_row9_col1,#T_abe9c_row9_col2,#T_abe9c_row9_col3,#T_abe9c_row9_col4,#T_abe9c_row9_col5,#T_abe9c_row9_col6,#T_abe9c_row9_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_abe9c_row0_col1,#T_abe9c_row0_col4,#T_abe9c_row1_col5,#T_abe9c_row1_col6,#T_abe9c_row2_col2,#T_abe9c_row2_col3,#T_abe9c_row2_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_abe9c_row0_col8,#T_abe9c_row1_col8,#T_abe9c_row2_col8,#T_abe9c_row3_col8,#T_abe9c_row4_col8,#T_abe9c_row5_col8,#T_abe9c_row6_col8,#T_abe9c_row7_col8,#T_abe9c_row8_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_abe9c_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_abe9c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abe9c_level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_abe9c_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_abe9c_row0_col1" class="data row0 col1" >0.8837</td>
#                         <td id="T_abe9c_row0_col2" class="data row0 col2" >0.9430</td>
#                         <td id="T_abe9c_row0_col3" class="data row0 col3" >0.9073</td>
#                         <td id="T_abe9c_row0_col4" class="data row0 col4" >0.7788</td>
#                         <td id="T_abe9c_row0_col5" class="data row0 col5" >0.8377</td>
#                         <td id="T_abe9c_row0_col6" class="data row0 col6" >0.7479</td>
#                         <td id="T_abe9c_row0_col7" class="data row0 col7" >0.7538</td>
#                         <td id="T_abe9c_row0_col8" class="data row0 col8" >0.1100</td>
#             </tr>
#             <tr>
#                         <th id="T_abe9c_level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_abe9c_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#                         <td id="T_abe9c_row1_col1" class="data row1 col1" >0.8831</td>
#                         <td id="T_abe9c_row1_col2" class="data row1 col2" >0.9418</td>
#                         <td id="T_abe9c_row1_col3" class="data row1 col3" >0.9176</td>
#                         <td id="T_abe9c_row1_col4" class="data row1 col4" >0.7728</td>
#                         <td id="T_abe9c_row1_col5" class="data row1 col5" >0.8385</td>
#                         <td id="T_abe9c_row1_col6" class="data row1 col6" >0.7481</td>
#                         <td id="T_abe9c_row1_col7" class="data row1 col7" >0.7554</td>
#                         <td id="T_abe9c_row1_col8" class="data row1 col8" >0.1950</td>
#             </tr>
#             <tr>
#                         <th id="T_abe9c_level0_row2" class="row_heading level0 row2" >8</th>
#                         <td id="T_abe9c_row2_col0" class="data row2 col0" >NGBClassifier</td>
#                         <td id="T_abe9c_row2_col1" class="data row2 col1" >0.8809</td>
#                         <td id="T_abe9c_row2_col2" class="data row2 col2" >0.9435</td>
#                         <td id="T_abe9c_row2_col3" class="data row2 col3" >0.9326</td>
#                         <td id="T_abe9c_row2_col4" class="data row2 col4" >0.7628</td>
#                         <td id="T_abe9c_row2_col5" class="data row2 col5" >0.8381</td>
#                         <td id="T_abe9c_row2_col6" class="data row2 col6" >0.7455</td>
#                         <td id="T_abe9c_row2_col7" class="data row2 col7" >0.7564</td>
#                         <td id="T_abe9c_row2_col8" class="data row2 col8" >1.3650</td>
#             </tr>
#             <tr>
#                         <th id="T_abe9c_level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_abe9c_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_abe9c_row3_col1" class="data row3 col1" >0.8806</td>
#                         <td id="T_abe9c_row3_col2" class="data row3 col2" >0.9411</td>
#                         <td id="T_abe9c_row3_col3" class="data row3 col3" >0.9077</td>
#                         <td id="T_abe9c_row3_col4" class="data row3 col4" >0.7725</td>
#                         <td id="T_abe9c_row3_col5" class="data row3 col5" >0.8342</td>
#                         <td id="T_abe9c_row3_col6" class="data row3 col6" >0.7419</td>
#                         <td id="T_abe9c_row3_col7" class="data row3 col7" >0.7483</td>
#                         <td id="T_abe9c_row3_col8" class="data row3 col8" >0.0290</td>
#             </tr>
#             <tr>
#                         <th id="T_abe9c_level0_row4" class="row_heading level0 row4" >7</th>
#                         <td id="T_abe9c_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#                         <td id="T_abe9c_row4_col1" class="data row4 col1" >0.8796</td>
#                         <td id="T_abe9c_row4_col2" class="data row4 col2" >0.9377</td>
#                         <td id="T_abe9c_row4_col3" class="data row4 col3" >0.8935</td>
#                         <td id="T_abe9c_row4_col4" class="data row4 col4" >0.7768</td>
#                         <td id="T_abe9c_row4_col5" class="data row4 col5" >0.8307</td>
#                         <td id="T_abe9c_row4_col6" class="data row4 col6" >0.7380</td>
#                         <td id="T_abe9c_row4_col7" class="data row4 col7" >0.7428</td>
#                         <td id="T_abe9c_row4_col8" class="data row4 col8" >0.1490</td>
#             </tr>
#             <tr>
#                         <th id="T_abe9c_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_abe9c_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_abe9c_row5_col1" class="data row5 col1" >0.8743</td>
#                         <td id="T_abe9c_row5_col2" class="data row5 col2" >0.9392</td>
#                         <td id="T_abe9c_row5_col3" class="data row5 col3" >0.8763</td>
#                         <td id="T_ab

# %% [markdown]
# ### The top model is performing well, so let's compare it against our unseen eval dataset:

# %%
best_model = create_model(model_matrix)

unseen_predictions = predict_model(best_model, data=df_eval)
# Out:
# <style  type="text/css" >
# #T_3dd92_row10_col0,#T_3dd92_row10_col1,#T_3dd92_row10_col2,#T_3dd92_row10_col3,#T_3dd92_row10_col4,#T_3dd92_row10_col5,#T_3dd92_row10_col6{
#             background:  yellow;
#         }</style><table id="T_3dd92_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3dd92_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3dd92_row0_col0" class="data row0 col0" >0.8709</td>
#                         <td id="T_3dd92_row0_col1" class="data row0 col1" >0.9334</td>
#                         <td id="T_3dd92_row0_col2" class="data row0 col2" >0.8584</td>
#                         <td id="T_3dd92_row0_col3" class="data row0 col3" >0.7752</td>
#                         <td id="T_3dd92_row0_col4" class="data row0 col4" >0.8147</td>
#                         <td id="T_3dd92_row0_col5" class="data row0 col5" >0.7160</td>
#                         <td id="T_3dd92_row0_col6" class="data row0 col6" >0.7182</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3dd92_row1_col0" class="data row1 col0" >0.8610</td>
#                         <td id="T_3dd92_row1_col1" class="data row1 col1" >0.9411</td>
#                         <td id="T_3dd92_row1_col2" class="data row1 col2" >0.8798</td>
#                         <td id="T_3dd92_row1_col3" class="data row1 col3" >0.7455</td>
#                         <td id="T_3dd92_row1_col4" class="data row1 col4" >0.8071</td>
#                         <td id="T_3dd92_row1_col5" class="data row1 col5" >0.6996</td>
#                         <td id="T_3dd92_row1_col6" class="data row1 col6" >0.7055</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3dd92_row2_col0" class="data row2 col0" >0.8679</td>
#                         <td id="T_3dd92_row2_col1" class="data row2 col1" >0.9372</td>
#                         <td id="T_3dd92_row2_col2" class="data row2 col2" >0.8841</td>
#                         <td id="T_3dd92_row2_col3" class="data row2 col3" >0.7574</td>
#                         <td id="T_3dd92_row2_col4" class="data row2 col4" >0.8158</td>
#                         <td id="T_3dd92_row2_col5" class="data row2 col5" >0.7138</td>
#                         <td id="T_3dd92_row2_col6" class="data row2 col6" >0.7190</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3dd92_row3_col0" class="data row3 col0" >0.8963</td>
#                         <td id="T_3dd92_row3_col1" class="data row3 col1" >0.9434</td>
#                         <td id="T_3dd92_row3_col2" class="data row3 col2" >0.9528</td>
#                         <td id="T_3dd92_row3_col3" class="data row3 col3" >0.7817</td>
#                         <td id="T_3dd92_row3_col4" class="data row3 col4" >0.8588</td>
#                         <td id="T_3dd92_row3_col5" class="data row3 col5" >0.7781</td>
#                         <td id="T_3dd92_row3_col6" class="data row3 col6" >0.7876</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3dd92_row4_col0" class="data row4 col0" >0.8906</td>
#                         <td id="T_3dd92_row4_col1" class="data row4 col1" >0.9447</td>
#                         <td id="T_3dd92_row4_col2" class="data row4 col2" >0.8670</td>
#                         <td id="T_3dd92_row4_col3" class="data row4 col3" >0.8145</td>
#                         <td id="T_3dd92_row4_col4" class="data row4 col4" >0.8399</td>
#                         <td id="T_3dd92_row4_col5" class="data row4 col5" >0.7570</td>
#                         <td id="T_3dd92_row4_col6" class="data row4 col6" >0.7578</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3dd92_row5_col0" class="data row5 col0" >0.9006</td>
#                         <td id="T_3dd92_row5_col1" class="data row5 col1" >0.9428</td>
#                         <td id="T_3dd92_row5_col2" class="data row5 col2" >0.9227</td>
#                         <td id="T_3dd92_row5_col3" class="data row5 col3" >0.8052</td>
#                         <td id="T_3dd92_row5_col4" class="data row5 col4" >0.8600</td>
#                         <td id="T_3dd92_row5_col5" class="data row5 col5" >0.7835</td>
#                         <td id="T_3dd92_row5_col6" class="data row5 col6" >0.7878</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3dd92_row6_col0" class="data row6 col0" >0.8935</td>
#                         <td id="T_3dd92_row6_col1" class="data row6 col1" >0.9518</td>
#                         <td id="T_3dd92_row6_col2" class="data row6 col2" >0.9056</td>
#                         <td id="T_3dd92_row6_col3" class="data row6 col3" >0.7992</td>
#                         <td id="T_3dd92_row6_col4" class="data row6 col4" >0.8491</td>
#                         <td id="T_3dd92_row6_col5" class="data row6 col5" >0.7673</td>
#                         <td id="T_3dd92_row6_col6" class="data row6 col6" >0.7708</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3dd92_row7_col0" class="data row7 col0" >0.9020</td>
#                         <td id="T_3dd92_row7_col1" class="data row7 col1" >0.9554</td>
#                         <td id="T_3dd92_row7_col2" class="data row7 col2" >0.9270</td>
#                         <td id="T_3dd92_row7_col3" class="data row7 col3" >0.8060</td>
#                         <td id="T_3dd92_row7_col4" class="data row7 col4" >0.8623</td>
#                         <td id="T_3dd92_row7_col5" class="data row7 col5" >0.7868</td>
#                         <td id="T_3dd92_row7_col6" class="data row7 col6" >0.7914</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3dd92_row8_col0" class="data row8 col0" >0.8722</td>
#                         <td id="T_3dd92_row8_col1" class="data row8 col1" >0.9372</td>
#                         <td id="T_3dd92_row8_col2" class="data row8 col2" >0.9399</td>
#                         <td id="T_3dd92_row8_col3" class="data row8 col3" >0.7424</td>
#                         <td id="T_3dd92_row8_col4" class="data row8 col4" >0.8295</td>
#                         <td id="T_3dd92_row8_col5" class="data row8 col5" >0.7295</td>
#                         <td id="T_3dd92_row8_col6" class="data row8 col6" >0.7425</td>
#             </tr>
#             <tr>
#                         <th id="T_3dd92_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3dd92_row9_col0" class="data row9 col0" >0.8821</td>
#                         <td id="T_3dd92_row9_col1" class="data row9 col1" >0.9436</td>
#                         <td id="T_3dd92_row9_col2" class="data row9 col2" >0.9353</td>
#                         <td id="T_3dd92_row9_col3" class="data row9 col3" >0.7614</td>
#                         <td id="T_3dd92_row9_col4" class="data row9 col4" >0.8395</td>
#                         <td id="T_3dd92_row9_col5" class="data row9 col5" >0.7478</td>
#                         <td id=

# %%
plot_model(best_model, plot='feature')

# %%
plot_model(best_model, plot='confusion_matrix')

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
# Here you can document some ideas on the results from above

# %% [markdown]
# ## Conclusions
# Here you can talk about next steps, did the experiment work? If yes, what to do next? If no, why?
