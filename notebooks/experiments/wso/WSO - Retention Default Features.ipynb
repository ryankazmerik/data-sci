# %% [markdown]
# # WSO Retention Model
# * StelllarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * May 18, 2022

# %% [markdown]
# ## Hypothesis
# This notebook will test the standard StellarAlgo retention model features and the goal is to check if our standard retention model works for WSO or not and how our accuracy and scores look. We are also checking if we have enough data for training the retention model effectively.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import boto3
import pandas as pd
import psycopg2
import matplotlib.pyplot as plt

from pycaret.classification import *

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ### To connect to RedShift, we have to tell AWS which profile we'd like to login to, this will send us for a browser authentication trip:

# %%
! aws sso login --profile Stellaralgo-DataScienceAdmin
# Out:
# Attempting to automatically open the SSO authorization page in your default browser.
# If the browser does not open or you wish to use a different device to authorize this request, open the following URL:
#
# https://device.sso.us-east-1.amazonaws.com/
#
# Then enter the code:
#
# KDJL-QNLC
# Successully logged into Start URL: https://stellaralgo.awsapps.com/start

# %% [markdown]
# ### Now we can create a session and client to RedShift, and create a new connection using Psycopg2:

# %%
session = boto3.session.Session(profile_name='Stellaralgo-DataScienceAdmin')
client = session.client('redshift')

CLUSTER = 'qa-app'
DBNAME = 'stlrwso'

creds = client.get_cluster_credentials(                
    ClusterIdentifier = CLUSTER,
    DbUser = 'admin',
    DbName = DBNAME,
    DbGroups = ['admin_group'],
    AutoCreate=True
)

print(f"GOT CONNECTION TO DATABASE: {CLUSTER} {DBNAME}")
# Out:
# GOT CONNECTION TO DATABASE: qa-app stlrwso

# %% [markdown]
# ### First we need to call the stored procedure, which will create a named cursor - then we can query the results produced by the stored proc using that named cursor:

# %%
# create a connection & cursor and call the stored procedure
conn = psycopg2.connect(
    host = 'qa-app.ctjussvyafp4.us-east-1.redshift.amazonaws.com',
    port = 5439,
    user = creds['DbUser'],
    password = creds['DbPassword'],
    database = DBNAME
)

cur = conn.cursor()
cur.execute(f"CALL dw.getretentionmodeldata(14, 2010, 2021, 'rkcursor')")

# create a named cursor based on the cursor name passed in above
named_cursor = conn.cursor('rkcursor')
data = named_cursor.fetchall()

# load the data and columns into a data frame
cols = [row[0] for row in named_cursor.description]
df = pd.DataFrame(data=data, columns=cols)

conn.commit()

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12251 entries, 0 to 12250
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   lkupclientid         12251 non-null  int64
#  1   dimcustomermasterid  12251 non-null  int64
#  2   year                 12251 non-null  int64
#  3   productgrouping      12251 non-null  object
#  4   totalspent           12251 non-null  float64
#  5   recentdate           12251 non-null  datetime64[ns]
#  6   attendancepercent    12251 non-null  float64
#  7   renewedbeforedays    12251 non-null  int64
#  8   source_tenure        12251 non-null  object
#  9   tenure               12251 non-null  int64
#  10  disttovenue          12251 non-null  float64
#  11  recency              12251 non-null  int64
#  12  missed_games_1       12251 non-null  object
#  13  missed_games_2       12251 non-null  object
#  14  missed_games_over_2  12251 non-null  object
#  15  forward_records      12251 non-null  int64
#  16  opentosendratio      12251 non-null  object
#  17  clicktosendratio     12251 non-null  object
#  18  clicktoopenratio     12251 non-null  object
#  19  gender               12251 non-null  object
#  20  phonecall            12251 non-null  int64
#  21  inperson_contact     12251 non-null  int64
#  22  isnextyear_buyer     12251 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(10), object(9)
# memory usage: 2.1+ MB
#    lkupclientid  dimcustomermasterid  year productgrouping  totalspent  \
# 0            14            296604868  2016     Full Series       62.50
# 1            14            277980900  2016     Full Series       87.50
# 2            14            278047462  2016     Full Series      368.76
# 3            14            278017194  2016     Full Series      100.00
# 4            14            296601973  2016     Full Series       50.00
#
#   recentdate  attendancepercent  renewedbeforedays source_tenure  tenure  \
# 0 1970-01-01               0.40                253          6935     261
# 1 1970-01-01               0.53                250          3650     258
# 2 1970-01-01               0.25                124          2555     132
# 3 2016-08-18               0.63                243          2920     251
# 4 2016-08-21               0.67                228          8760     236
#
#    disttovenue  recency missed_games_1 missed_games_2 missed_games_over_2  \
# 0        34.23        0              0              0                   1
# 1       390.90        0              0              0                   1
# 2       615.89        0              0              0                   1
# 3       417.58        0              0              0                   1
# 4       896.58        0              0              0                   4
#
#    forward_records opentosendratio clicktosendratio clicktoopenratio   gender  \
# 0                0            0.00             0.00             0.00  Unknown
# 1                0            0.00             0.00             0.00  Unknown
# 2                0            0.00             0.00             0.00  Unknown
# 3                0            0.00             0.00             0.00  Unknown
# 4                0            0.00             0.00             0.00  Unknown
#
#    phonecall  inperson_contact  isnextyear_buyer
# 0          0                 0                 1
# 1          0                 0                 0
# 2          0                 0                 0
# 3          0                 0                 0
# 4          0                 0                 1

# %% [markdown]
# ### Let's see how much data we have for each year:

# %%
df["year"].value_counts().sort_index(ascending=False)
# Out:
# 2021    2397
# 2019    2389
# 2018    2717
# 2017    2412
# 2016    2336
# Name: year, dtype: int64

# %% [markdown]
# ### We should specify the features used in our model:

# %%
# choose the features for the stellar base retention model
features = [
                "dimcustomermasterid",
                "attendancepercent",
                "disttovenue",
                "missed_games_1",
                "missed_games_2",
                "missed_games_over_2",
                "totalspent",
                "recency",
                "source_tenure",
                "renewedbeforedays",
                "isnextyear_buyer",
                "productgrouping",
                "year"
]

# copy your main dataframe
df_dataset = df

# choose the features & train year & test year
df_dataset = df_dataset[features]
df_dataset["year"] = pd.to_numeric(df_dataset["year"])
df_dataset = df_dataset.loc[df_dataset["year"] <= 2019]

df_train = df_dataset.sample(frac=0.85, random_state=786)
df_eval = df_dataset.drop(df_train.index)

df_train.reset_index(drop=True, inplace=True)
df_eval.reset_index(drop=True, inplace=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (8376, 13)
# Unseen Data For Predictions: (1478, 13)

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isnextyear_buyer", 
    train_size = 0.85,
    data_split_shuffle=True,
    ignore_features=["dimcustomermasterid","productgrouping","year"],
    silent=True,
    verbose=False,
    numeric_features=[
                "attendancepercent",
                "disttovenue",
                "missed_games_1",
                "missed_games_2",
                "missed_games_over_2",
                "totalspent",
                "recency",
                "source_tenure",
                "renewedbeforedays"
    ]
);

# %%
model_matrix = compare_models(
    fold=10,
    include=["dummy", "dt", "gbc", "lightgbm", "lr", "rf", "xgboost"]
)
# Out:
# <style type="text/css">
# #T_611f8_ th {
#   text-align: left;
# }
# #T_611f8_row0_col0, #T_611f8_row0_col3, #T_611f8_row0_col4, #T_611f8_row1_col0, #T_611f8_row1_col1, #T_611f8_row1_col2, #T_611f8_row1_col4, #T_611f8_row1_col5, #T_611f8_row1_col6, #T_611f8_row1_col7, #T_611f8_row2_col0, #T_611f8_row2_col1, #T_611f8_row2_col2, #T_611f8_row2_col3, #T_611f8_row2_col5, #T_611f8_row2_col6, #T_611f8_row2_col7, #T_611f8_row3_col0, #T_611f8_row3_col1, #T_611f8_row3_col2, #T_611f8_row3_col3, #T_611f8_row3_col4, #T_611f8_row3_col5, #T_611f8_row3_col6, #T_611f8_row3_col7, #T_611f8_row4_col0, #T_611f8_row4_col1, #T_611f8_row4_col2, #T_611f8_row4_col3, #T_611f8_row4_col4, #T_611f8_row4_col5, #T_611f8_row4_col6, #T_611f8_row4_col7, #T_611f8_row5_col0, #T_611f8_row5_col1, #T_611f8_row5_col2, #T_611f8_row5_col3, #T_611f8_row5_col4, #T_611f8_row5_col5, #T_611f8_row5_col6, #T_611f8_row5_col7, #T_611f8_row6_col0, #T_611f8_row6_col1, #T_611f8_row6_col2, #T_611f8_row6_col3, #T_611f8_row6_col4, #T_611f8_row6_col5, #T_611f8_row6_col6, #T_611f8_row6_col7 {
#   text-align: left;
# }
# #T_611f8_row0_col1, #T_611f8_row0_col2, #T_611f8_row0_col5, #T_611f8_row0_col6, #T_611f8_row0_col7, #T_611f8_row1_col3, #T_611f8_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_611f8_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_611f8_row1_col8, #T_611f8_row2_col8, #T_611f8_row3_col8, #T_611f8_row4_col8, #T_611f8_row5_col8, #T_611f8_row6_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_611f8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_611f8_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_611f8_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_611f8_row0_col1" class="data row0 col1" >0.8180</td>
#       <td id="T_611f8_row0_col2" class="data row0 col2" >0.8961</td>
#       <td id="T_611f8_row0_col3" class="data row0 col3" >0.7731</td>
#       <td id="T_611f8_row0_col4" class="data row0 col4" >0.8116</td>
#       <td id="T_611f8_row0_col5" class="data row0 col5" >0.7916</td>
#       <td id="T_611f8_row0_col6" class="data row0 col6" >0.6302</td>
#       <td id="T_611f8_row0_col7" class="data row0 col7" >0.6310</td>
#       <td id="T_611f8_row0_col8" class="data row0 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_611f8_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_611f8_row1_col1" class="data row1 col1" >0.8143</td>
#       <td id="T_611f8_row1_col2" class="data row1 col2" >0.8926</td>
#       <td id="T_611f8_row1_col3" class="data row1 col3" >0.7756</td>
#       <td id="T_611f8_row1_col4" class="data row1 col4" >0.8031</td>
#       <td id="T_611f8_row1_col5" class="data row1 col5" >0.7888</td>
#       <td id="T_611f8_row1_col6" class="data row1 col6" >0.6232</td>
#       <td id="T_611f8_row1_col7" class="data row1 col7" >0.6239</td>
#       <td id="T_611f8_row1_col8" class="data row1 col8" >0.2720</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_611f8_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_611f8_row2_col1" class="data row2 col1" >0.8098</td>
#       <td id="T_611f8_row2_col2" class="data row2 col2" >0.8870</td>
#       <td id="T_611f8_row2_col3" class="data row2 col3" >0.7392</td>
#       <td id="T_611f8_row2_col4" class="data row2 col4" >0.8191</td>
#       <td id="T_611f8_row2_col5" class="data row2 col5" >0.7767</td>
#       <td id="T_611f8_row2_col6" class="data row2 col6" >0.6118</td>
#       <td id="T_611f8_row2_col7" class="data row2 col7" >0.6147</td>
#       <td id="T_611f8_row2_col8" class="data row2 col8" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_611f8_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_611f8_row3_col1" class="data row3 col1" >0.7965</td>
#       <td id="T_611f8_row3_col2" class="data row3 col2" >0.8784</td>
#       <td id="T_611f8_row3_col3" class="data row3 col3" >0.7382</td>
#       <td id="T_611f8_row3_col4" class="data row3 col4" >0.7930</td>
#       <td id="T_611f8_row3_col5" class="data row3 col5" >0.7642</td>
#       <td id="T_611f8_row3_col6" class="data row3 col6" >0.5856</td>
#       <td id="T_611f8_row3_col7" class="data row3 col7" >0.5872</td>
#       <td id="T_611f8_row3_col8" class="data row3 col8" >0.1150</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_611f8_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_611f8_row4_col1" class="data row4 col1" >0.7473</td>
#       <td id="T_611f8_row4_col2" class="data row4 col2" >0.7447</td>
#       <td id="T_611f8_row4_col3" class="data row4 col3" >0.7200</td>
#       <td id="T_611f8_row4_col4" class="data row4 col4" >0.7167</td>
#       <td id="T_611f8_row4_col5" class="data row4 col5" >0.7182</td>
#       <td id="T_611f8_row4_col6" class="data row4 col6" >0.4892</td>
#       <td id="T_611f8_row4_col7" class="data row4 col7" >0.4893</td>
#       <td id="T_611f8_row4_col8" class="data row4 col8" >0.1660</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_611f8_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_611f8_row5_col1" class="data row5 col1" >0.7356</td>
#       <td id="T_611f8_row5_col2" class="data row5 col2" >0.8101</td>
#       <td id="T_611f8_row5_col3" class="data row5 col3" >0.7248</td>
#       <td id="T_611f8_row5_col4" class="data row5 col4" >0.6968</td>
#       <td id="T_611f8_row5_col5" class="data row5 col5" >0.7103</td>
#       <td id="T_611f8_row5_col6" class="data row5 col6" >0.4674</td>
#       <td id="T_611f8_row5_col7" class="data row5 col7" >0.4680</td>
#       <td id="T_611f8_row5_col8" class="data row5 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_611f8_level0_row6" class="row_heading level0 row6" >dummy</th>
#       <td id="T_611f8_row6_col0" class="data row6 col0" >Dummy Classifier</td>
#       <td id="T_611f8_row6_col1" class="data row6 col1" >0.5525</td>
#       <td id="T_611f8_row6_col2" class="data row6 col2" >0.5000</td>
#       <td id="T_611f8_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_611f8_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_611f8_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_611f8_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_611f8_row6_col7" class="data row6 col7" >0.0000</td>
#       <td id="T_611f8_row6_col8" class="data row6 col8" >0.6240</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = create_model(model_matrix)
final_model = finalize_model(best_model)
# Out:
# <style type="text/css">
# #T_9b4e0_row10_col0, #T_9b4e0_row10_col1, #T_9b4e0_row10_col2, #T_9b4e0_row10_col3, #T_9b4e0_row10_col4, #T_9b4e0_row10_col5, #T_9b4e0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9b4e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b4e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b4e0_row0_col0" class="data row0 col0" >0.7992</td>
#       <td id="T_9b4e0_row0_col1" class="data row0 col1" >0.8830</td>
#       <td id="T_9b4e0_row0_col2" class="data row0 col2" >0.7398</td>
#       <td id="T_9b4e0_row0_col3" class="data row0 col3" >0.7973</td>
#       <td id="T_9b4e0_row0_col4" class="data row0 col4" >0.7675</td>
#       <td id="T_9b4e0_row0_col5" class="data row0 col5" >0.5912</td>
#       <td id="T_9b4e0_row0_col6" class="data row0 col6" >0.5924</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b4e0_row1_col0" class="data row1 col0" >0.8104</td>
#       <td id="T_9b4e0_row1_col1" class="data row1 col1" >0.9017</td>
#       <td id="T_9b4e0_row1_col2" class="data row1 col2" >0.7524</td>
#       <td id="T_9b4e0_row1_col3" class="data row1 col3" >0.8108</td>
#       <td id="T_9b4e0_row1_col4" class="data row1 col4" >0.7805</td>
#       <td id="T_9b4e0_row1_col5" class="data row1 col5" >0.6140</td>
#       <td id="T_9b4e0_row1_col6" class="data row1 col6" >0.6154</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b4e0_row2_col0" class="data row2 col0" >0.8202</td>
#       <td id="T_9b4e0_row2_col1" class="data row2 col1" >0.8992</td>
#       <td id="T_9b4e0_row2_col2" class="data row2 col2" >0.7931</td>
#       <td id="T_9b4e0_row2_col3" class="data row2 col3" >0.8032</td>
#       <td id="T_9b4e0_row2_col4" class="data row2 col4" >0.7981</td>
#       <td id="T_9b4e0_row2_col5" class="data row2 col5" >0.6361</td>
#       <td id="T_9b4e0_row2_col6" class="data row2 col6" >0.6361</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b4e0_row3_col0" class="data row3 col0" >0.8132</td>
#       <td id="T_9b4e0_row3_col1" class="data row3 col1" >0.8892</td>
#       <td id="T_9b4e0_row3_col2" class="data row3 col2" >0.7304</td>
#       <td id="T_9b4e0_row3_col3" class="data row3 col3" >0.8321</td>
#       <td id="T_9b4e0_row3_col4" class="data row3 col4" >0.7780</td>
#       <td id="T_9b4e0_row3_col5" class="data row3 col5" >0.6179</td>
#       <td id="T_9b4e0_row3_col6" class="data row3 col6" >0.6218</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b4e0_row4_col0" class="data row4 col0" >0.8329</td>
#       <td id="T_9b4e0_row4_col1" class="data row4 col1" >0.9040</td>
#       <td id="T_9b4e0_row4_col2" class="data row4 col2" >0.7868</td>
#       <td id="T_9b4e0_row4_col3" class="data row4 col3" >0.8311</td>
#       <td id="T_9b4e0_row4_col4" class="data row4 col4" >0.8084</td>
#       <td id="T_9b4e0_row4_col5" class="data row4 col5" >0.6604</td>
#       <td id="T_9b4e0_row4_col6" class="data row4 col6" >0.6612</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b4e0_row5_col0" class="data row5 col0" >0.8104</td>
#       <td id="T_9b4e0_row5_col1" class="data row5 col1" >0.8905</td>
#       <td id="T_9b4e0_row5_col2" class="data row5 col2" >0.7806</td>
#       <td id="T_9b4e0_row5_col3" class="data row5 col3" >0.7930</td>
#       <td id="T_9b4e0_row5_col4" class="data row5 col4" >0.7867</td>
#       <td id="T_9b4e0_row5_col5" class="data row5 col5" >0.6161</td>
#       <td id="T_9b4e0_row5_col6" class="data row5 col6" >0.6161</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b4e0_row6_col0" class="data row6 col0" >0.8062</td>
#       <td id="T_9b4e0_row6_col1" class="data row6 col1" >0.8888</td>
#       <td id="T_9b4e0_row6_col2" class="data row6 col2" >0.7704</td>
#       <td id="T_9b4e0_row6_col3" class="data row6 col3" >0.7903</td>
#       <td id="T_9b4e0_row6_col4" class="data row6 col4" >0.7803</td>
#       <td id="T_9b4e0_row6_col5" class="data row6 col5" >0.6069</td>
#       <td id="T_9b4e0_row6_col6" class="data row6 col6" >0.6071</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b4e0_row7_col0" class="data row7 col0" >0.8455</td>
#       <td id="T_9b4e0_row7_col1" class="data row7 col1" >0.9092</td>
#       <td id="T_9b4e0_row7_col2" class="data row7 col2" >0.8082</td>
#       <td id="T_9b4e0_row7_col3" class="data row7 col3" >0.8399</td>
#       <td id="T_9b4e0_row7_col4" class="data row7 col4" >0.8237</td>
#       <td id="T_9b4e0_row7_col5" class="data row7 col5" >0.6863</td>
#       <td id="T_9b4e0_row7_col6" class="data row7 col6" >0.6867</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b4e0_row8_col0" class="data row8 col0" >0.8132</td>
#       <td id="T_9b4e0_row8_col1" class="data row8 col1" >0.8961</td>
#       <td id="T_9b4e0_row8_col2" class="data row8 col2" >0.7830</td>
#       <td id="T_9b4e0_row8_col3" class="data row8 col3" >0.7955</td>
#       <td id="T_9b4e0_row8_col4" class="data row8 col4" >0.7892</td>
#       <td id="T_9b4e0_row8_col5" class="data row8 col5" >0.6215</td>
#       <td id="T_9b4e0_row8_col6" class="data row8 col6" >0.6216</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b4e0_row9_col0" class="data row9 col0" >0.8284</td>
#       <td id="T_9b4e0_row9_col1" class="data row9 col1" >0.8991</td>
#       <td id="T_9b4e0_row9_col2" class="data row9 col2" >0.7862</td>
#       <td id="T_9b4e0_row9_col3" class="data row9 col3" >0.8224</td>
#       <td id="T_9b4e0_row9_col4" class="data row9 col4" >0.8039</td>
#       <td id="T_9b4e0_row9_col5" class="data row9 col5" >0.6515</td>
#       <td id="T_9b4e0_row9_col6" class="data row9 col6" >0.6520</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9b4e0_row10_col0" class="data row10 col0" >0.8180</td>
#       <td id="T_9b4e0_row10_col1" class="data row10 col1" >0.8961</td>
#       <td id="T_9b4e0_row10_col2" class="data row10 col2" >0.7731</td>
#       <td id="T_9b4e0_row10_col3" class="data row10 col3" >0.8116</td>
#       <td id="T_9b4e0_row10_col4" class="data row10 col4" >0.7916</td>
#       <td id="T_9b4e0_row10_col5" class="data row10 col5" >0.6302</td>
#       <td id="T_9b4e0_row10_col6" class="data row10 col6" >0.6310</td>
#     </tr>
#     <tr>
#       <th id="T_9b4e0_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_9b4e0_row11_col0" class="data row11 col0" >0.0132</td>
#       <td id="T_9b4e0_row11_col1" class="data row11 col1" >0.0077</td>
#       <td id="T_9b4e0_row11_col2" class="data row11 col2" >0.0235</td>
#       <td id="T_9b4e0_row11_col3" class="data row11 col3" >0.0175</td>
#       <td id="T_9b4e0_row11_col4" class="data row11 col4" >0.0160</td>
#       <td id="T_9b4e0_row11_col5" class="data row11 col5" >0.0270</td>
#       <td id="T_9b4e0_row11_col6" class="data row11 col6" >0.0268</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Let's load in our 2021 season data and get retention scores using the model:

# %%
df_inference = df.loc[df["year"] >= 2021]
df_inference = df_inference.fillna(0)
df_inference.shape
# Out:
# (2397, 23)

# %%
new_predictions = predict_model(final_model, data=df_inference, raw_score=True)
new_predictions.head()
# Out:
#       lkupclientid  dimcustomermasterid  year productgrouping  totalspent  \
# 999             14            296599192  2021     Full Series     10500.0
# 1000            14            296599122  2021     Full Series      2900.0
# 1001            14            296598861  2021     Full Series      7320.0
# 1002            14            296598475  2021     Full Series      1560.0
# 1003            14            296576532  2021     Full Series      2500.0
#
#      recentdate  attendancepercent  renewedbeforedays source_tenure  tenure  \
# 999  1970-01-01               0.70                201          8760    2082
# 1000 2021-08-22               0.50                200          8760    2110
# 1001 1970-01-01               0.50                136          3650    2090
# 1002 1970-01-01               0.80                200          8760    2110
# 1003 1970-01-01               0.67                207          2920    1636
#
#       ...  opentosendratio  clicktosendratio clicktoopenratio   gender  \
# 999   ...             0.00              0.00             0.00  Unknown
# 1000  ...             0.00              0.00             0.00  Unknown
# 1001  ...             0.00              0.00             0.00  Unknown
# 1002  ...             0.00              0.00             0.00  Unknown
# 1003  ...             0.00              0.00             0.00  Unknown
#
#      phonecall  inperson_contact isnextyear_buyer Label Score_0 Score_1
# 999          0                 0                0     0  0.8314  0.1686
# 1000         0                 0                0     0  0.8242  0.1758
# 1001         0                 0                0     0  0.6090  0.3910
# 1002         0                 0                0     1  0.2873  0.7127
# 1003         0                 0                0     0  0.9358  0.0642
#
# [5 rows x 26 columns]

# %%
new_predictions["Label"].value_counts()
# Out:
# 0    2305
# 1      92
# Name: Label, dtype: int64

# %%
new_predictions["Score_1"].value_counts(bins=[0, 0.5, 0.75, 1.0])
# Out:
# (-0.001, 0.5]    2305
# (0.5, 0.75]        87
# (0.75, 1.0]         5
# Name: Score_1, dtype: int64

# %%
plt.hist(new_predictions["Score_1"], bins=20, edgecolor='black')
plt.title("Retention Scores")
plt.ylabel("Num Fans")
plt.xlabel("SA Buyer Score")
plt.show()

# %%
plot_model(best_model, plot='feature')

# %%
plot_model(best_model, plot='confusion_matrix')

# %% [markdown]
# ### Observations:
#
# 1. How much data did we have available to train the model, was it enough data?
# * We have 9,854 data for training (we selected data from 2016 to 2019 to train the model).
#
# 2. How accurate was our retention model when applied to this tennis tournament dataset?
# * The accuracy is 81%, typically our retention model accuracy is over 90%.
#
# 3. How many fans scored over 0.75 for the 2021 season? How does this compare with a retention model for a regular season (ex. Flames)
# * We have 9 of 2397 fans that scored over 0.75 for the 2021 season which is quite low.
# * typically our retention model scores the majority of fans over 0.5.
#
# 4. What were the most important features in making a correct model prediction? Do they make sense for a tennis tournament?
#
# * Renewedbeforedays, totalspent, and source_tenure are still important which makes sense in the context of a tennis tournament.
# * Disttovenue and recency are not significant features in the model which also makes sense in the context of a tennis tournament, fans would likely travel further for a tournament than a regular game, tournaments also happens once per year.

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# Based on our observations above we would not reccomend using this retention model for tournaments because eventhough it is 80% accurate it does not predict high enough number of buyers to be useful for the WSO.
