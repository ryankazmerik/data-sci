# %% [markdown]
# # Portland Trail Blazers - Feature Selection
# * StellarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * October 8, 2021

# %% [markdown]
# ## Hypothesis
# Two very important components of a machine learning model are feature selection and feature engineering. Our idea is that adding some more features to the StellarAlgo retention model could improve performance of the model.

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling

# %%
import getpass
import pyodbc
import pandas as pd
import warnings

from pycaret.classification import *
from ngboost import NGBClassifier

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password ··················

# %%
lkupclientid = 5 # Portland Trail Blazers

cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrTrailBlazers].[ds].[getRetentionScoringModelData] {lkupclientid}"""
)

df = pd.read_sql(storedProc, CNXN)

CNXN.commit()
cursor.close()

# %% [markdown]
# ### Let's drop the features that have lots of null values, as these won't be useful to our model:

# %%
df.drop([
    'urbanicity', 
    'isnextyear_buyer', 
    'isnextyear_samepkg_buyer',
    'pkgupgrade_status',
    'auto_renewal'],
    axis=1, 
    inplace=True
)

# %% [markdown]
# ### In order to compare two sets of features, we need to create some datasets for training and evalution:

# %%
# choose the features that include the extended stellar retention features
features = [
    "dimCustomerMasterId",
    "attendancePercent",
    "distToVenue",
    "education",
    "fill_out_form",
    "forward_records",
    "gender",
    "isNextYear_Buyer",
    "missed_games_1",
    "missed_games_2",
    "missed_games_over_2",
    "posting_records",
    "productGrouping",
    "recency",
    "renewedBeforeDays",
    "resale_atp",
    "resale_records",
    "source_tenure",
    "totalSpent",
    "tenure",
    "year"
]

# select 90% of the data for training
df_train = df.sample(frac=0.9, random_state=786).reset_index(drop=True)

# create the eval datasets for A and B
df_eval = df.drop(df_train.index).reset_index(drop=True)

# choose features for each train dataset
df_train = df_train[features]

# choose features for each train dataset
df_eval = df_eval[features]

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (9896, 21)
# Unseen Data For Predictions: (1100, 21)

# %% [markdown]
# ## Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.80,
    data_split_shuffle=True,
    silent=True,
    ignore_features=["dimCustomerMasterId","productGrouping","year"],
    categorical_features=[
        "education","gender"
    ],
    numeric_features=[
        "attendancePercent",
        "distToVenue",
        "fill_out_form",
        "forward_records",
        "missed_games_1",
        "missed_games_2",
        "missed_games_over_2",
        "posting_records",
        "recency",
        "renewedBeforeDays",
        "resale_atp",
        "resale_records",
        "source_tenure",
        "totalSpent"
    ]
)

# %%
# adding an extra classifier ngboost
ngc = NGBClassifier()
ngboost = create_model(ngc)

model_matrix = compare_models(
    fold=10,
    include=["ada","dt","gbc","et","knn","lightgbm","lr","rf",ngboost,"xgboost"]
)
# Out:
# <style  type="text/css" >
#     #T_b5491_ th {
#           text-align: left;
#     }#T_b5491_row0_col0,#T_b5491_row0_col4,#T_b5491_row1_col0,#T_b5491_row1_col1,#T_b5491_row1_col2,#T_b5491_row1_col3,#T_b5491_row1_col4,#T_b5491_row1_col5,#T_b5491_row1_col6,#T_b5491_row1_col7,#T_b5491_row2_col0,#T_b5491_row2_col1,#T_b5491_row2_col2,#T_b5491_row2_col3,#T_b5491_row2_col4,#T_b5491_row2_col5,#T_b5491_row2_col6,#T_b5491_row2_col7,#T_b5491_row3_col0,#T_b5491_row3_col1,#T_b5491_row3_col2,#T_b5491_row3_col3,#T_b5491_row3_col4,#T_b5491_row3_col5,#T_b5491_row3_col6,#T_b5491_row3_col7,#T_b5491_row4_col0,#T_b5491_row4_col1,#T_b5491_row4_col2,#T_b5491_row4_col3,#T_b5491_row4_col4,#T_b5491_row4_col5,#T_b5491_row4_col6,#T_b5491_row4_col7,#T_b5491_row5_col0,#T_b5491_row5_col1,#T_b5491_row5_col2,#T_b5491_row5_col3,#T_b5491_row5_col5,#T_b5491_row5_col6,#T_b5491_row5_col7,#T_b5491_row6_col0,#T_b5491_row6_col1,#T_b5491_row6_col2,#T_b5491_row6_col3,#T_b5491_row6_col4,#T_b5491_row6_col5,#T_b5491_row6_col6,#T_b5491_row6_col7,#T_b5491_row7_col0,#T_b5491_row7_col1,#T_b5491_row7_col2,#T_b5491_row7_col3,#T_b5491_row7_col4,#T_b5491_row7_col5,#T_b5491_row7_col6,#T_b5491_row7_col7,#T_b5491_row8_col0,#T_b5491_row8_col1,#T_b5491_row8_col2,#T_b5491_row8_col3,#T_b5491_row8_col4,#T_b5491_row8_col5,#T_b5491_row8_col6,#T_b5491_row8_col7,#T_b5491_row9_col0,#T_b5491_row9_col1,#T_b5491_row9_col2,#T_b5491_row9_col3,#T_b5491_row9_col4,#T_b5491_row9_col5,#T_b5491_row9_col6,#T_b5491_row9_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_b5491_row0_col1,#T_b5491_row0_col2,#T_b5491_row0_col3,#T_b5491_row0_col5,#T_b5491_row0_col6,#T_b5491_row0_col7,#T_b5491_row5_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_b5491_row0_col8,#T_b5491_row1_col8,#T_b5491_row2_col8,#T_b5491_row3_col8,#T_b5491_row4_col8,#T_b5491_row5_col8,#T_b5491_row6_col8,#T_b5491_row7_col8,#T_b5491_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_b5491_row8_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_b5491_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5491_level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_b5491_row0_col0" class="data row0 col0" >NGBClassifier</td>
#                         <td id="T_b5491_row0_col1" class="data row0 col1" >0.9162</td>
#                         <td id="T_b5491_row0_col2" class="data row0 col2" >0.9622</td>
#                         <td id="T_b5491_row0_col3" class="data row0 col3" >0.9832</td>
#                         <td id="T_b5491_row0_col4" class="data row0 col4" >0.8067</td>
#                         <td id="T_b5491_row0_col5" class="data row0 col5" >0.8862</td>
#                         <td id="T_b5491_row0_col6" class="data row0 col6" >0.8210</td>
#                         <td id="T_b5491_row0_col7" class="data row0 col7" >0.8311</td>
#                         <td id="T_b5491_row0_col8" class="data row0 col8" >2.8720</td>
#             </tr>
#             <tr>
#                         <th id="T_b5491_level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_b5491_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#                         <td id="T_b5491_row1_col1" class="data row1 col1" >0.9157</td>
#                         <td id="T_b5491_row1_col2" class="data row1 col2" >0.9600</td>
#                         <td id="T_b5491_row1_col3" class="data row1 col3" >0.9611</td>
#                         <td id="T_b5491_row1_col4" class="data row1 col4" >0.8171</td>
#                         <td id="T_b5491_row1_col5" class="data row1 col5" >0.8832</td>
#                         <td id="T_b5491_row1_col6" class="data row1 col6" >0.8180</td>
#                         <td id="T_b5491_row1_col7" class="data row1 col7" >0.8247</td>
#                         <td id="T_b5491_row1_col8" class="data row1 col8" >0.2520</td>
#             </tr>
#             <tr>
#                         <th id="T_b5491_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b5491_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_b5491_row2_col1" class="data row2 col1" >0.9157</td>
#                         <td id="T_b5491_row2_col2" class="data row2 col2" >0.9617</td>
#                         <td id="T_b5491_row2_col3" class="data row2 col3" >0.9604</td>
#                         <td id="T_b5491_row2_col4" class="data row2 col4" >0.8176</td>
#                         <td id="T_b5491_row2_col5" class="data row2 col5" >0.8831</td>
#                         <td id="T_b5491_row2_col6" class="data row2 col6" >0.8179</td>
#                         <td id="T_b5491_row2_col7" class="data row2 col7" >0.8245</td>
#                         <td id="T_b5491_row2_col8" class="data row2 col8" >0.1170</td>
#             </tr>
#             <tr>
#                         <th id="T_b5491_level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_b5491_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_b5491_row3_col1" class="data row3 col1" >0.9155</td>
#                         <td id="T_b5491_row3_col2" class="data row3 col2" >0.9605</td>
#                         <td id="T_b5491_row3_col3" class="data row3 col3" >0.9371</td>
#                         <td id="T_b5491_row3_col4" class="data row3 col4" >0.8302</td>
#                         <td id="T_b5491_row3_col5" class="data row3 col5" >0.8803</td>
#                         <td id="T_b5491_row3_col6" class="data row3 col6" >0.8153</td>
#                         <td id="T_b5491_row3_col7" class="data row3 col7" >0.8191</td>
#                         <td id="T_b5491_row3_col8" class="data row3 col8" >0.0470</td>
#             </tr>
#             <tr>
#                         <th id="T_b5491_level0_row4" class="row_heading level0 row4" >9</th>
#                         <td id="T_b5491_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_b5491_row4_col1" class="data row4 col1" >0.9119</td>
#                         <td id="T_b5491_row4_col2" class="data row4 col2" >0.9589</td>
#                         <td id="T_b5491_row4_col3" class="data row4 col3" >0.9287</td>
#                         <td id="T_b5491_row4_col4" class="data row4 col4" >0.8271</td>
#                         <td id="T_b5491_row4_col5" class="data row4 col5" >0.8748</td>
#                         <td id="T_b5491_row4_col6" class="data row4 col6" >0.8073</td>
#                         <td id="T_b5491_row4_col7" class="data row4 col7" >0.8107</td>
#                         <td id="T_b5491_row4_col8" class="data row4 col8" >0.6440</td>
#             </tr>
#             <tr>
#                         <th id="T_b5491_level0_row5" class="row_heading level0 row5" >7</th>
#                         <td id="T_b5491_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#                         <td id="T_b5491_row5_col1" class="data row5 col1" >0.9055</td>
#                         <td id="T_b5491_row5_col2" class="data row5 col2" >0.9569</td>
#                         <td id="T_b5491_row5_col3" class="data row5 col3" >0.8982</td>
#                         <td id="T_b5

# %% [markdown]
# ### The top model is performing well, so hypertune the parameters and then compare it against our unseen eval dataset:

# %%
best_model = create_model(model_matrix)

unseen_predictions = predict_model(best_model, data=df_eval)
# Out:
# <style  type="text/css" >
# #T_203af_row10_col0,#T_203af_row10_col1,#T_203af_row10_col2,#T_203af_row10_col3,#T_203af_row10_col4,#T_203af_row10_col5,#T_203af_row10_col6{
#             background:  yellow;
#         }</style><table id="T_203af_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_203af_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_203af_row0_col0" class="data row0 col0" >0.9116</td>
#                         <td id="T_203af_row0_col1" class="data row0 col1" >0.9589</td>
#                         <td id="T_203af_row0_col2" class="data row0 col2" >0.9924</td>
#                         <td id="T_203af_row0_col3" class="data row0 col3" >0.7933</td>
#                         <td id="T_203af_row0_col4" class="data row0 col4" >0.8818</td>
#                         <td id="T_203af_row0_col5" class="data row0 col5" >0.8126</td>
#                         <td id="T_203af_row0_col6" class="data row0 col6" >0.8256</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_203af_row1_col0" class="data row1 col0" >0.9192</td>
#                         <td id="T_203af_row1_col1" class="data row1 col1" >0.9609</td>
#                         <td id="T_203af_row1_col2" class="data row1 col2" >0.9886</td>
#                         <td id="T_203af_row1_col3" class="data row1 col3" >0.8100</td>
#                         <td id="T_203af_row1_col4" class="data row1 col4" >0.8904</td>
#                         <td id="T_203af_row1_col5" class="data row1 col5" >0.8274</td>
#                         <td id="T_203af_row1_col6" class="data row1 col6" >0.8377</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_203af_row2_col0" class="data row2 col0" >0.9255</td>
#                         <td id="T_203af_row2_col1" class="data row2 col1" >0.9719</td>
#                         <td id="T_203af_row2_col2" class="data row2 col2" >0.9810</td>
#                         <td id="T_203af_row2_col3" class="data row2 col3" >0.8269</td>
#                         <td id="T_203af_row2_col4" class="data row2 col4" >0.8974</td>
#                         <td id="T_203af_row2_col5" class="data row2 col5" >0.8396</td>
#                         <td id="T_203af_row2_col6" class="data row2 col6" >0.8471</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_203af_row3_col0" class="data row3 col0" >0.9104</td>
#                         <td id="T_203af_row3_col1" class="data row3 col1" >0.9646</td>
#                         <td id="T_203af_row3_col2" class="data row3 col2" >0.9658</td>
#                         <td id="T_203af_row3_col3" class="data row3 col3" >0.8038</td>
#                         <td id="T_203af_row3_col4" class="data row3 col4" >0.8774</td>
#                         <td id="T_203af_row3_col5" class="data row3 col5" >0.8077</td>
#                         <td id="T_203af_row3_col6" class="data row3 col6" >0.8161</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_203af_row4_col0" class="data row4 col0" >0.9167</td>
#                         <td id="T_203af_row4_col1" class="data row4 col1" >0.9593</td>
#                         <td id="T_203af_row4_col2" class="data row4 col2" >0.9771</td>
#                         <td id="T_203af_row4_col3" class="data row4 col3" >0.8101</td>
#                         <td id="T_203af_row4_col4" class="data row4 col4" >0.8858</td>
#                         <td id="T_203af_row4_col5" class="data row4 col5" >0.8211</td>
#                         <td id="T_203af_row4_col6" class="data row4 col6" >0.8300</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_203af_row5_col0" class="data row5 col0" >0.9192</td>
#                         <td id="T_203af_row5_col1" class="data row5 col1" >0.9685</td>
#                         <td id="T_203af_row5_col2" class="data row5 col2" >0.9809</td>
#                         <td id="T_203af_row5_col3" class="data row5 col3" >0.8133</td>
#                         <td id="T_203af_row5_col4" class="data row5 col4" >0.8893</td>
#                         <td id="T_203af_row5_col5" class="data row5 col5" >0.8265</td>
#                         <td id="T_203af_row5_col6" class="data row5 col6" >0.8355</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_203af_row6_col0" class="data row6 col0" >0.9090</td>
#                         <td id="T_203af_row6_col1" class="data row6 col1" >0.9590</td>
#                         <td id="T_203af_row6_col2" class="data row6 col2" >0.9847</td>
#                         <td id="T_203af_row6_col3" class="data row6 col3" >0.7914</td>
#                         <td id="T_203af_row6_col4" class="data row6 col4" >0.8776</td>
#                         <td id="T_203af_row6_col5" class="data row6 col5" >0.8065</td>
#                         <td id="T_203af_row6_col6" class="data row6 col6" >0.8187</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_203af_row7_col0" class="data row7 col0" >0.9064</td>
#                         <td id="T_203af_row7_col1" class="data row7 col1" >0.9541</td>
#                         <td id="T_203af_row7_col2" class="data row7 col2" >0.9809</td>
#                         <td id="T_203af_row7_col3" class="data row7 col3" >0.7883</td>
#                         <td id="T_203af_row7_col4" class="data row7 col4" >0.8741</td>
#                         <td id="T_203af_row7_col5" class="data row7 col5" >0.8011</td>
#                         <td id="T_203af_row7_col6" class="data row7 col6" >0.8132</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_203af_row8_col0" class="data row8 col0" >0.9204</td>
#                         <td id="T_203af_row8_col1" class="data row8 col1" >0.9668</td>
#                         <td id="T_203af_row8_col2" class="data row8 col2" >0.9924</td>
#                         <td id="T_203af_row8_col3" class="data row8 col3" >0.8100</td>
#                         <td id="T_203af_row8_col4" class="data row8 col4" >0.8919</td>
#                         <td id="T_203af_row8_col5" class="data row8 col5" >0.8299</td>
#                         <td id="T_203af_row8_col6" class="data row8 col6" >0.8406</td>
#             </tr>
#             <tr>
#                         <th id="T_203af_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_203af_row9_col0" class="data row9 col0" >0.9241</td>
#                         <td id="T_203af_row9_col1" class="data row9 col1" >0.9582</td>
#                         <td id="T_203af_row9_col2" class="data row9 col2" >0.9885</td>
#                         <td id="T_203af_row9_col3" class="data row9 col3" >0.8196</td>
#                         <td id="T_203af_row9_col4" class="data row9 col4" >0.8962</td>
#                         <td id="T_203af_row9_col5" class="data row9 col5" >0.8373</td>
#                         <td id=

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
# Here you can document some ideas on the results from above

# %% [markdown]
# ## Conclusions
# Here you can talk about next steps, did the experiment work? If yes, what to do next? If no, why?
