# %% [markdown]
# # Inter-Maimi - PROD Retention Score _ all teams
# * StelllarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * June 20, 2022

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

from pycaret.classification import *

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
# connect to SQL Server.
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password ··················

# %%
cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrMLS].[ds].[getRetentionScoringModelData_all_teams] """
)

df = pd.read_sql(storedProc, CNXN)

# apply some data transformations
df["year"] = pd.to_numeric(df["year"])

CNXN.commit()
cursor.close()

df.shape
# Out:
# (59948, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59948 entries, 0 to 59947
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   dimCustomerMasterId     59948 non-null  int64
#  1   year                    59948 non-null  int64
#  2   productGrouping         59948 non-null  object
#  3   totalSpent              59948 non-null  float64
#  4   recentDate              59948 non-null  object
#  5   attendancePercent       59948 non-null  float64
#  6   renewedBeforeDays       59927 non-null  float64
#  7   isBuyer                 59948 non-null  object
#  8   source_tenure           59927 non-null  float64
#  9   tenure                  59927 non-null  float64
#  10  distToVenue             59948 non-null  float64
#  11  totalGames              59948 non-null  int64
#  12  recency                 59948 non-null  int64
#  13  missed_games_1          59948 non-null  int64
#  14  missed_games_2          59948 non-null  int64
#  15  missed_games_over_2     59948 non-null  int64
#  16  click_link              59948 non-null  int64
#  17  fill_out_form           59948 non-null  int64
#  18  open_email              59948 non-null  int64
#  19  send_email              59948 non-null  int64
#  20  unsubscribe_email       59948 non-null  int64
#  21  openToSendRatio         59948 non-null  float64
#  22  clickToSendRatio        59948 non-null  float64
#  23  clickToOpenRatio        59948 non-null  float64
#  24  posting_records         59948 non-null  int64
#  25  resale_records          59948 non-null  int64
#  26  resale_atp              59948 non-null  float64
#  27  forward_records         59948 non-null  int64
#  28  cancel_records          59948 non-null  int64
#  29  email                   59948 non-null  int64
#  30  inbound_email           59948 non-null  int64
#  31  inbound_phonecall       59948 non-null  int64
#  32  inperson_contact        59948 non-null  int64
#  33  internal_note           59948 non-null  int64
#  34  left_message            59948 non-null  int64
#  35  outbound_email          59948 non-null  int64
#  36  outbound_phonecall      59948 non-null  int64
#  37  phonecall               59948 non-null  int64
#  38  text                    59948 non-null  int64
#  39  unknown                 59948 non-null  int64
#  40  gender                  59948 non-null  object
#  41  childrenPresentInHH     59948 non-null  int64
#  42  maritalStatus           59948 non-null  int64
#  43  lengthOfResidenceInYrs  0 non-null      object
#  44  annualHHIncome          59948 non-null  object
#  45  education               59948 non-null  object
#  46  urbanicity              0 non-null      object
#  47  credits_after_refund    59948 non-null  float64
#  48  is_Lockdown             59948 non-null  int64
#  49  NumberofGamesPerSeason  59948 non-null  int64
#  50  CNTPostponedGames       0 non-null      object
#  51  isNextYear_Buyer        59948 non-null  int64
# dtypes: float64(11), int64(32), object(9)
# memory usage: 23.8+ MB

# %% [markdown]
# ### We should specify the features used in our model:

# %%
# choose the features for the stellar base retention model
features = [
            "dimCustomerMasterId",
            "year",
            "productGrouping", 
            "totalSpent", 
            "recentDate",
            "attendancePercent", 
            "renewedBeforeDays",
            "source_tenure",
            "tenure",
            "distToVenue",
            "recency",
            "missed_games_1",
            "missed_games_2",
            "missed_games_over_2",
            "isNextYear_Buyer"
]

# copy your main dataframe
df_dataset = df

# choose the features & train year & test year
df_dataset = df_dataset[features]
df_dataset["year"] = pd.to_numeric(df_dataset["year"])
df_dataset = df_dataset.loc[df_dataset["year"] <= 2021]

df_train = df_dataset.sample(frac=0.85, random_state=786)
df_eval = df_dataset.drop(df_train.index)

df_train.reset_index(drop=True, inplace=True)
df_eval.reset_index(drop=True, inplace=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (43284, 15)
# Unseen Data For Predictions: (7638, 15)

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.85,
    data_split_shuffle=True,
    ignore_features=["dimCustomerMasterId","productGrouping","year"],
    silent=True,
    verbose=False,
    numeric_features=[
    "totalSpent", 
            "attendancePercent", 
            "renewedBeforeDays",
            "source_tenure",
            "tenure",
            "distToVenue",
            "recency",
            "missed_games_1",
            "missed_games_2",
            "missed_games_over_2"
    ]
);

# %%
model_matrix = compare_models(
    fold=10,
    include=["lightgbm","lr","xgboost"]
)
# Out:
# <style type="text/css">
# #T_ab2db th {
#   text-align: left;
# }
# #T_ab2db_row0_col0, #T_ab2db_row0_col4, #T_ab2db_row1_col0, #T_ab2db_row1_col1, #T_ab2db_row1_col2, #T_ab2db_row1_col3, #T_ab2db_row1_col5, #T_ab2db_row1_col6, #T_ab2db_row1_col7, #T_ab2db_row2_col0, #T_ab2db_row2_col1, #T_ab2db_row2_col2, #T_ab2db_row2_col3, #T_ab2db_row2_col4, #T_ab2db_row2_col5, #T_ab2db_row2_col6, #T_ab2db_row2_col7 {
#   text-align: left;
# }
# #T_ab2db_row0_col1, #T_ab2db_row0_col2, #T_ab2db_row0_col3, #T_ab2db_row0_col5, #T_ab2db_row0_col6, #T_ab2db_row0_col7, #T_ab2db_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ab2db_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ab2db_row1_col8, #T_ab2db_row2_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ab2db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab2db_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab2db_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ab2db_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ab2db_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ab2db_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ab2db_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ab2db_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ab2db_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ab2db_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab2db_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ab2db_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ab2db_row0_col1" class="data row0 col1" >0.7826</td>
#       <td id="T_ab2db_row0_col2" class="data row0 col2" >0.8298</td>
#       <td id="T_ab2db_row0_col3" class="data row0 col3" >0.8995</td>
#       <td id="T_ab2db_row0_col4" class="data row0 col4" >0.7893</td>
#       <td id="T_ab2db_row0_col5" class="data row0 col5" >0.8408</td>
#       <td id="T_ab2db_row0_col6" class="data row0 col6" >0.5025</td>
#       <td id="T_ab2db_row0_col7" class="data row0 col7" >0.5133</td>
#       <td id="T_ab2db_row0_col8" class="data row0 col8" >0.4200</td>
#     </tr>
#     <tr>
#       <th id="T_ab2db_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_ab2db_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ab2db_row1_col1" class="data row1 col1" >0.7801</td>
#       <td id="T_ab2db_row1_col2" class="data row1 col2" >0.8262</td>
#       <td id="T_ab2db_row1_col3" class="data row1 col3" >0.8893</td>
#       <td id="T_ab2db_row1_col4" class="data row1 col4" >0.7918</td>
#       <td id="T_ab2db_row1_col5" class="data row1 col5" >0.8377</td>
#       <td id="T_ab2db_row1_col6" class="data row1 col6" >0.5001</td>
#       <td id="T_ab2db_row1_col7" class="data row1 col7" >0.5083</td>
#       <td id="T_ab2db_row1_col8" class="data row1 col8" >1.7060</td>
#     </tr>
#     <tr>
#       <th id="T_ab2db_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ab2db_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ab2db_row2_col1" class="data row2 col1" >0.7359</td>
#       <td id="T_ab2db_row2_col2" class="data row2 col2" >0.7589</td>
#       <td id="T_ab2db_row2_col3" class="data row2 col3" >0.8897</td>
#       <td id="T_ab2db_row2_col4" class="data row2 col4" >0.7457</td>
#       <td id="T_ab2db_row2_col5" class="data row2 col5" >0.8114</td>
#       <td id="T_ab2db_row2_col6" class="data row2 col6" >0.3826</td>
#       <td id="T_ab2db_row2_col7" class="data row2 col7" >0.3996</td>
#       <td id="T_ab2db_row2_col8" class="data row2 col8" >0.9410</td>
#     </tr>
#   </tbody>
# </table>

# %%
lightgbm_model = create_model('lightgbm')
lr_model = create_model('lr')
xgboost_model = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_786fa_row10_col0, #T_786fa_row10_col1, #T_786fa_row10_col2, #T_786fa_row10_col3, #T_786fa_row10_col4, #T_786fa_row10_col5, #T_786fa_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_786fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_786fa_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_786fa_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_786fa_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_786fa_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_786fa_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_786fa_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_786fa_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_786fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_786fa_row0_col0" class="data row0 col0" >0.7845</td>
#       <td id="T_786fa_row0_col1" class="data row0 col1" >0.8345</td>
#       <td id="T_786fa_row0_col2" class="data row0 col2" >0.8885</td>
#       <td id="T_786fa_row0_col3" class="data row0 col3" >0.7972</td>
#       <td id="T_786fa_row0_col4" class="data row0 col4" >0.8403</td>
#       <td id="T_786fa_row0_col5" class="data row0 col5" >0.5119</td>
#       <td id="T_786fa_row0_col6" class="data row0 col6" >0.5191</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_786fa_row1_col0" class="data row1 col0" >0.7725</td>
#       <td id="T_786fa_row1_col1" class="data row1 col1" >0.8183</td>
#       <td id="T_786fa_row1_col2" class="data row1 col2" >0.8888</td>
#       <td id="T_786fa_row1_col3" class="data row1 col3" >0.7837</td>
#       <td id="T_786fa_row1_col4" class="data row1 col4" >0.8330</td>
#       <td id="T_786fa_row1_col5" class="data row1 col5" >0.4807</td>
#       <td id="T_786fa_row1_col6" class="data row1 col6" >0.4902</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_786fa_row2_col0" class="data row2 col0" >0.7885</td>
#       <td id="T_786fa_row2_col1" class="data row2 col1" >0.8314</td>
#       <td id="T_786fa_row2_col2" class="data row2 col2" >0.8931</td>
#       <td id="T_786fa_row2_col3" class="data row2 col3" >0.7992</td>
#       <td id="T_786fa_row2_col4" class="data row2 col4" >0.8435</td>
#       <td id="T_786fa_row2_col5" class="data row2 col5" >0.5205</td>
#       <td id="T_786fa_row2_col6" class="data row2 col6" >0.5282</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_786fa_row3_col0" class="data row3 col0" >0.7850</td>
#       <td id="T_786fa_row3_col1" class="data row3 col1" >0.8353</td>
#       <td id="T_786fa_row3_col2" class="data row3 col2" >0.8893</td>
#       <td id="T_786fa_row3_col3" class="data row3 col3" >0.7973</td>
#       <td id="T_786fa_row3_col4" class="data row3 col4" >0.8407</td>
#       <td id="T_786fa_row3_col5" class="data row3 col5" >0.5129</td>
#       <td id="T_786fa_row3_col6" class="data row3 col6" >0.5202</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_786fa_row4_col0" class="data row4 col0" >0.7711</td>
#       <td id="T_786fa_row4_col1" class="data row4 col1" >0.8185</td>
#       <td id="T_786fa_row4_col2" class="data row4 col2" >0.8829</td>
#       <td id="T_786fa_row4_col3" class="data row4 col3" >0.7852</td>
#       <td id="T_786fa_row4_col4" class="data row4 col4" >0.8312</td>
#       <td id="T_786fa_row4_col5" class="data row4 col5" >0.4797</td>
#       <td id="T_786fa_row4_col6" class="data row4 col6" >0.4877</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_786fa_row5_col0" class="data row5 col0" >0.7815</td>
#       <td id="T_786fa_row5_col1" class="data row5 col1" >0.8290</td>
#       <td id="T_786fa_row5_col2" class="data row5 col2" >0.8880</td>
#       <td id="T_786fa_row5_col3" class="data row5 col3" >0.7940</td>
#       <td id="T_786fa_row5_col4" class="data row5 col4" >0.8384</td>
#       <td id="T_786fa_row5_col5" class="data row5 col5" >0.5043</td>
#       <td id="T_786fa_row5_col6" class="data row5 col6" >0.5119</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_786fa_row6_col0" class="data row6 col0" >0.7812</td>
#       <td id="T_786fa_row6_col1" class="data row6 col1" >0.8176</td>
#       <td id="T_786fa_row6_col2" class="data row6 col2" >0.8905</td>
#       <td id="T_786fa_row6_col3" class="data row6 col3" >0.7923</td>
#       <td id="T_786fa_row6_col4" class="data row6 col4" >0.8386</td>
#       <td id="T_786fa_row6_col5" class="data row6 col5" >0.5026</td>
#       <td id="T_786fa_row6_col6" class="data row6 col6" >0.5109</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_786fa_row7_col0" class="data row7 col0" >0.7782</td>
#       <td id="T_786fa_row7_col1" class="data row7 col1" >0.8288</td>
#       <td id="T_786fa_row7_col2" class="data row7 col2" >0.8905</td>
#       <td id="T_786fa_row7_col3" class="data row7 col3" >0.7891</td>
#       <td id="T_786fa_row7_col4" class="data row7 col4" >0.8367</td>
#       <td id="T_786fa_row7_col5" class="data row7 col5" >0.4949</td>
#       <td id="T_786fa_row7_col6" class="data row7 col6" >0.5038</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_786fa_row8_col0" class="data row8 col0" >0.7755</td>
#       <td id="T_786fa_row8_col1" class="data row8 col1" >0.8204</td>
#       <td id="T_786fa_row8_col2" class="data row8 col2" >0.8863</td>
#       <td id="T_786fa_row8_col3" class="data row8 col3" >0.7883</td>
#       <td id="T_786fa_row8_col4" class="data row8 col4" >0.8345</td>
#       <td id="T_786fa_row8_col5" class="data row8 col5" >0.4893</td>
#       <td id="T_786fa_row8_col6" class="data row8 col6" >0.4975</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_786fa_row9_col0" class="data row9 col0" >0.7825</td>
#       <td id="T_786fa_row9_col1" class="data row9 col1" >0.8284</td>
#       <td id="T_786fa_row9_col2" class="data row9 col2" >0.8948</td>
#       <td id="T_786fa_row9_col3" class="data row9 col3" >0.7917</td>
#       <td id="T_786fa_row9_col4" class="data row9 col4" >0.8401</td>
#       <td id="T_786fa_row9_col5" class="data row9 col5" >0.5042</td>
#       <td id="T_786fa_row9_col6" class="data row9 col6" >0.5135</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_786fa_row10_col0" class="data row10 col0" >0.7801</td>
#       <td id="T_786fa_row10_col1" class="data row10 col1" >0.8262</td>
#       <td id="T_786fa_row10_col2" class="data row10 col2" >0.8893</td>
#       <td id="T_786fa_row10_col3" class="data row10 col3" >0.7918</td>
#       <td id="T_786fa_row10_col4" class="data row10 col4" >0.8377</td>
#       <td id="T_786fa_row10_col5" class="data row10 col5" >0.5001</td>
#       <td id="T_786fa_row10_col6" class="data row10 col6" >0.5083</td>
#     </tr>
#     <tr>
#       <th id="T_786fa_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_786fa_row11_col0" class="data row11 col0" >0.0054</td>
#       <td id="T_786fa_row11_col1" class="data row11 col1" >0.0065</td>
#       <td id="T_786fa_row11_col2" class="data row11 col2" >0.0032</td>
#       <td id="T_786fa_row11_col3" class="data row11 col3" >0.0050</td>
#       <td id="T_786fa_row11_col4" class="data row11 col4" >0.0037</td>
#       <td id="T_786fa_row11_col5" class="data row11 col5" >0.0130</td>
#       <td id="T_786fa_row11_col6" class="data row11 col6" >0.0126</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Let's load in our 2021 season data and get retention scores using the model:

# %%
cursor = CNXN.cursor()

storedProc_scoring = (
    f"""Exec [stlrMLS].[ds].[getRetentionScoringModelData_staging2] """
)

df_scoring = pd.read_sql(storedProc_scoring, CNXN)

# apply some data transformations
df_scoring["year"] = pd.to_numeric(df_scoring["year"])

CNXN.commit()
cursor.close()

df_scoring.shape
# Out:
# (6909, 15)

# %%
df_inference = df_scoring.loc[df_scoring["year"] >= 2022]
df_inference = df_inference.fillna(0)
df_inference.shape
# Out:
# (2679, 15)

# %%
lightgbm_predictions = predict_model(lightgbm_model, data=df_inference, raw_score=True)
lr_predictions = predict_model(lr_model, data=df_inference, raw_score=True)
xgboost_predictions = predict_model(xgboost_model, data=df_inference, raw_score=True)

# %%
print(f"lightgbm:\n {lightgbm_predictions.Label.value_counts()}")
print(f"log reg:\n {lr_predictions.Label.value_counts()}")
print(f"xgboost:\n {xgboost_predictions.Label.value_counts()}")
# Out:
# lightgbm:
#  0    2489
# 1     190
# Name: Label, dtype: int64
# log reg:
#  0    2251
# 1     428
# Name: Label, dtype: int64
# xgboost:
#  0    2391
# 1     288
# Name: Label, dtype: int64

# %%
print(f"lightgbm:\n {lightgbm_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")
print(f"lr:\n {lr_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")
print(f"xgboost:\n {xgboost_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")
# Out:
# lightgbm:
#  (-0.001, 0.25]    1963
# (0.25, 0.5]        526
# (0.5, 0.75]        188
# (0.75, 1.0]          2
# Name: Score_1, dtype: int64
# lr:
#  (-0.001, 0.25]    1655
# (0.25, 0.5]        596
# (0.5, 0.75]        412
# (0.75, 1.0]         16
# Name: Score_1, dtype: int64
# xgboost:
#  (-0.001, 0.25]    1532
# (0.25, 0.5]        859
# (0.5, 0.75]        251
# (0.75, 1.0]         37
# Name: Score_1, dtype: int64

# %%
model_predictions = [lightgbm_predictions, lr_predictions, xgboost_predictions]

for idx, df_predictions in enumerate(model_predictions):

    plt.subplot(1, 3, idx+1)

    plt.hist(df_predictions["Score_1"], bins=20, edgecolor='black')
    plt.title("Retention Scores")
    plt.ylabel("Num Fans")
    plt.xlabel("SA Buyer Score")

plt.rcParams["figure.figsize"] = (20,4)
plt.show()

# %%
plot_model(lightgbm_model, plot='feature')

# %%
plot_model(lr_model, plot='feature')

# %%
plot_model(xgboost_model, plot='feature')

# %%
plot_model(lightgbm_model, plot='confusion_matrix')

# %%
plot_model(lr_model, plot='confusion_matrix')

# %%
plot_model(xgboost_model, plot='confusion_matrix')

# %% [markdown]
# ## Observations
# Here you can document some ideas on the results from above
