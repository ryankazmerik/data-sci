# %% [markdown]
# # Inter-Maimi - PROD Retention Score _ all teams
# * StelllarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * June 20, 2022

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# ## Experiment
# This section details our experiment including querying data, data transformations, feature selection and modelling.

# %%
import getpass
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

from pycaret.classification import *

# %% [markdown]
# ### Let's connect to MSSQL and run a stored proc to get our dataset:

# %%
# connect to SQL Server.
SERVER = '34.206.73.189' 
DATABASE = 'datascience' 
USERNAME = 'dsAdminWrite' 
PASSWORD = getpass.getpass(prompt='Enter your password')
CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
# Out:
# Enter your password ··················

# %%
cursor = CNXN.cursor()

storedProc = (
    f"""Exec [stlrMLS].[ds].[getRetentionScoringModelData_all_teams] """
)

df = pd.read_sql(storedProc, CNXN)

# apply some data transformations
df["year"] = pd.to_numeric(df["year"])

CNXN.commit()
cursor.close()

df.shape
# Out:
# (59948, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59948 entries, 0 to 59947
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   dimCustomerMasterId     59948 non-null  int64
#  1   year                    59948 non-null  int64
#  2   productGrouping         59948 non-null  object
#  3   totalSpent              59948 non-null  float64
#  4   recentDate              59948 non-null  object
#  5   attendancePercent       59948 non-null  float64
#  6   renewedBeforeDays       59927 non-null  float64
#  7   isBuyer                 59948 non-null  object
#  8   source_tenure           59927 non-null  float64
#  9   tenure                  59927 non-null  float64
#  10  distToVenue             59948 non-null  float64
#  11  totalGames              59948 non-null  int64
#  12  recency                 59948 non-null  int64
#  13  missed_games_1          59948 non-null  int64
#  14  missed_games_2          59948 non-null  int64
#  15  missed_games_over_2     59948 non-null  int64
#  16  click_link              59948 non-null  int64
#  17  fill_out_form           59948 non-null  int64
#  18  open_email              59948 non-null  int64
#  19  send_email              59948 non-null  int64
#  20  unsubscribe_email       59948 non-null  int64
#  21  openToSendRatio         59948 non-null  float64
#  22  clickToSendRatio        59948 non-null  float64
#  23  clickToOpenRatio        59948 non-null  float64
#  24  posting_records         59948 non-null  int64
#  25  resale_records          59948 non-null  int64
#  26  resale_atp              59948 non-null  float64
#  27  forward_records         59948 non-null  int64
#  28  cancel_records          59948 non-null  int64
#  29  email                   59948 non-null  int64
#  30  inbound_email           59948 non-null  int64
#  31  inbound_phonecall       59948 non-null  int64
#  32  inperson_contact        59948 non-null  int64
#  33  internal_note           59948 non-null  int64
#  34  left_message            59948 non-null  int64
#  35  outbound_email          59948 non-null  int64
#  36  outbound_phonecall      59948 non-null  int64
#  37  phonecall               59948 non-null  int64
#  38  text                    59948 non-null  int64
#  39  unknown                 59948 non-null  int64
#  40  gender                  59948 non-null  object
#  41  childrenPresentInHH     59948 non-null  int64
#  42  maritalStatus           59948 non-null  int64
#  43  lengthOfResidenceInYrs  0 non-null      object
#  44  annualHHIncome          59948 non-null  object
#  45  education               59948 non-null  object
#  46  urbanicity              0 non-null      object
#  47  credits_after_refund    59948 non-null  float64
#  48  is_Lockdown             59948 non-null  int64
#  49  NumberofGamesPerSeason  59948 non-null  int64
#  50  CNTPostponedGames       0 non-null      object
#  51  isNextYear_Buyer        59948 non-null  int64
# dtypes: float64(11), int64(32), object(9)
# memory usage: 23.8+ MB

# %% [markdown]
# ### We should specify the features used in our model:

# %%
# choose the features for the stellar base retention model
features = [
            "dimCustomerMasterId",
            "year",
            "productGrouping", 
            "totalSpent", 
            "recentDate",
            "attendancePercent", 
            "renewedBeforeDays",
            "source_tenure",
            "tenure",
            "distToVenue",
            "recency",
            "missed_games_1",
            "missed_games_2",
            "missed_games_over_2",
            "isNextYear_Buyer"
]

# copy your main dataframe
df_dataset = df

# choose the features & train year & test year
df_dataset = df_dataset[features]
df_dataset["year"] = pd.to_numeric(df_dataset["year"])
df_dataset = df_dataset.loc[df_dataset["year"] <= 2021]

df_train = df_dataset.sample(frac=0.85, random_state=786)
df_eval = df_dataset.drop(df_train.index)

df_train.reset_index(drop=True, inplace=True)
df_eval.reset_index(drop=True, inplace=True)

# print out the number of records for training and eval
print('Data for Modeling: ' + str(df_train.shape))
print('Unseen Data For Predictions: ' + str(df_eval.shape), end="\n\n")
# Out:
# Data for Modeling: (43284, 15)
# Unseen Data For Predictions: (7638, 15)

# %% [markdown]
# ### Now we can model the data using a binary classification prediction for the isnextyear_buyer field to see how likely a customer is to re-purchase.

# %%
setup(
    data= df_train, 
    target="isNextYear_Buyer", 
    train_size = 0.85,
    data_split_shuffle=True,
    ignore_features=["dimCustomerMasterId","productGrouping","year"],
    silent=True,
    verbose=False,
    numeric_features=[
    "totalSpent", 
            "attendancePercent", 
            "renewedBeforeDays",
            "source_tenure",
            "tenure",
            "distToVenue",
            "recency",
            "missed_games_1",
            "missed_games_2",
            "missed_games_over_2"
    ]
);

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
model_matrix = compare_models(
    fold=10,
    include=["lightgbm","lr","xgboost"]
)
# Out:
# <style type="text/css">
# #T_ab2db th {
#   text-align: left;
# }
# #T_ab2db_row0_col0, #T_ab2db_row0_col4, #T_ab2db_row1_col0, #T_ab2db_row1_col1, #T_ab2db_row1_col2, #T_ab2db_row1_col3, #T_ab2db_row1_col5, #T_ab2db_row1_col6, #T_ab2db_row1_col7, #T_ab2db_row2_col0, #T_ab2db_row2_col1, #T_ab2db_row2_col2, #T_ab2db_row2_col3, #T_ab2db_row2_col4, #T_ab2db_row2_col5, #T_ab2db_row2_col6, #T_ab2db_row2_col7 {
#   text-align: left;
# }
# #T_ab2db_row0_col1, #T_ab2db_row0_col2, #T_ab2db_row0_col3, #T_ab2db_row0_col5, #T_ab2db_row0_col6, #T_ab2db_row0_col7, #T_ab2db_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ab2db_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ab2db_row1_col8, #T_ab2db_row2_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ab2db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab2db_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab2db_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ab2db_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ab2db_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ab2db_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ab2db_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ab2db_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ab2db_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ab2db_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab2db_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ab2db_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ab2db_row0_col1" class="data row0 col1" >0.7826</td>
#       <td id="T_ab2db_row0_col2" class="data row0 col2" >0.8298</td>
#       <td id="T_ab2db_row0_col3" class="data row0 col3" >0.8995</td>
#       <td id="T_ab2db_row0_col4" class="data row0 col4" >0.7893</td>
#       <td id="T_ab2db_row0_col5" class="data row0 col5" >0.8408</td>
#       <td id="T_ab2db_row0_col6" class="data row0 col6" >0.5025</td>
#       <td id="T_ab2db_row0_col7" class="data row0 col7" >0.5133</td>
#       <td id="T_ab2db_row0_col8" class="data row0 col8" >0.4200</td>
#     </tr>
#     <tr>
#       <th id="T_ab2db_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_ab2db_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ab2db_row1_col1" class="data row1 col1" >0.7801</td>
#       <td id="T_ab2db_row1_col2" class="data row1 col2" >0.8262</td>
#       <td id="T_ab2db_row1_col3" class="data row1 col3" >0.8893</td>
#       <td id="T_ab2db_row1_col4" class="data row1 col4" >0.7918</td>
#       <td id="T_ab2db_row1_col5" class="data row1 col5" >0.8377</td>
#       <td id="T_ab2db_row1_col6" class="data row1 col6" >0.5001</td>
#       <td id="T_ab2db_row1_col7" class="data row1 col7" >0.5083</td>
#       <td id="T_ab2db_row1_col8" class="data row1 col8" >1.7060</td>
#     </tr>
#     <tr>
#       <th id="T_ab2db_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ab2db_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ab2db_row2_col1" class="data row2 col1" >0.7359</td>
#       <td id="T_ab2db_row2_col2" class="data row2 col2" >0.7589</td>
#       <td id="T_ab2db_row2_col3" class="data row2 col3" >0.8897</td>
#       <td id="T_ab2db_row2_col4" class="data row2 col4" >0.7457</td>
#       <td id="T_ab2db_row2_col5" class="data row2 col5" >0.8114</td>
#       <td id="T_ab2db_row2_col6" class="data row2 col6" >0.3826</td>
#       <td id="T_ab2db_row2_col7" class="data row2 col7" >0.3996</td>
#       <td id="T_ab2db_row2_col8" class="data row2 col8" >0.9410</td>
#     </tr>
#   </tbody>
# </table>

# %%
lightgbm_model = create_model('lightgbm')
lr_model = create_model('lr')
xgboost_model = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_b7474_row10_col0, #T_b7474_row10_col1, #T_b7474_row10_col2, #T_b7474_row10_col3, #T_b7474_row10_col4, #T_b7474_row10_col5, #T_b7474_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b7474">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7474_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b7474_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b7474_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b7474_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b7474_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b7474_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b7474_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7474_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7474_row0_col0" class="data row0 col0" >0.7351</td>
#       <td id="T_b7474_row0_col1" class="data row0 col1" >0.7603</td>
#       <td id="T_b7474_row0_col2" class="data row0 col2" >0.8782</td>
#       <td id="T_b7474_row0_col3" class="data row0 col3" >0.7496</td>
#       <td id="T_b7474_row0_col4" class="data row0 col4" >0.8089</td>
#       <td id="T_b7474_row0_col5" class="data row0 col5" >0.3859</td>
#       <td id="T_b7474_row0_col6" class="data row0 col6" >0.3990</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7474_row1_col0" class="data row1 col0" >0.7336</td>
#       <td id="T_b7474_row1_col1" class="data row1 col1" >0.7535</td>
#       <td id="T_b7474_row1_col2" class="data row1 col2" >0.8927</td>
#       <td id="T_b7474_row1_col3" class="data row1 col3" >0.7422</td>
#       <td id="T_b7474_row1_col4" class="data row1 col4" >0.8105</td>
#       <td id="T_b7474_row1_col5" class="data row1 col5" >0.3747</td>
#       <td id="T_b7474_row1_col6" class="data row1 col6" >0.3933</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7474_row2_col0" class="data row2 col0" >0.7382</td>
#       <td id="T_b7474_row2_col1" class="data row2 col1" >0.7632</td>
#       <td id="T_b7474_row2_col2" class="data row2 col2" >0.8846</td>
#       <td id="T_b7474_row2_col3" class="data row2 col3" >0.7501</td>
#       <td id="T_b7474_row2_col4" class="data row2 col4" >0.8118</td>
#       <td id="T_b7474_row2_col5" class="data row2 col5" >0.3915</td>
#       <td id="T_b7474_row2_col6" class="data row2 col6" >0.4061</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7474_row3_col0" class="data row3 col0" >0.7429</td>
#       <td id="T_b7474_row3_col1" class="data row3 col1" >0.7626</td>
#       <td id="T_b7474_row3_col2" class="data row3 col2" >0.8931</td>
#       <td id="T_b7474_row3_col3" class="data row3 col3" >0.7511</td>
#       <td id="T_b7474_row3_col4" class="data row3 col4" >0.8160</td>
#       <td id="T_b7474_row3_col5" class="data row3 col5" >0.3998</td>
#       <td id="T_b7474_row3_col6" class="data row3 col6" >0.4167</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7474_row4_col0" class="data row4 col0" >0.7274</td>
#       <td id="T_b7474_row4_col1" class="data row4 col1" >0.7527</td>
#       <td id="T_b7474_row4_col2" class="data row4 col2" >0.8863</td>
#       <td id="T_b7474_row4_col3" class="data row4 col3" >0.7387</td>
#       <td id="T_b7474_row4_col4" class="data row4 col4" >0.8058</td>
#       <td id="T_b7474_row4_col5" class="data row4 col5" >0.3609</td>
#       <td id="T_b7474_row4_col6" class="data row4 col6" >0.3781</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b7474_row5_col0" class="data row5 col0" >0.7361</td>
#       <td id="T_b7474_row5_col1" class="data row5 col1" >0.7528</td>
#       <td id="T_b7474_row5_col2" class="data row5 col2" >0.8918</td>
#       <td id="T_b7474_row5_col3" class="data row5 col3" >0.7449</td>
#       <td id="T_b7474_row5_col4" class="data row5 col4" >0.8118</td>
#       <td id="T_b7474_row5_col5" class="data row5 col5" >0.3819</td>
#       <td id="T_b7474_row5_col6" class="data row5 col6" >0.3997</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b7474_row6_col0" class="data row6 col0" >0.7344</td>
#       <td id="T_b7474_row6_col1" class="data row6 col1" >0.7578</td>
#       <td id="T_b7474_row6_col2" class="data row6 col2" >0.8901</td>
#       <td id="T_b7474_row6_col3" class="data row6 col3" >0.7440</td>
#       <td id="T_b7474_row6_col4" class="data row6 col4" >0.8105</td>
#       <td id="T_b7474_row6_col5" class="data row6 col5" >0.3783</td>
#       <td id="T_b7474_row6_col6" class="data row6 col6" >0.3957</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b7474_row7_col0" class="data row7 col0" >0.7325</td>
#       <td id="T_b7474_row7_col1" class="data row7 col1" >0.7579</td>
#       <td id="T_b7474_row7_col2" class="data row7 col2" >0.8829</td>
#       <td id="T_b7474_row7_col3" class="data row7 col3" >0.7451</td>
#       <td id="T_b7474_row7_col4" class="data row7 col4" >0.8082</td>
#       <td id="T_b7474_row7_col5" class="data row7 col5" >0.3768</td>
#       <td id="T_b7474_row7_col6" class="data row7 col6" >0.3919</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7474_row8_col0" class="data row8 col0" >0.7366</td>
#       <td id="T_b7474_row8_col1" class="data row8 col1" >0.7643</td>
#       <td id="T_b7474_row8_col2" class="data row8 col2" >0.8974</td>
#       <td id="T_b7474_row8_col3" class="data row8 col3" >0.7433</td>
#       <td id="T_b7474_row8_col4" class="data row8 col4" >0.8131</td>
#       <td id="T_b7474_row8_col5" class="data row8 col5" >0.3802</td>
#       <td id="T_b7474_row8_col6" class="data row8 col6" >0.4001</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b7474_row9_col0" class="data row9 col0" >0.7426</td>
#       <td id="T_b7474_row9_col1" class="data row9 col1" >0.7642</td>
#       <td id="T_b7474_row9_col2" class="data row9 col2" >0.8995</td>
#       <td id="T_b7474_row9_col3" class="data row9 col3" >0.7482</td>
#       <td id="T_b7474_row9_col4" class="data row9 col4" >0.8169</td>
#       <td id="T_b7474_row9_col5" class="data row9 col5" >0.3956</td>
#       <td id="T_b7474_row9_col6" class="data row9 col6" >0.4151</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b7474_row10_col0" class="data row10 col0" >0.7359</td>
#       <td id="T_b7474_row10_col1" class="data row10 col1" >0.7589</td>
#       <td id="T_b7474_row10_col2" class="data row10 col2" >0.8897</td>
#       <td id="T_b7474_row10_col3" class="data row10 col3" >0.7457</td>
#       <td id="T_b7474_row10_col4" class="data row10 col4" >0.8114</td>
#       <td id="T_b7474_row10_col5" class="data row10 col5" >0.3826</td>
#       <td id="T_b7474_row10_col6" class="data row10 col6" >0.3996</td>
#     </tr>
#     <tr>
#       <th id="T_b7474_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_b7474_row11_col0" class="data row11 col0" >0.0044</td>
#       <td id="T_b7474_row11_col1" class="data row11 col1" >0.0045</td>
#       <td id="T_b7474_row11_col2" class="data row11 col2" >0.0063</td>
#       <td id="T_b7474_row11_col3" class="data row11 col3" >0.0037</td>
#       <td id="T_b7474_row11_col4" class="data row11 col4" >0.0032</td>
#       <td id="T_b7474_row11_col5" class="data row11 col5" >0.0107</td>
#       <td id="T_b7474_row11_col6" class="data row11 col6" >0.0107</td>
#     </tr>
#   </tbody>
# </table>
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   10:04:00
# Status     . . . . . . . . . . . . . . . . . .           Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/data.py:208: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ### Let's load in our 2021 season data and get retention scores using the model:

# %%
df_inference = df.loc[df["year"] >= 2022]
df_inference = df_inference.fillna(0)
df_inference.shape

# %%
lightgbm_predictions = predict_model(lightgbm_model, data=df_inference, raw_score=True)
lr_predictions = predict_model(lr_model, data=df_inference, raw_score=True)
xgboost_predictions = predict_model(xgboost_model, data=df_inference, raw_score=True)

# %%
print(f"lightgbm:\n {lightgbm_predictions.Label.value_counts()}")
print(f"log reg:\n {lr_predictions.Label.value_counts()}")
print(f"xgboost:\n {xgboost_predictions.Label.value_counts()}")

# %%
print(f"lightgbm:\n {lightgbm_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")
print(f"lr:\n {lr_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")
print(f"xgboost:\n {xgboost_predictions.Score_1.value_counts(bins=[0, 0.25, 0.5, 0.75, 1])}")

# %%
model_predictions = [lightgbm_predictions, lr_predictions, xgboost_predictions]

for idx, df_predictions in enumerate(model_predictions):

    plt.subplot(1, 3, idx+1)

    plt.hist(df_predictions["Score_1"], bins=20, edgecolor='black')
    plt.title("Retention Scores")
    plt.ylabel("Num Fans")
    plt.xlabel("SA Buyer Score")

plt.rcParams["figure.figsize"] = (20,4)
plt.show()

# %%
plot_model(lightgbm_model, plot='feature')

# %%
plot_model(lr_model, plot='feature')

# %%
plot_model(xgboost_model, plot='feature')

# %%
plot_model(lightgbm_model, plot='confusion_matrix')

# %%
plot_model(lr_model, plot='confusion_matrix')

# %%
plot_model(xgboost_model, plot='confusion_matrix')

# %% [markdown]
# ## Observations
# Here you can document some ideas on the results from above
