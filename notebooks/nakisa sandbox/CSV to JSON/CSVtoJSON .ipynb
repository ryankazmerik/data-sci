# %%
import pandas as pd
df = pd.read_csv (r'galaxy.csv')
df.to_json (r'galaxy_json.json')

# %%
df_json = pd.read_json (r'galaxy_json.json')

# %%
df_json
# Out:
#        atp_last  attended_last  attended_prior clientcode  \
# 0         73.50              1               1     GALAXY
# 1         32.86             11              11     GALAXY
# 2         37.50              1               1     GALAXY
# 3         25.41              1               1     GALAXY
# 4         42.25              4               4     GALAXY
# ...         ...            ...             ...        ...
# 14486      0.00              0               0     GALAXY
# 14487     28.13              1               1     GALAXY
# 14488     34.50              0               0     GALAXY
# 14489     46.80              0               0     GALAXY
# 14490     95.00              0               0     GALAXY
#
#        dimcustomermasterid  distance  events_last  events_prior  lkupclientid  \
# 0                437182025     94.66            1             1             6
# 1                437182052     13.20           15            15             6
# ...
