# %%
import getpass
import pyodbc
import pandas as pd
import warnings
import matplotlib.pyplot as plt

import datetime


from pytz import timezone
from pycaret.classification import *

warnings.filterwarnings('ignore')

# %%
def get_db_connection(dbEnvironment):
    if dbEnvironment =='QA':
        try:
            # connect to SQL Server.
            SERVER = '52.44.171.130' 
            DATABASE = 'datascience' 
            USERNAME = 'nrad' 
            PASSWORD = 'ThisIsQA123' #getpass.getpass(prompt='Enter your password')
            CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
            print("The Connection to "+dbEnvironment +" was succesfull")
        except Exception as err:
            print("The Connection to "+dbEnvironment +" wasn't succesfull", err)
    elif dbEnvironment =='PRD':
        try:
            # connect to SQL Server.
            SERVER = '34.206.73.189' 
            DATABASE = 'datascience' 
            USERNAME = 'nrad' 
            PASSWORD = '83F25619-D272-4660-98A2-93AF5CC18D59' #getpass.getpass(prompt='Enter your password')
            CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
            print("The Connection to "+dbEnvironment +" was succesfull")
        except Exception as err:
            print("The Connection to "+dbEnvironment +" wasn't succesfull", err)
    return CNXN

# %%
def get_ds_scores(connection):
    try:
        
        today = datetime.datetime.now()
        today_date = today.strftime("%Y-%m-%d")
        cursor = connection.cursor()
        clientid =  f'''select distinct lkupclientid, stlrDBName from ds.productyear_all;'''
        clientid_df = pd.read_sql(clientid, connection)
        lkupclientid = clientid_df['lkupclientid']
        stlrdbname = clientid_df['stlrDBName']
        for idx, m in enumerate(lkupclientid):
            lkupclientid_value=lkupclientid[idx]
            stlrdb_value= stlrdbname[idx]
            numRecords =  f'''select count(*) as numRecords  from ds.customerScores where lkupclientid ={lkupclientid_value} and cast(insertDate as date) = {"'"+ str(today_date) + "'"} group by lkupclientid;'''
            cntTodayScores = pd.read_sql(numRecords, connection)
            cntrecords= cntTodayScores['numRecords']
            for idx, m in enumerate(cntrecords):
                value=cntrecords[idx]
                if value == 0:
                    print("ds.customerScores is not updated for " +str(lkupclientid_value))
                elif value !=0:
                    print("ds.customerScores table is updated and " + str(value) + " records been inserted on " + str(today_date) + " for "+ str(lkupclientid_value))
        connection.commit()
        cursor.close()
    except Exception as err:
        
        print("The Connection wasn't succesfull", err)

# %%
def get_stlr_scores(factconnection):
    try:
        
        today = datetime.datetime.now()
        today_date_id = today.strftime("%Y%m%d")
        cursor = factconnection.cursor()
        clientid =  f'''select distinct lkupclientid, stlrDBName from ds.productyear_all;'''
        clientid_df = pd.read_sql(clientid, factconnection)
        lkupclientid = clientid_df['lkupclientid']
        stlrdbname = clientid_df['stlrDBName']
        for idx, m in enumerate(lkupclientid):
            lkupclientid_value=lkupclientid[idx]
            stlrdb_value= stlrdbname[idx] 
    
            try:
                SERVER = '34.206.73.189'
                DATABASE = stlrdb_value 
                USERNAME = 'nrad' 
                PASSWORD = '83F25619-D272-4660-98A2-93AF5CC18D59' #getpass.getpass(prompt='Enter your password')
                CNXN = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+SERVER+';DATABASE='+DATABASE+';UID='+USERNAME+';PWD='+ PASSWORD)
                print("The Connection to was succesfull to "+  stlrdb_value)
                fact_numRecords =  f'''select count(*) as factnumRecords from dw.factCustomerretentionScore where lkupclientid ={lkupclientid_value} and cast(dimDateId as int) = {today_date_id};'''
                cntTodayScores = pd.read_sql(fact_numRecords, CNXN)
                cntrecords= cntTodayScores['factnumRecords']
                for idx, m in enumerate(cntrecords):
                    value=cntrecords[idx]
                    if value == 0:
                        print("dw.factCustomerretentionScore is not updated for " +str(lkupclientid_value))
                    elif value !=0:
                        print("dw.factCustomerretentionScore table is updated and " + str(value) + " records been inserted on " + str(today_date_id) + " for "+ str(lkupclientid_value))
            except Exception as err:
                print("The Connection to wasn't succesfull to " + stlrdb_value, err)
        factconnection.commit()
        cursor.close()
    except Exception as err:
            print("The Connection wasn't succesfull", err)

# %%
def main():
    
    conn = get_db_connection("PRD")
    retention_scores = get_ds_scores(conn)
    fact_retention_scores = get_stlr_scores(conn)
if __name__ == "__main__":
    main()
# Out:
# The Connection to PRD was succesfull
# ds.customerScores table is updated and 7935 records been inserted on 2022-03-14 for 6
# ds.customerScores table is updated and 5130 records been inserted on 2022-03-14 for 7
# ds.customerScores table is updated and 1275 records been inserted on 2022-03-14 for 8
# ds.customerScores table is updated and 5184 records been inserted on 2022-03-14 for 13
# ds.customerScores table is updated and 1634 records been inserted on 2022-03-14 for 16
# ds.customerScores table is updated and 2941 records been inserted on 2022-03-14 for 31
# ds.customerScores table is updated and 5183 records been inserted on 2022-03-14 for 33
# ds.customerScores table is updated and 5369 records been inserted on 2022-03-14 for 36
# ds.customerScores table is updated and 777 records been inserted on 2022-03-14 for 37
# ds.customerScores table is updated and 2291 records been inserted on 2022-03-14 for 52
# ds.customerScores table is updated and 2643 records been inserted on 2022-03-14 for 55
# ds.customerScores table is updated and 712 records been inserted on 2022-03-14 for 56
# ds.customerScores table is updated and 3686 records been inserted on 2022-03-14 for 93
# The Connection to was succesfull to stlrTrailBlazers
# dw.factCustomerretentionScore is not updated for 5
# The Connection to was succesfull to stlrMLS
# dw.factCustomerretentionScore table is updated and 7935 records been inserted on 20220314 for 6
# The Connection to was succesfull to stlrCanucks
# dw.factCustomerretentionScore table is updated and 5130 records been inserted on 20220314 for 7
# The Connection to was succesfull to stlrNLL
# dw.factCustomerretentionScore table is updated and 1275 records been inserted on 20220314 for 8
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 9
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 11
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 12
# The Connection to was succesfull to stlrMLS
# dw.factCustomerretentionScore table is updated and 5184 records been inserted on 20220314 for 13
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 15
# The Connection to was succesfull to stlrAHL
# dw.factCustomerretentionScore is not updated for 16
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 17
# The Connection to was succesfull to stlrUSL
# dw.factCustomerretentionScore is not updated for 18
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 19
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 20
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 24
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 26
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 27
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 28
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 30
# The Connection to was succesfull to stlrMLS
# dw.factCustomerretentionScore table is updated and 2941 records been inserted on 20220314 for 31
# The Connection to was succesfull to stlrVGK
# dw.factCustomerretentionScore table is updated and 5183 records been inserted on 20220314 for 33
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 34
# The Connection to was succesfull to stlrCFL
# dw.factCustomerretentionScore is not updated for 35
# The Connection to was succesfull to stlrFlames
# dw.factCustomerretentionScore table is updated and 5369 records been inserted on 20220314 for 36
# The Connection to was succesfull to stlrWHL
# dw.factCustomerretentionScore table is updated and 777 records been inserted on 20220314 for 37
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 40
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 43
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 44
# The Connection to wasn't succesfull to stlrRays ('42000', '[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Cannot open database "stlrRays" requested by the login. The login failed. (4060) (SQLDriverConnect)')
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 47
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 48
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 49
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 51
# The Connection to was succesfull to stlrAHL
# dw.factCustomerretentionScore table is updated and 2291 records been inserted on 20220314 for 52
# The Connection to was succesfull to stlrCoyotes
# dw.factCustomerretentionScore table is updated and 2643 records been inserted on 20220314 for 55
# The Connection to was succesfull to stlrAHL
# dw.factCustomerretentionScore is not updated for 56
# The Connection to was succesfull to stlrMILB
# dw.factCustomerretentionScore is not updated for 59
# The Connection to was succesfull to stlrNHLPanthers
# dw.factCustomerretentionScore table is updated and 3686 records been inserted on 20220314 for 93
