# %% [markdown]
# # Calling RedShift Stored Procedure
# * StelllarAlgo Data Science
# * Ryan Kazmerik & Nakisa Rad
# * May 15, 2022
#
# This notebook provides example code of how to execute a RedShift stored procedure and get a result set back by connecting to the RedShift db directly using the psycodb2 package. The data and databases used are for demonstration purposes only:

# %%
import boto3
import pandas as pd
import psycopg2

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ### To connect to RedShift, we have to tell AWS which profile we'd like to login to, this will send us for a browser authentication trip:

# %%
! aws sso login --profile Stellaralgo-DataScienceAdmin
# Out:
# Attempting to automatically open the SSO authorization page in your default browser.
# If the browser does not open or you wish to use a different device to authorize this request, open the following URL:
#
# https://device.sso.us-east-1.amazonaws.com/
#
# Then enter the code:
#
# TZRH-GDTF
# Successfully logged into Start URL: https://stellaralgo.awsapps.com/start#/

# %% [markdown]
# ### Now we can create a session and client to RedShift (QA), and create a new connection using Psycopg2:

# %%
session = boto3.session.Session(profile_name='Stellaralgo-DataScienceAdmin')
client = session.client('redshift')

CLUSTER = 'qa-app'
DBNAME = 'stlrcfl'

creds = client.get_cluster_credentials(                
    ClusterIdentifier = CLUSTER,
    DbUser = 'admin',
    DbName = DBNAME,
    DbGroups = ['admin_group'],
    AutoCreate=True
)

# create a connection & cursor and call the stored procedure
conn = psycopg2.connect(
    host = 'qa-app.ctjussvyafp4.us-east-1.redshift.amazonaws.com',
    port = 5439,
    user = creds['DbUser'],
    password = creds['DbPassword'],
    database = DBNAME
)

print(f"GOT CONNECTION TO DATABASE: {CLUSTER} {DBNAME}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get Stored Proc Results.ipynb Cell 6' in <cell line: 16>()
#       <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=6'>7</a> creds = client.get_cluster_credentials(
#       <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=7'>8</a>     ClusterIdentifier = CLUSTER,
#       <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=8'>9</a>     DbUser = 'admin',
#    (...)
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=11'>12</a>     AutoCreate=True
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=12'>13</a> )
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=14'>15</a> # create a connection & cursor and call the stored procedure
# ---> <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=15'>16</a> conn = psycopg2.connect(
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=16'>17</a>     host = 'qa-app.ctjussvyafp4.us-east-1.redshift.amazonaws.com',
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=17'>18</a>     port = 5439,
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=18'>19</a>     user = creds['DbUser'],
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=19'>20</a>     password = creds['DbPassword'],
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=20'>21</a>     database = DBNAME
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=21'>22</a> )
#      <a href='vscode-notebook-cell:/Users/petermorrison/Documents/repos/data-sci/notebooks/examples/Get%20Stored%20Proc%20Results.ipynb#ch0000005?line=23'>24</a> print(f"GOT CONNECTION TO DATABASE: {CLUSTER} {DBNAME}")
#
# File ~/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     <a href='file:///Users/petermorrison/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py?line=118'>119</a>     kwasync['async_'] = kwargs.pop('async_')
#     <a href='file:///Users/petermorrison/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py?line=120'>121</a> dsn = _ext.make_dsn(dsn, **kwargs)
# --> <a href='file:///Users/petermorrison/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py?line=121'>122</a> conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     <a href='file:///Users/petermorrison/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py?line=122'>123</a> if cursor_factory is not None:
#     <a href='file:///Users/petermorrison/opt/miniconda3/envs/package/lib/python3.9/site-packages/psycopg2/__init__.py?line=123'>124</a>     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "qa-app.ctjussvyafp4.us-east-1.redshift.amazonaws.com" (54.162.199.152), port 5439 failed: Operation timed out
# 	Is the server running on that host and accepting TCP/IP connections?

# %% [markdown]
# ### Now we can call our stored procedure, and in the last parameter include the name of our named cursor, which we can then use to fetch all of the data returned by the stored proc, and load this into a dataframe:

# %%
# call the stored proc to get data for the retention model
cur = conn.cursor()
cur.execute(f"CALL dw.getretentionmodeldata(35, 2020, 2021, 'rkcursor')")

# create a named cursor based on the cursor name passed in above
named_cursor = conn.cursor('rkcursor')
data = named_cursor.fetchall()

# load the data and columns into a data frame
cols = [row[0] for row in named_cursor.description]
df = pd.DataFrame(data=data, columns=cols)

conn.commit()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5645 entries, 0 to 5644
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   lkupclientid         5645 non-null   int64
#  1   dimcustomermasterid  5645 non-null   int64
#  2   year                 5645 non-null   int64
#  3   productgrouping      5645 non-null   object
#  4   totalspent           5645 non-null   float64
#  5   recentdate           5645 non-null   datetime64[ns]
#  6   attendancepercent    5645 non-null   float64
#  7   renewedbeforedays    5645 non-null   int64
#  8   source_tenure        5645 non-null   object
#  9   tenure               5645 non-null   int64
#  10  disttovenue          5645 non-null   float64
#  11  recency              5645 non-null   int64
#  12  missed_games_1       5645 non-null   object
#  13  missed_games_2       5645 non-null   object
#  14  missed_games_over_2  5645 non-null   object
#  15  forward_records      5645 non-null   int64
#  16  opentosendratio      5645 non-null   object
#  17  clicktosendratio     5645 non-null   object
#  18  clicktoopenratio     5645 non-null   object
#  19  gender               5645 non-null   object
#  20  phonecall            5645 non-null   int64
#  21  inperson_contact     5645 non-null   int64
#  22  isnextyear_buyer     5645 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(10), object(9)
# memory usage: 1014.5+ KB

# %%
df.head()
# Out:
#    lkupclientid  dimcustomermasterid  year productgrouping  totalspent  \
# 0            11            272867517  2014           Group      254.83
# 1            11            272808838  2014           Group       80.00
# 2            11            272918909  2014       Mini Plan       72.00
# 3            11            304301466  2014       Mini Plan       64.00
# 4            11            272883990  2014           Group      170.81
#
#   recentdate  attendancepercent  renewedbeforedays source_tenure  tenure  \
# 0 1970-01-01               0.76                5.0             5     5.0
# 1 1970-01-01               1.00                6.0             6     6.0
# 2 2014-08-25               0.67               35.0          1825   132.0
# 3 1970-01-01               1.00                8.0          1825    81.0
# 4 1970-01-01               0.84               11.0            11    11.0
#
#    disttovenue  recency missed_games_1 missed_games_2 missed_games_over_2  \
# 0        24.07        0              1              0                   0
# 1         0.87        0              1              0                   0
# 2        19.28        0              0              0                   9
# 3        12.12        0              0              1                   0
# 4        30.64        0              1              0                   0
#
#    forward_records opentosendratio clicktosendratio clicktoopenratio   gender  \
# 0                0            0.00             0.00             0.00  Unknown
# 1                0            0.00             0.00             0.00  Unknown
# 2                0            0.00             0.00             0.00  Unknown
# 3                0            0.00             0.00             0.00  Unknown
# 4                0            0.00             0.00             0.00  Unknown
#
#    phonecall  inperson_contact  isnextyear_buyer
# 0          0                 0                 0
# 1          0                 0                 1
# 2          0                 0                 1
# 3          0                 0                 1
# 4          0                 0                 0
